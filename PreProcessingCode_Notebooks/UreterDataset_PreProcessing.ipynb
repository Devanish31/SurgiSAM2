# %% [markdown]
# ## Ureter Dataset Preprocessing

# %% [markdown]
# #### (For relative paths) This notebook is located in a folder, which is in the same folder as the original dataset being preprocessed
#
# Download dataset from -- "https://ieee-dataport.org/documents/ud-ureter-uterine-artery-nerve-dataset"

# %% [markdown]
# ## Confirming whether the masks only have 3 or less masks (1 for each organ type)

# %%
import os
import re
import random
import shutil
import numpy as np
import pandas as pd
from PIL import Image
from math import ceil
from collections import defaultdict

# Define the base directory as the relative path from your notebook location
base_dir = os.path.join("..", "Datasets_BeforePreprocessing", "UD Ureter-Uterine Artery-Nerve Dataset")

# Define paths to the images and masks directories relative to the base directory
images_dir = os.path.join(base_dir, "images")
masks_dir = os.path.join(base_dir, "mask")

# Get list of image file names without extensions
image_files = [os.path.splitext(f)[0] for f in os.listdir(images_dir) if os.path.isfile(os.path.join(images_dir, f))]

# Get list of mask file names without extensions
mask_files = [os.path.splitext(f)[0] for f in os.listdir(masks_dir) if os.path.isfile(os.path.join(masks_dir, f))]

# Initialize a dictionary to store mask counts for each image
mask_counts = defaultdict(int)

# Build a mapping of masks to images
for image_name in image_files:
    # Filter masks that correspond to the current image
    corresponding_masks = [mask for mask in mask_files if mask.startswith(image_name)]
    # Count the number of masks
    mask_counts[image_name] = len(corresponding_masks)

# Convert the results into a DataFrame
df_mask_counts = pd.DataFrame(list(mask_counts.items()), columns=['Image Name', 'Mask Count'])

# Define the path to save the Excel file
output_path = os.path.join(base_dir, "image_mask_counts.xlsx")

# Save the DataFrame to an Excel file
df_mask_counts.to_excel(output_path, index=False)

output_path
# Out:
# '..\\Datasets_BeforePreprocessing\\UD Ureter-Uterine Artery-Nerve Dataset\\image_mask_counts.xlsx'

# %% [markdown]
# ## Removing masks that have empty labels

# %%
# Function to check if a mask has no points (all zeros)
def is_empty_mask(mask_path):
    mask = np.array(Image.open(mask_path))
    return np.all(mask == 0)

# Initialize counter for deleted masks
deleted_mask_count = 0

# Iterate over all masks in the folder
for mask_file in os.listdir(masks_dir):
    mask_path = os.path.join(masks_dir, mask_file)
    if mask_file.endswith(('.png', '.jpg', '.jpeg')) and os.path.isfile(mask_path):
        if is_empty_mask(mask_path):
            os.remove(mask_path)  # Remove the empty mask
            deleted_mask_count += 1

# Output the result
print(f"Total number of empty masks removed: {deleted_mask_count}")
# Out:
# Total number of empty masks removed: 341

# %% [markdown]
# ## Splitting masks into ureter/artery/nerve folders

# %%
# Define output folders for each class
output_dirs = {
    "artery": os.path.join(mask_dir, "artery"),
    "ureter": os.path.join(mask_dir, "ureter"),
    "nerve": os.path.join(mask_dir, "nerve"),
}

# Ensure output directories exist
for class_label, path in output_dirs.items():
    os.makedirs(path, exist_ok=True)

# Move files to their respective folders
for mask_file in os.listdir(mask_dir):
    mask_path = os.path.join(mask_dir, mask_file)
    
    # Check if it is a file and classify it
    if os.path.isfile(mask_path):
        if "arthery" in mask_file:
            shutil.move(mask_path, output_dirs["artery"])
        elif "ureter" in mask_file:
            shutil.move(mask_path, output_dirs["ureter"])
        elif "nerve" in mask_file:
            shutil.move(mask_path, output_dirs["nerve"])

print("Masks have been organized into their respective folders.")
# Out:
# Masks have been organized into their respective folders.

# %% [markdown]
# ## Removing class identifiers/names of masks

# %%
class_dirs = {
    "artery": os.path.join(base_dir, "artery"),
    "ureter": os.path.join(base_dir, "ureter"),
    "nerve": os.path.join(base_dir, "nerve"),
}

# Rename files in artery folder
for filename in os.listdir(class_dirs["artery"]):
    if ".png_arthery" in filename:
        old_path = os.path.join(class_dirs["artery"], filename)
        new_filename = filename.replace(".png_arthery", "")
        new_path = os.path.join(class_dirs["artery"], new_filename)
        os.rename(old_path, new_path)

# Rename files in ureter folder
for filename in os.listdir(class_dirs["ureter"]):
    if ".png_ureter" in filename:
        old_path = os.path.join(class_dirs["ureter"], filename)
        new_filename = filename.replace(".png_ureter", "")
        new_path = os.path.join(class_dirs["ureter"], new_filename)
        os.rename(old_path, new_path)

# Rename files in nerve folder
for filename in os.listdir(class_dirs["nerve"]):
    if re.search(r"\.png_\d{1,3},\d{1,3}_nerve", filename):  # Match patterns like ".png_#,###_nerve" or ".png_0,36_nerve"
        old_path = os.path.join(class_dirs["nerve"], filename)
        new_filename = re.sub(r"\.png_\d{1,3},\d{1,3}_nerve", "", filename)
        new_path = os.path.join(class_dirs["nerve"], new_filename)
        os.rename(old_path, new_path)

print("Renaming completed for all classes.")
# Out:
# Renaming completed for all classes.

# %% [markdown]
# ## Splitting the nerve, ureter, and uterine artery masks into train/val/test (70/15/15) - also ensuring patient-wise split

# %%
# Define base directories
after_base_dir = os.path.join("..", "Datasets_AfterPreprocessing", "UD Ureter-Uterine Artery-Nerve Dataset")

# Source directories for masks
classes = ["nerve", "ureter", "artery"]
source_dirs = {class_label: os.path.join(base_dir, "mask", class_label) for class_label in classes}

# Target directories for splits in the after folder
split_dirs = {
    class_label: {
        "train": os.path.join(after_base_dir, "train", class_label),
        "val": os.path.join(after_base_dir, "val", class_label),
        "test": os.path.join(after_base_dir, "test", class_label),
    }
    for class_label in classes
}

# Ensure split directories exist
for class_label, splits in split_dirs.items():
    for split_dir in splits.values():
        os.makedirs(split_dir, exist_ok=True)

# Function to split masks for a class
def split_masks_by_class(class_label):
    print(f"\nProcessing class: {class_label.capitalize()}")

    # Group masks by patient
    mask_data = defaultdict(list)  # {patient_id: [mask_paths]}
    for mask_file in os.listdir(source_dirs[class_label]):
        if mask_file.endswith('.png'):
            patient_id = mask_file.split('.')[0]  # Extract patient ID (e.g., video_1)
            mask_path = os.path.join(source_dirs[class_label], mask_file)
            mask_data[patient_id].append(mask_path)

    # Shuffle patient IDs
    patients = list(mask_data.keys())
    random.shuffle(patients)

    # Define split ratios
    train_ratio, val_ratio, test_ratio = 0.7, 0.15, 0.15

    # Split patients into train, val, and test
    num_patients = len(patients)
    train_patients = patients[:int(num_patients * train_ratio)]
    val_patients = patients[int(num_patients * train_ratio):int(num_patients * (train_ratio + val_ratio))]
    test_patients = patients[int(num_patients * (train_ratio + val_ratio)):]

    # Print patient distribution
    print("Patient Distribution:")
    print(f"Train Patients: {len(train_patients)} -> {train_patients}")
    print(f"Val Patients: {len(val_patients)} -> {val_patients}")
    print(f"Test Patients: {len(test_patients)} -> {test_patients}")

    # Copy masks into respective split directories
    for split, patient_list in [("train", train_patients), ("val", val_patients), ("test", test_patients)]:
        for patient in patient_list:
            for mask_path in mask_data[patient]:
                destination = split_dirs[class_label][split]
                shutil.copy2(mask_path, destination)

    # Print split summary
    print(f"\nSplit Summary for {class_label.capitalize()}:")
    for split, split_dir in split_dirs[class_label].items():
        num_files = len(os.listdir(split_dir))
        print(f"{split.capitalize()}: {num_files} masks")

# Split masks for each class
for class_label in classes:
    split_masks_by_class(class_label)
# Out:
# Processing class: Nerve
# Patient Distribution:
# Train Patients: 4 -> ['video_14', 'video_18', 'video_15', 'video_19']
# Val Patients: 1 -> ['video_17']
# Test Patients: 1 -> ['video_16']
#
# Split Summary for Nerve:
# Train: 115 masks
# Val: 30 masks
# Test: 38 masks
#
# Processing class: Ureter
# Patient Distribution:
# Train Patients: 8 -> ['video_23', 'video_25', 'video_12', 'video_21', 'video_6', 'video_22', 'video_24', 'video_2']
# Val Patients: 2 -> ['video_4', 'video_5']
# Test Patients: 2 -> ['video_11', 'video_20']
#
# Split Summary for Ureter:
# Train: 165 masks
# Val: 35 masks
# Test: 54 masks
#
# Processing class: Artery
# Patient Distribution:
# Train Patients: 15 -> ['video_20', 'video_12', 'video_29', 'video_32', 'video_8', 'video_25', 'video_38', 'video_36', 'video_27', 'video_3', 'video_9', 'video_7', 'video_6', 'video_35', 'video_1']
# Val Patients: 3 -> ['video_13', 'video_31', 'video_26']
# Test Patients: 4 -> ['video_33', 'video_30', 'video_37', 'video_34']
#
# Split Summary for Artery:
# Train: 139 masks
# Val: 50 masks
# Test: 22 masks

# %% [markdown]
# ## Renaming image filenames

# %%
# Iterate over all files in the folder
for filename in os.listdir(images_dir):
    old_path = os.path.join(images_dir, filename)

    # Remove the last .png if it exists
    if filename.endswith('.png'):
        new_filename = filename.rsplit('.png', 1)[0]  # Remove only the last .png
    else:
        new_filename = filename

    # Remove patterns like ".png_#,###" if they exist, keeping the ".jpg"
    new_filename = re.sub(r"\.png_\d+,\d+", "", new_filename)  # Matches ".png_<digits>,<digits>"

    # If the name has changed, rename the file
    if new_filename != filename:
        new_path = os.path.join(images_dir, new_filename)
        os.rename(old_path, new_path)
        print(f'Renamed: "{filename}" to "{new_filename}"')

print("All redundant extensions and patterns have been removed.")
# Out:
# Renamed: "video_1.mov_0.024000.png.png" to "video_1.mov_0.024000.png"
# Renamed: "video_1.mov_0.320667.png.png" to "video_1.mov_0.320667.png"
# Renamed: "video_1.mov_0.466000.png.png" to "video_1.mov_0.466000.png"
# Renamed: "video_1.mov_0.483667.png.png" to "video_1.mov_0.483667.png"
# Renamed: "video_1.mov_0.508000.png.png" to "video_1.mov_0.508000.png"
# Renamed: "video_1.mov_0.697333.png.png" to "video_1.mov_0.697333.png"
# Renamed: "video_7.mp4_3.379600.png.png" to "video_7.mp4_3.379600.png"
# Renamed: "video_7.mp4_3.884400.png.png" to "video_7.mp4_3.884400.png"
# Renamed: "video_7.mp4_3.947200.png.png" to "video_7.mp4_3.947200.png"
# Renamed: "video_7.mp4_4.075200.png.png" to "video_7.mp4_4.075200.png"
# Renamed: "video_8.mp4_11.378000.png.png" to "video_8.mp4_11.378000.png"
# Renamed: "video_8.mp4_2.760400.png.png" to "video_8.mp4_2.760400.png"
# Renamed: "video_8.mp4_3.846000.png.png" to "video_8.mp4_3.846000.png"
# Renamed: "video_8.mp4_4.555600.png.png" to "video_8.mp4_4.555600.png"
# Renamed: "video_8.mp4_6.003200.png.png" to "video_8.mp4_6.003200.png"
# Renamed: "video_8.mp4_7.188000.png.png" to "video_8.mp4_7.188000.png"
# Renamed: "video_8.mp4_7.826000.png.png" to "video_8.mp4_7.826000.png"
# Renamed: "video_8.mp4_8.230400.png.png" to "video_8.mp4_8.230400.png"
# Renamed: "video_9.mp4_10.713200.png.png" to "video_9.mp4_10.713200.png"
# All redundant extensions and patterns have been removed.

# %% [markdown]
# ## Moving image files into "Masks" and "Frames" folders in each of train/val/test split folders according to "Masks" splits

# %%
# Define train, val, and test folders
mask_splits = ["train", "val", "test"]

# Iterate through each split (train, val, test)
for split in mask_splits:
    split_dir = os.path.join(after_base_dir, split)  # Current split directory
    masks_dir = os.path.join(split_dir, "Masks")  # New Masks directory

    # Ensure the Masks directory exists
    os.makedirs(masks_dir, exist_ok=True)

    # Move class folders (artery, nerve, ureter) into Masks
    for class_folder in ["artery", "nerve", "ureter"]:
        class_path = os.path.join(split_dir, class_folder)
        if os.path.exists(class_path) and os.path.isdir(class_path):
            shutil.move(class_path, masks_dir)  # Move the class folder to Masks
            print(f"Moved: {class_folder} to {masks_dir}")
        else:
            print(f"Warning: {class_folder} not found in {split_dir}")

print("Class folders have been moved into Masks in train/val/test splits.")
# Out:
# Moved: artery to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks
# Moved: nerve to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks
# Moved: ureter to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks
# Moved: artery to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\val\Masks
# Moved: nerve to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\val\Masks
# Moved: ureter to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\val\Masks
# Moved: artery to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\test\Masks
# Moved: nerve to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\test\Masks
# Moved: ureter to ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\test\Masks
# Class folders have been moved into Masks in train/val/test splits.

# %%
# Target directories for images (Frames) in the AfterPreprocessing splits
image_split_dirs = {split: os.path.join(after_base_dir, split, "Frames") for split in mask_splits}

# Ensure target directories for Frames exist
for split_dir in image_split_dirs.values():
    os.makedirs(split_dir, exist_ok=True)

# Copy images based on mask split filenames
for split in mask_splits:
    mask_dir = os.path.join(after_base_dir, split, "Masks")  # Mask directory
    image_dest_dir = image_split_dirs[split]  # Target directory for Frames

    # Iterate through all mask subdirectories (artery, nerve, ureter)
    for class_folder in os.listdir(mask_dir):
        class_path = os.path.join(mask_dir, class_folder)
        if os.path.isdir(class_path):  # Ensure it's a directory
            for mask_file in os.listdir(class_path):
                # Extract corresponding image filename without changing the extension
                base_name = os.path.splitext(mask_file)[0]
                
                # Check if the image exists with .png or .jpg 
                image_file = None
                for ext in [".png", ".jpg"]:
                    possible_image = base_name + ext
                    image_src = os.path.join(images_dir, possible_image)
                    if os.path.exists(image_src):
                        image_file = possible_image
                        break

                # If the image exists, copy it to the destination folder
                if image_file:
                    image_dest = os.path.join(image_dest_dir, image_file)
                    shutil.copy2(image_src, image_dest)
                    print(f"Copied: {image_file} to {split}/Frames")
                else:
                    print(f"Warning: No matching image found for {mask_file} in {images_dir}")

print("Images have been split into train/val/test Frames based on mask splits.")
# Out:
# Copied: video_1.mov_0.024000.png to train/Frames
# Copied: video_1.mov_0.320667.png to train/Frames
# Copied: video_1.mov_0.466000.png to train/Frames
# Copied: video_1.mov_0.483667.png to train/Frames
# Copied: video_1.mov_0.508000.png to train/Frames
# Copied: video_1.mov_0.697333.png to train/Frames
# Copied: video_1.mov_0.740333.png to train/Frames
# Copied: video_1.mov_0.848667.png to train/Frames
# Copied: video_1.mov_0.877667.png to train/Frames
# Copied: video_1.mov_1.020333.png to train/Frames
# Copied: video_1.mov_1.198333.png to train/Frames
# Copied: video_1.mov_1.300000.png to train/Frames
# Copied: video_1.mov_1.535000.png to train/Frames
# Copied: video_1.mov_1.759333.png to train/Frames
# Copied: video_1.mov_1.788667.png to train/Frames
# Copied: video_1.mov_10.017000.png to train/Frames
# Copied: video_1.mov_10.127667.png to train/Frames
# Copied: video_1.mov_10.177000.png to train/Frames
# Copied: video_1.mov_10.220333.png to train/Frames
# Copied: video_1.mov_10.310667.png to train/Frames
# Copied: video_1.mov_10.374333.png to train/Frames
# Copied: video_1.mov_10.407000.png to train/Frames
# Copied: video_1.mov_10.418667.png to train/Frames
# Copied: video_12.mov_0.998333.png to train/Frames
# Copied: video_12.mov_10.500333.png to train/Frames
# Copied: video_12.mov_2.804667.png to train/Frames
# Copied: video_12.mov_3.051333.png to train/Frames
# Copied: video_12.mov_3.728333.png to train/Frames
# Copied: video_12.mov_4.288000.png to train/Frames
# Copied: video_12.mov_4.713000.png to train/Frames
# Copied: video_12.mov_4.746333.png to train/Frames
# Copied: video_12.mov_4.886667.png to train/Frames
# Copied: video_12.mov_5.412667.png to train/Frames
# Copied: video_12.mov_6.210000.png to train/Frames
# Copied: video_12.mov_6.253333.png to train/Frames
# Copied: video_12.mov_6.493333.png to train/Frames
# Copied: video_12.mov_7.331333.png to train/Frames
# Copied: video_12.mov_7.343000.png to train/Frames
# Copied: video_12.mov_7.496000.png to train/Frames
# Copied: video_20.mov_0.094667.png to train/Frames
# Copied: video_20.mov_0.102000.png to train/Frames
# Copied: video_20.mov_0.777667.png to train/Frames
# Copied: video_20.mov_1.388667.png to train/Frames
# Copied: video_20.mov_1.957333.png to train/Frames
# Copied: video_20.mov_1.986000.png to train/Frames
# Copied: video_20.mov_10.580667.png to train/Frames
# Copied: video_20.mov_2.130667.png to train/Frames
# Copied: video_20.mov_2.165333.png to train/Frames
# Copied: video_20.mov_2.274667.png to train/Frames
# Copied: video_20.mov_3.395333.png to train/Frames
# Copied: video_20.mov_4.411667.png to train/Frames
# Copied: video_20.mov_4.449333.png to train/Frames
# Copied: video_20.mov_4.686000.png to train/Frames
# Copied: video_20.mov_5.076333.png to train/Frames
# Copied: video_20.mov_5.924333.png to train/Frames
# Copied: video_20.mov_6.513000.png to train/Frames
# Copied: video_20.mov_6.719000.png to train/Frames
# Copied: video_20.mov_7.013000.png to train/Frames
# Copied: video_20.mov_7.663333.png to train/Frames
# Copied: video_20.mov_8.569333.png to train/Frames
# Copied: video_20.mov_8.886667.png to train/Frames
# Copied: video_20.mov_9.221333.png to train/Frames
# Copied: video_20.mov_9.577667.png to train/Frames
# Copied: video_20.mov_9.614667.png to train/Frames
# Copied: video_20.mov_9.846000.png to train/Frames
# Copied: video_25.mp4_0.085410.png to train/Frames
# Copied: video_25.mp4_0.942508.png to train/Frames
# Copied: video_25.mp4_1.464974.png to train/Frames
# Copied: video_25.mp4_1.904699.png to train/Frames
# Copied: video_25.mp4_10.141715.png to train/Frames
# Copied: video_25.mp4_10.187089.png to train/Frames
# Copied: video_25.mp4_10.192093.png to train/Frames
# Copied: video_25.mp4_10.373922.png to train/Frames
# Copied: video_25.mp4_10.418295.png to train/Frames
# Copied: video_25.mp4_2.010794.png to train/Frames
# Copied: video_25.mp4_2.486218.png to train/Frames
# Copied: video_25.mp4_2.809507.png to train/Frames
# Copied: video_25.mp4_2.905259.png to train/Frames
# Copied: video_25.mp4_3.457084.png to train/Frames
# Copied: video_25.mp4_8.031833.png to train/Frames
# Copied: video_27.mov_0.434000.png to train/Frames
# Copied: video_27.mov_4.984400.png to train/Frames
# Copied: video_29.mp4_7.948000.png to train/Frames
# Copied: video_29.mp4_8.604000.png to train/Frames
# Copied: video_29.mp4_9.049667.png to train/Frames
# Copied: video_3.mov_0.187667.png to train/Frames
# Copied: video_3.mov_0.235667.png to train/Frames
# Copied: video_3.mov_0.258000.png to train/Frames
# Copied: video_3.mov_0.344667.png to train/Frames
# Copied: video_3.mov_0.612667.png to train/Frames
# Copied: video_3.mov_0.613000.png to train/Frames
# Copied: video_3.mov_0.906667.png to train/Frames
# Copied: video_3.mov_1.056000.png to train/Frames
# Copied: video_3.mov_1.385333.png to train/Frames
# Copied: video_3.mov_1.389000.png to train/Frames
# Copied: video_3.mov_1.390000.png to train/Frames
# Copied: video_3.mov_1.401000.png to train/Frames
# Copied: video_3.mov_1.417667.png to train/Frames
# Copied: video_3.mov_1.779667.png to train/Frames
# Copied: video_3.mov_1.909000.png to train/Frames
# Copied: video_32.mp4_11.179200.png to train/Frames
# Copied: video_32.mp4_11.850400.png to train/Frames
# Copied: video_32.mp4_5.290800.png to train/Frames
# Copied: video_32.mp4_7.186400.png to train/Frames
# Copied: video_32.mp4_7.753200.png to train/Frames
# Copied: video_32.mp4_9.388000.png to train/Frames
# Copied: video_35.mp4_10.006400.png to train/Frames
# Copied: video_35.mp4_13.037200.png to train/Frames
# Copied: video_35.mp4_8.661200.png to train/Frames
# Copied: video_36.mov_7.321600.png to train/Frames
# Copied: video_38.mov_0.663200.png to train/Frames
# Copied: video_38.mov_11.106800.png to train/Frames
# Copied: video_38.mov_2.991200.png to train/Frames
# Copied: video_38.mov_3.689600.png to train/Frames
# Copied: video_38.mov_6.343600.png to train/Frames
# Copied: video_6.mov_1.332000.png to train/Frames
# Copied: video_6.mov_10.522667.png to train/Frames
# Copied: video_6.mov_2.066333.png to train/Frames
# Copied: video_6.mov_2.930333.png to train/Frames
# Copied: video_6.mov_4.908667.png to train/Frames
# Copied: video_7.mp4_11.851600.png to train/Frames
# Copied: video_7.mp4_2.420800.png to train/Frames
# Copied: video_7.mp4_2.551600.png to train/Frames
# Copied: video_7.mp4_2.722400.png to train/Frames
# Copied: video_7.mp4_2.903600.png to train/Frames
# Copied: video_7.mp4_2.960000.png to train/Frames
# Copied: video_7.mp4_3.379600.png to train/Frames
# Copied: video_7.mp4_3.884400.png to train/Frames
# Copied: video_7.mp4_3.947200.png to train/Frames
# Copied: video_7.mp4_4.075200.png to train/Frames
# Copied: video_8.mp4_11.378000.png to train/Frames
# Copied: video_8.mp4_2.760400.png to train/Frames
# Copied: video_8.mp4_3.846000.png to train/Frames
# Copied: video_8.mp4_4.555600.png to train/Frames
# Copied: video_8.mp4_6.003200.png to train/Frames
# Copied: video_8.mp4_7.188000.png to train/Frames
# Copied: video_8.mp4_7.826000.png to train/Frames
# Copied: video_8.mp4_8.230400.png to train/Frames
# Copied: video_9.mp4_10.713200.png to train/Frames
# Copied: video_14.mov_1.035667.jpg to train/Frames
# Copied: video_14.mov_1.041000.jpg to train/Frames
# Copied: video_14.mov_1.355333.jpg to train/Frames
# Copied: video_14.mov_1.513667.jpg to train/Frames
# Copied: video_14.mov_1.682000.jpg to train/Frames
# Copied: video_14.mov_1.825667.jpg to train/Frames
# Copied: video_14.mov_1.992000.jpg to train/Frames
# Copied: video_14.mov_10.130000.jpg to train/Frames
# Copied: video_14.mov_10.212333.jpg to train/Frames
# Copied: video_14.mov_10.217000.jpg to train/Frames
# Copied: video_14.mov_10.234667.jpg to train/Frames
# Copied: video_14.mov_10.295667.jpg to train/Frames
# Copied: video_14.mov_10.355667.jpg to train/Frames
# Copied: video_14.mov_2.952667.jpg to train/Frames
# Copied: video_14.mov_2.972000.jpg to train/Frames
# Copied: video_14.mov_3.380667.jpg to train/Frames
# Copied: video_14.mov_4.067333.jpg to train/Frames
# Copied: video_14.mov_4.183000.jpg to train/Frames
# Copied: video_14.mov_4.499333.jpg to train/Frames
# Copied: video_14.mov_4.677000.jpg to train/Frames
# Copied: video_14.mov_4.749000.jpg to train/Frames
# Copied: video_14.mov_5.178333.jpg to train/Frames
# Copied: video_14.mov_5.220000.jpg to train/Frames
# Copied: video_14.mov_7.528667.jpg to train/Frames
# Copied: video_14.mov_7.560000.jpg to train/Frames
# Copied: video_14.mov_7.925333.jpg to train/Frames
# Copied: video_14.mov_8.042667.jpg to train/Frames
# Copied: video_14.mov_8.081333.jpg to train/Frames
# Copied: video_14.mov_8.159667.jpg to train/Frames
# Copied: video_14.mov_8.450667.jpg to train/Frames
# Copied: video_14.mov_8.476000.jpg to train/Frames
# Copied: video_14.mov_8.537667.jpg to train/Frames
# Copied: video_14.mov_8.695667.jpg to train/Frames
# Copied: video_14.mov_8.779333.jpg to train/Frames
# Copied: video_14.mov_9.667333.jpg to train/Frames
# Copied: video_14.mov_9.747667.jpg to train/Frames
# Copied: video_14.mov_9.768667.jpg to train/Frames
# Copied: video_14.mov_9.961667.jpg to train/Frames
# Copied: video_15.mov_0.130000.jpg to train/Frames
# Copied: video_15.mov_0.827667.jpg to train/Frames
# Copied: video_15.mov_1.299667.jpg to train/Frames
# Copied: video_15.mov_1.417000.jpg to train/Frames
# Copied: video_15.mov_2.145667.jpg to train/Frames
# Copied: video_15.mov_2.444000.jpg to train/Frames
# Copied: video_15.mov_2.658000.jpg to train/Frames
# Copied: video_15.mov_2.740333.jpg to train/Frames
# Copied: video_15.mov_2.775667.jpg to train/Frames
# Copied: video_15.mov_2.785333.jpg to train/Frames
# Copied: video_15.mov_2.811000.jpg to train/Frames
# Copied: video_15.mov_3.676667.jpg to train/Frames
# Copied: video_15.mov_3.717333.jpg to train/Frames
# Copied: video_15.mov_3.820000.jpg to train/Frames
# Copied: video_15.mov_3.837667.jpg to train/Frames
# Copied: video_15.mov_4.150667.jpg to train/Frames
# Copied: video_15.mov_5.119667.jpg to train/Frames
# Copied: video_15.mov_5.165000.jpg to train/Frames
# Copied: video_15.mov_5.442667.jpg to train/Frames
# Copied: video_15.mov_5.524333.jpg to train/Frames
# Copied: video_15.mov_5.790333.jpg to train/Frames
# Copied: video_15.mov_5.974000.jpg to train/Frames
# Copied: video_15.mov_5.998333.jpg to train/Frames
# Copied: video_15.mov_6.194667.jpg to train/Frames
# Copied: video_15.mov_6.204333.jpg to train/Frames
# Copied: video_15.mov_6.386333.jpg to train/Frames
# Copied: video_15.mov_6.391000.jpg to train/Frames
# Copied: video_15.mov_6.723000.jpg to train/Frames
# Copied: video_18.mov_0.319000.jpg to train/Frames
# Copied: video_18.mov_0.933000.jpg to train/Frames
# Copied: video_18.mov_1.213000.jpg to train/Frames
# Copied: video_18.mov_1.281333.jpg to train/Frames
# Copied: video_18.mov_10.254667.jpg to train/Frames
# Copied: video_18.mov_10.693000.jpg to train/Frames
# Copied: video_18.mov_3.237000.jpg to train/Frames
# Copied: video_18.mov_3.289333.jpg to train/Frames
# Copied: video_18.mov_3.396000.jpg to train/Frames
# Copied: video_18.mov_3.478000.jpg to train/Frames
# Copied: video_18.mov_3.830333.jpg to train/Frames
# Copied: video_18.mov_4.135333.jpg to train/Frames
# Copied: video_18.mov_6.310000.jpg to train/Frames
# Copied: video_18.mov_6.410333.jpg to train/Frames
# Copied: video_18.mov_6.492000.jpg to train/Frames
# Copied: video_18.mov_6.578333.jpg to train/Frames
# Copied: video_18.mov_6.797333.jpg to train/Frames
# Copied: video_18.mov_7.037667.jpg to train/Frames
# Copied: video_18.mov_7.760333.jpg to train/Frames
# Copied: video_18.mov_7.966000.jpg to train/Frames
# Copied: video_19.mov_0.412333.jpg to train/Frames
# Copied: video_19.mov_1.078000.jpg to train/Frames
# Copied: video_19.mov_1.165667.jpg to train/Frames
# Copied: video_19.mov_1.490667.jpg to train/Frames
# Copied: video_19.mov_10.519333.jpg to train/Frames
# Copied: video_19.mov_10.674667.jpg to train/Frames
# Copied: video_19.mov_10.788333.jpg to train/Frames
# Copied: video_19.mov_2.158667.jpg to train/Frames
# Copied: video_19.mov_2.529333.jpg to train/Frames
# Copied: video_19.mov_5.138000.jpg to train/Frames
# Copied: video_19.mov_5.236667.jpg to train/Frames
# Copied: video_19.mov_5.339333.jpg to train/Frames
# Copied: video_19.mov_5.344000.jpg to train/Frames
# Copied: video_19.mov_5.394000.jpg to train/Frames
# Copied: video_19.mov_5.456333.jpg to train/Frames
# Copied: video_19.mov_5.458333.jpg to train/Frames
# Copied: video_19.mov_5.692000.jpg to train/Frames
# Copied: video_19.mov_5.972333.jpg to train/Frames
# Copied: video_19.mov_6.291667.jpg to train/Frames
# Copied: video_19.mov_6.654333.jpg to train/Frames
# Copied: video_19.mov_6.739000.jpg to train/Frames
# Copied: video_19.mov_6.815333.jpg to train/Frames
# Copied: video_19.mov_8.693000.jpg to train/Frames
# Copied: video_19.mov_8.787667.jpg to train/Frames
# Copied: video_19.mov_9.376667.jpg to train/Frames
# Copied: video_19.mov_9.665000.jpg to train/Frames
# Copied: video_19.mov_9.863333.jpg to train/Frames
# Copied: video_19.mov_9.871667.jpg to train/Frames
# Copied: video_19.mov_9.971667.jpg to train/Frames
# Copied: video_12.mov_0.998333.png to train/Frames
# Copied: video_12.mov_1.430667.png to train/Frames
# Copied: video_12.mov_10.500333.png to train/Frames
# Copied: video_12.mov_2.027667.png to train/Frames
# Copied: video_12.mov_2.804667.png to train/Frames
# Copied: video_12.mov_3.051333.png to train/Frames
# Copied: video_12.mov_3.108667.png to train/Frames
# Copied: video_12.mov_3.728333.png to train/Frames
# Copied: video_12.mov_4.081000.png to train/Frames
# Copied: video_12.mov_4.088333.png to train/Frames
# Copied: video_12.mov_4.288000.png to train/Frames
# Copied: video_12.mov_4.713000.png to train/Frames
# Copied: video_12.mov_4.746333.png to train/Frames
# Copied: video_12.mov_4.886667.png to train/Frames
# Copied: video_12.mov_5.412667.png to train/Frames
# Copied: video_12.mov_5.813000.png to train/Frames
# Copied: video_12.mov_6.210000.png to train/Frames
# Copied: video_12.mov_6.253333.png to train/Frames
# Copied: video_12.mov_6.493333.png to train/Frames
# Copied: video_12.mov_7.331333.png to train/Frames
# Copied: video_12.mov_7.343000.png to train/Frames
# Copied: video_12.mov_7.496000.png to train/Frames
# Copied: video_2.mov_0.036667.png to train/Frames
# Copied: video_2.mov_0.096667.png to train/Frames
# Copied: video_2.mov_0.113000.png to train/Frames
# Copied: video_2.mov_0.365000.png to train/Frames
# Copied: video_2.mov_0.482333.png to train/Frames
# Copied: video_2.mov_1.300667.png to train/Frames
# Copied: video_2.mov_1.471000.png to train/Frames
# Copied: video_2.mov_1.964667.png to train/Frames
# Copied: video_2.mov_10.040333.png to train/Frames
# Copied: video_2.mov_10.130667.png to train/Frames
# Copied: video_2.mov_10.222000.png to train/Frames
# Copied: video_21.mov_0.376000.png to train/Frames
# Copied: video_21.mov_0.826333.png to train/Frames
# Copied: video_21.mov_0.919000.png to train/Frames
# Copied: video_21.mov_1.065333.png to train/Frames
# Copied: video_21.mov_1.209000.png to train/Frames
# Copied: video_21.mov_1.341000.png to train/Frames
# Copied: video_21.mov_1.387000.png to train/Frames
# Copied: video_21.mov_1.434333.png to train/Frames
# Copied: video_21.mov_1.480333.png to train/Frames
# Copied: video_21.mov_1.511333.png to train/Frames
# Copied: video_21.mov_1.627333.png to train/Frames
# Copied: video_21.mov_1.721000.png to train/Frames
# Copied: video_21.mov_1.766333.png to train/Frames
# Copied: video_21.mov_1.978333.png to train/Frames
# Copied: video_21.mov_1.999667.png to train/Frames
# Copied: video_21.mov_10.127000.png to train/Frames
# Copied: video_21.mov_10.457000.png to train/Frames
# Copied: video_21.mov_10.841333.png to train/Frames
# Copied: video_21.mov_10.889333.png to train/Frames
# Copied: video_21.mov_10.892333.png to train/Frames
# Copied: video_21.mov_2.038667.png to train/Frames
# Copied: video_21.mov_2.736000.png to train/Frames
# Copied: video_21.mov_2.863000.png to train/Frames
# Copied: video_21.mov_3.010333.png to train/Frames
# Copied: video_21.mov_3.022000.png to train/Frames
# Copied: video_21.mov_3.114000.png to train/Frames
# Copied: video_21.mov_3.388667.png to train/Frames
# Copied: video_21.mov_4.002000.png to train/Frames
# Copied: video_21.mov_4.013667.png to train/Frames
# Copied: video_21.mov_4.236000.png to train/Frames
# Copied: video_21.mov_4.280667.png to train/Frames
# Copied: video_21.mov_4.349667.png to train/Frames
# Copied: video_21.mov_4.369667.png to train/Frames
# Copied: video_21.mov_4.390000.png to train/Frames
# Copied: video_21.mov_4.536667.png to train/Frames
# Copied: video_21.mov_4.786333.png to train/Frames
# Copied: video_21.mov_4.817667.png to train/Frames
# Copied: video_21.mov_4.860333.png to train/Frames
# Copied: video_21.mov_4.898333.png to train/Frames
# Copied: video_21.mov_5.336333.png to train/Frames
# Copied: video_21.mov_5.434333.png to train/Frames
# Copied: video_21.mov_5.545333.png to train/Frames
# Copied: video_21.mov_5.755000.png to train/Frames
# Copied: video_21.mov_5.859333.png to train/Frames
# Copied: video_21.mov_9.712000.png to train/Frames
# Copied: video_21.mov_9.783667.png to train/Frames
# Copied: video_21.mov_9.814333.png to train/Frames
# Copied: video_22.mov_0.012667.png to train/Frames
# Copied: video_22.mov_0.073333.png to train/Frames
# Copied: video_22.mov_0.213000.png to train/Frames
# Copied: video_22.mov_0.367000.png to train/Frames
# Copied: video_22.mov_0.597000.png to train/Frames
# Copied: video_22.mov_0.692333.png to train/Frames
# Copied: video_22.mov_0.993000.png to train/Frames
# Copied: video_22.mov_10.297000.png to train/Frames
# Copied: video_22.mov_10.314667.png to train/Frames
# Copied: video_22.mov_10.583667.png to train/Frames
# Copied: video_22.mov_10.752667.png to train/Frames
# Copied: video_22.mov_10.892000.png to train/Frames
# Copied: video_22.mov_2.851000.png to train/Frames
# Copied: video_22.mov_3.133333.png to train/Frames
# Copied: video_22.mov_3.154000.png to train/Frames
# Copied: video_22.mov_3.559000.png to train/Frames
# Copied: video_22.mov_4.291333.png to train/Frames
# Copied: video_22.mov_4.312333.png to train/Frames
# Copied: video_22.mov_4.420000.png to train/Frames
# Copied: video_22.mov_4.612333.png to train/Frames
# Copied: video_22.mov_4.619000.png to train/Frames
# Copied: video_22.mov_4.803000.png to train/Frames
# Copied: video_22.mov_4.879333.png to train/Frames
# Copied: video_22.mov_5.929667.png to train/Frames
# Copied: video_22.mov_6.621000.png to train/Frames
# Copied: video_22.mov_7.293333.png to train/Frames
# Copied: video_22.mov_7.303000.png to train/Frames
# Copied: video_22.mov_7.430000.png to train/Frames
# Copied: video_22.mov_7.478667.png to train/Frames
# Copied: video_22.mov_7.575000.png to train/Frames
# Copied: video_22.mov_7.643333.png to train/Frames
# Copied: video_23.mov_0.565667.png to train/Frames
# Copied: video_23.mov_0.585000.png to train/Frames
# Copied: video_23.mov_0.606667.png to train/Frames
# Copied: video_23.mov_0.709333.png to train/Frames
# Copied: video_23.mov_0.771667.png to train/Frames
# Copied: video_23.mov_1.047667.png to train/Frames
# Copied: video_23.mov_1.180000.png to train/Frames
# Copied: video_23.mov_1.323667.png to train/Frames
# Copied: video_23.mov_2.253000.png to train/Frames
# Copied: video_23.mov_2.469333.png to train/Frames
# Copied: video_23.mov_2.537000.png to train/Frames
# Copied: video_23.mov_2.657333.png to train/Frames
# Copied: video_23.mov_3.014000.png to train/Frames
# Copied: video_23.mov_3.252667.png to train/Frames
# Copied: video_23.mov_3.260333.png to train/Frames
# Copied: video_23.mov_3.826000.png to train/Frames
# Copied: video_23.mov_3.968000.png to train/Frames
# Copied: video_23.mov_4.598333.png to train/Frames
# Copied: video_23.mov_4.988000.png to train/Frames
# Copied: video_23.mov_5.398667.png to train/Frames
# Copied: video_23.mov_5.476667.png to train/Frames
# Copied: video_23.mov_5.557000.png to train/Frames
# Copied: video_23.mov_5.604333.png to train/Frames
# Copied: video_23.mov_5.757000.png to train/Frames
# Copied: video_23.mov_6.587667.png to train/Frames
# Copied: video_24.mov_0.349000.png to train/Frames
# Copied: video_24.mov_0.465333.png to train/Frames
# Copied: video_24.mov_0.540333.png to train/Frames
# Copied: video_24.mov_0.669000.png to train/Frames
# Copied: video_24.mov_0.674667.png to train/Frames
# Copied: video_24.mov_0.879000.png to train/Frames
# Copied: video_24.mov_0.961333.png to train/Frames
# Copied: video_24.mov_1.152333.png to train/Frames
# Copied: video_24.mov_1.934667.png to train/Frames
# Copied: video_25.mp4_0.085410.png to train/Frames
# Copied: video_25.mp4_0.942508.png to train/Frames
# Copied: video_25.mp4_1.464974.png to train/Frames
# Copied: video_25.mp4_1.904699.png to train/Frames
# Copied: video_25.mp4_10.141715.png to train/Frames
# Copied: video_25.mp4_10.187089.png to train/Frames
# Copied: video_25.mp4_10.192093.png to train/Frames
# Copied: video_25.mp4_10.373922.png to train/Frames
# Copied: video_25.mp4_10.418295.png to train/Frames
# Copied: video_25.mp4_2.010794.png to train/Frames
# Copied: video_25.mp4_2.486218.png to train/Frames
# Copied: video_25.mp4_2.809507.png to train/Frames
# Copied: video_25.mp4_2.905259.png to train/Frames
# Copied: video_25.mp4_3.457084.png to train/Frames
# Copied: video_25.mp4_8.031833.png to train/Frames
# Copied: video_6.mov_1.332000.png to train/Frames
# Copied: video_6.mov_10.522667.png to train/Frames
# Copied: video_6.mov_2.066333.png to train/Frames
# Copied: video_6.mov_2.930333.png to train/Frames
# Copied: video_6.mov_4.908667.png to train/Frames
# Copied: video_13.mov_0.235333.png to val/Frames
# Copied: video_13.mov_0.365000.png to val/Frames
# Copied: video_13.mov_0.614000.png to val/Frames
# Copied: video_13.mov_0.654000.png to val/Frames
# Copied: video_13.mov_0.751333.png to val/Frames
# Copied: video_13.mov_0.949667.png to val/Frames
# Copied: video_13.mov_0.998667.png to val/Frames
# Copied: video_13.mov_1.009667.png to val/Frames
# Copied: video_13.mov_1.099000.png to val/Frames
# Copied: video_13.mov_1.114667.png to val/Frames
# Copied: video_13.mov_1.159333.png to val/Frames
# Copied: video_13.mov_1.239000.png to val/Frames
# Copied: video_13.mov_1.265333.png to val/Frames
# Copied: video_13.mov_1.334333.png to val/Frames
# Copied: video_13.mov_1.384333.png to val/Frames
# Copied: video_13.mov_1.457667.png to val/Frames
# Copied: video_13.mov_2.015333.png to val/Frames
# Copied: video_13.mov_2.167333.png to val/Frames
# Copied: video_13.mov_2.402667.png to val/Frames
# Copied: video_13.mov_2.775000.png to val/Frames
# Copied: video_13.mov_2.898000.png to val/Frames
# Copied: video_13.mov_3.115667.png to val/Frames
# Copied: video_13.mov_3.128667.png to val/Frames
# Copied: video_13.mov_3.610000.png to val/Frames
# Copied: video_13.mov_3.700667.png to val/Frames
# Copied: video_13.mov_3.718333.png to val/Frames
# Copied: video_13.mov_3.773667.png to val/Frames
# Copied: video_13.mov_3.807000.png to val/Frames
# Copied: video_13.mov_3.945000.png to val/Frames
# Copied: video_13.mov_4.246333.png to val/Frames
# Copied: video_13.mov_4.335000.png to val/Frames
# Copied: video_13.mov_4.368667.png to val/Frames
# Copied: video_13.mov_5.032333.png to val/Frames
# Copied: video_13.mov_5.548667.png to val/Frames
# Copied: video_13.mov_5.648000.png to val/Frames
# Copied: video_13.mov_5.718667.png to val/Frames
# Copied: video_13.mov_5.766667.png to val/Frames
# Copied: video_13.mov_6.057667.png to val/Frames
# Copied: video_13.mov_6.121667.png to val/Frames
# Copied: video_13.mov_6.126000.png to val/Frames
# Copied: video_13.mov_6.342667.png to val/Frames
# Copied: video_13.mov_6.404000.png to val/Frames
# Copied: video_26.mov_10.778800.png to val/Frames
# Copied: video_26.mov_10.904400.png to val/Frames
# Copied: video_31.mov_0.004000.png to val/Frames
# Copied: video_31.mov_0.010800.png to val/Frames
# Copied: video_31.mov_0.533600.png to val/Frames
# Copied: video_31.mov_0.678400.png to val/Frames
# Copied: video_31.mov_2.365600.png to val/Frames
# Copied: video_31.mov_2.414800.png to val/Frames
# Copied: video_17.mov_0.168333.jpg to val/Frames
# Copied: video_17.mov_1.214333.jpg to val/Frames
# Copied: video_17.mov_1.441000.jpg to val/Frames
# Copied: video_17.mov_1.844667.jpg to val/Frames
# Copied: video_17.mov_10.139000.jpg to val/Frames
# Copied: video_17.mov_10.284667.jpg to val/Frames
# Copied: video_17.mov_10.318667.jpg to val/Frames
# Copied: video_17.mov_10.438000.jpg to val/Frames
# Copied: video_17.mov_2.002333.jpg to val/Frames
# Copied: video_17.mov_2.062000.jpg to val/Frames
# Copied: video_17.mov_5.310333.jpg to val/Frames
# Copied: video_17.mov_5.343000.jpg to val/Frames
# Copied: video_17.mov_5.361000.jpg to val/Frames
# Copied: video_17.mov_5.546333.jpg to val/Frames
# Copied: video_17.mov_5.571000.jpg to val/Frames
# Copied: video_17.mov_6.279333.jpg to val/Frames
# Copied: video_17.mov_6.825667.jpg to val/Frames
# Copied: video_17.mov_7.069000.jpg to val/Frames
# Copied: video_17.mov_7.084333.jpg to val/Frames
# Copied: video_17.mov_7.493667.jpg to val/Frames
# Copied: video_17.mov_7.985667.jpg to val/Frames
# Copied: video_17.mov_8.126000.jpg to val/Frames
# Copied: video_17.mov_8.462000.jpg to val/Frames
# Copied: video_17.mov_8.512333.jpg to val/Frames
# Copied: video_17.mov_8.519667.jpg to val/Frames
# Copied: video_17.mov_8.668667.jpg to val/Frames
# Copied: video_17.mov_8.917333.jpg to val/Frames
# Copied: video_17.mov_8.963333.jpg to val/Frames
# Copied: video_17.mov_9.828667.jpg to val/Frames
# Copied: video_17.mov_9.859333.jpg to val/Frames
# Copied: video_4.mp4_1.197502.png to val/Frames
# Copied: video_4.mp4_1.205838.png to val/Frames
# Copied: video_4.mp4_1.443271.png to val/Frames
# Copied: video_4.mp4_10.524074.png to val/Frames
# Copied: video_4.mp4_10.601440.png to val/Frames
# Copied: video_4.mp4_2.045190.png to val/Frames
# Copied: video_4.mp4_2.565074.png to val/Frames
# Copied: video_4.mp4_3.181999.png to val/Frames
# Copied: video_4.mp4_3.592505.png to val/Frames
# Copied: video_4.mp4_4.002343.png to val/Frames
# Copied: video_4.mp4_4.719310.png to val/Frames
# Copied: video_4.mp4_4.720644.png to val/Frames
# Copied: video_4.mp4_6.370668.png to val/Frames
# Copied: video_4.mp4_6.586425.png to val/Frames
# Copied: video_4.mp4_7.000265.png to val/Frames
# Copied: video_4.mp4_7.142658.png to val/Frames
# Copied: video_4.mp4_7.151995.png to val/Frames
# Copied: video_4.mp4_7.471129.png to val/Frames
# Copied: video_4.mp4_7.580842.png to val/Frames
# Copied: video_4.mp4_7.896974.png to val/Frames
# Copied: video_4.mp4_8.028029.png to val/Frames
# Copied: video_4.mp4_8.084052.png to val/Frames
# Copied: video_4.mp4_8.183761.png to val/Frames
# Copied: video_4.mp4_8.272131.png to val/Frames
# Copied: video_4.mp4_8.388180.png to val/Frames
# Copied: video_4.mp4_8.560919.png to val/Frames
# Copied: video_4.mp4_9.468966.png to val/Frames
# Copied: video_5.mov_0.955333.png to val/Frames
# Copied: video_5.mov_2.448333.png to val/Frames
# Copied: video_5.mov_3.878333.png to val/Frames
# Copied: video_5.mov_4.044000.png to val/Frames
# Copied: video_5.mov_4.077667.png to val/Frames
# Copied: video_5.mov_4.229000.png to val/Frames
# Copied: video_5.mov_6.234333.png to val/Frames
# Copied: video_5.mov_6.986667.png to val/Frames
# Copied: video_30.mov_10.677600.png to test/Frames
# Copied: video_30.mov_10.821600.png to test/Frames
# Copied: video_30.mov_11.622400.png to test/Frames
# Copied: video_30.mov_12.459200.png to test/Frames
# Copied: video_30.mov_13.053600.png to test/Frames
# Copied: video_30.mov_3.952400.png to test/Frames
# Copied: video_30.mov_4.257600.png to test/Frames
# Copied: video_30.mov_5.216800.png to test/Frames
# Copied: video_33.mp4_0.669667.png to test/Frames
# Copied: video_33.mp4_10.179667.png to test/Frames
# Copied: video_33.mp4_10.333000.png to test/Frames
# Copied: video_33.mp4_10.607000.png to test/Frames
# Copied: video_33.mp4_4.332667.png to test/Frames
# Copied: video_33.mp4_7.096000.png to test/Frames
# Copied: video_33.mp4_7.853667.png to test/Frames
# Copied: video_33.mp4_9.898333.png to test/Frames
# Copied: video_34.mov_3.454000.png to test/Frames
# Copied: video_37.mov_0.037600.png to test/Frames
# Copied: video_37.mov_0.301200.png to test/Frames
# Copied: video_37.mov_0.328400.png to test/Frames
# Copied: video_37.mov_1.071600.png to test/Frames
# Copied: video_37.mov_1.366000.png to test/Frames
# Copied: video_16.mov_0.853667.jpg to test/Frames
# Copied: video_16.mov_0.915333.jpg to test/Frames
# Copied: video_16.mov_0.921667.jpg to test/Frames
# Copied: video_16.mov_1.345000.jpg to test/Frames
# Copied: video_16.mov_1.484667.jpg to test/Frames
# Copied: video_16.mov_1.581667.jpg to test/Frames
# Copied: video_16.mov_1.588000.jpg to test/Frames
# Copied: video_16.mov_10.499667.jpg to test/Frames
# Copied: video_16.mov_10.874667.jpg to test/Frames
# Copied: video_16.mov_10.907000.jpg to test/Frames
# Copied: video_16.mov_2.500333.jpg to test/Frames
# Copied: video_16.mov_2.617000.jpg to test/Frames
# Copied: video_16.mov_2.836000.jpg to test/Frames
# Copied: video_16.mov_2.872000.jpg to test/Frames
# Copied: video_16.mov_2.878667.jpg to test/Frames
# Copied: video_16.mov_4.363000.jpg to test/Frames
# Copied: video_16.mov_4.383000.jpg to test/Frames
# Copied: video_16.mov_4.708000.jpg to test/Frames
# Copied: video_16.mov_4.832333.jpg to test/Frames
# Copied: video_16.mov_4.919667.jpg to test/Frames
# Copied: video_16.mov_5.598667.jpg to test/Frames
# Copied: video_16.mov_5.772333.jpg to test/Frames
# Copied: video_16.mov_5.877333.jpg to test/Frames
# Copied: video_16.mov_6.574333.jpg to test/Frames
# Copied: video_16.mov_6.786000.jpg to test/Frames
# Copied: video_16.mov_7.142667.jpg to test/Frames
# Copied: video_16.mov_7.526000.jpg to test/Frames
# Copied: video_16.mov_8.169333.jpg to test/Frames
# Copied: video_16.mov_8.458000.jpg to test/Frames
# Copied: video_16.mov_8.675333.jpg to test/Frames
# Copied: video_16.mov_8.731000.jpg to test/Frames
# Copied: video_16.mov_8.920333.jpg to test/Frames
# Copied: video_16.mov_9.016000.jpg to test/Frames
# Copied: video_16.mov_9.306000.jpg to test/Frames
# Copied: video_16.mov_9.481000.jpg to test/Frames
# Copied: video_16.mov_9.484333.jpg to test/Frames
# Copied: video_16.mov_9.937000.jpg to test/Frames
# Copied: video_16.mov_9.972000.jpg to test/Frames
# Copied: video_11.mov_0.059667.png to test/Frames
# Copied: video_11.mov_0.317000.png to test/Frames
# Copied: video_11.mov_0.376000.png to test/Frames
# Copied: video_11.mov_1.829667.png to test/Frames
# Copied: video_11.mov_1.834000.png to test/Frames
# Copied: video_11.mov_1.867000.png to test/Frames
# Copied: video_11.mov_1.908667.png to test/Frames
# Copied: video_11.mov_10.018333.png to test/Frames
# Copied: video_11.mov_10.025000.png to test/Frames
# Copied: video_11.mov_10.061667.png to test/Frames
# Copied: video_11.mov_10.069000.png to test/Frames
# Copied: video_11.mov_10.184000.png to test/Frames
# Copied: video_11.mov_10.219000.png to test/Frames
# Copied: video_11.mov_10.280000.png to test/Frames
# Copied: video_11.mov_10.286667.png to test/Frames
# Copied: video_11.mov_10.320333.png to test/Frames
# Copied: video_11.mov_10.381667.png to test/Frames
# Copied: video_11.mov_10.396667.png to test/Frames
# Copied: video_11.mov_10.461667.png to test/Frames
# Copied: video_11.mov_10.535000.png to test/Frames
# Copied: video_11.mov_10.540333.png to test/Frames
# Copied: video_11.mov_10.634000.png to test/Frames
# Copied: video_11.mov_10.752667.png to test/Frames
# Copied: video_11.mov_10.841667.png to test/Frames
# Copied: video_11.mov_10.881333.png to test/Frames
# Copied: video_11.mov_2.051667.png to test/Frames
# Copied: video_20.mov_0.094667.png to test/Frames
# Copied: video_20.mov_0.102000.png to test/Frames
# Copied: video_20.mov_0.777667.png to test/Frames
# Copied: video_20.mov_1.388667.png to test/Frames
# Copied: video_20.mov_1.957333.png to test/Frames
# Copied: video_20.mov_1.986000.png to test/Frames
# Copied: video_20.mov_10.580667.png to test/Frames
# Copied: video_20.mov_2.130667.png to test/Frames
# Copied: video_20.mov_2.165333.png to test/Frames
# Copied: video_20.mov_2.274667.png to test/Frames
# Copied: video_20.mov_3.395333.png to test/Frames
# Copied: video_20.mov_4.411667.png to test/Frames
# Copied: video_20.mov_4.449333.png to test/Frames
# Copied: video_20.mov_4.686000.png to test/Frames
# Copied: video_20.mov_4.963667.png to test/Frames
# Copied: video_20.mov_5.076333.png to test/Frames
# Copied: video_20.mov_5.145000.png to test/Frames
# Copied: video_20.mov_5.924333.png to test/Frames
# Copied: video_20.mov_6.513000.png to test/Frames
# Copied: video_20.mov_6.719000.png to test/Frames
# Copied: video_20.mov_7.013000.png to test/Frames
# Copied: video_20.mov_7.663333.png to test/Frames
# Copied: video_20.mov_8.569333.png to test/Frames
# Copied: video_20.mov_8.886667.png to test/Frames
# Copied: video_20.mov_9.221333.png to test/Frames
# Copied: video_20.mov_9.577667.png to test/Frames
# Copied: video_20.mov_9.614667.png to test/Frames
# Copied: video_20.mov_9.846000.png to test/Frames
# Images have been split into train/val/test Frames based on mask splits.

# %% [markdown]
# ## Converting np.false and np.true in masks into (0) and (255)

# %%
# Function to convert masks to {0, 255} format
def convert_masks_to_uint8(mask_folder):
    for filename in os.listdir(mask_folder):
        mask_path = os.path.join(mask_folder, filename)
        if mask_path.endswith(('.png', '.jpg', '.jpeg')):  # Process only image files
            try:
                # Load mask
                mask_array = np.array(Image.open(mask_path))

                # Check if mask is boolean and convert to {0, 255}
                if mask_array.dtype == np.bool_ or np.array_equal(np.unique(mask_array), [False, True]):
                    mask_array = (mask_array * 255).astype(np.uint8)

                # Ensure masks already in uint8 are untouched
                elif mask_array.dtype == np.uint8 and set(np.unique(mask_array)) <= {0, 255}:
                    pass  # Mask is already in the correct format
                else:
                    # Normalize other values to {0, 255}
                    mask_array = ((mask_array > 0) * 255).astype(np.uint8)

                # Save the updated mask
                Image.fromarray(mask_array).save(mask_path)
                print(f"Converted: {mask_path}")

            except Exception as e:
                print(f"Error processing {mask_path}: {e}")

# Process masks in train, val, and test folders
for split in mask_splits:
    split_dir = os.path.join(after_base_dir, split, "Masks")
    if os.path.exists(split_dir):
        print(f"Processing {split} Masks...")
        for root, dirs, files in os.walk(split_dir):
            for dir_name in dirs:
                mask_folder = os.path.join(root, dir_name)
                convert_masks_to_uint8(mask_folder)
    else:
        print(f"'{split}' folder not found in the dataset.")

print("All masks have been standardized to {0, 255} in train, val, and test folders.")
# Out:
# Processing train Masks...
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.024000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.320667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.466000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.483667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.508000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.697333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.740333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.848667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_0.877667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_1.020333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_1.198333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_1.300000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_1.535000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_1.759333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_1.788667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.017000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.127667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.177000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.220333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.310667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.374333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.407000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_1.mov_10.418667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_0.998333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_10.500333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_2.804667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_3.051333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_3.728333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_4.288000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_4.713000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_4.746333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_4.886667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_5.412667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_6.210000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_6.253333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_6.493333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_7.331333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_7.343000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_12.mov_7.496000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_0.094667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_0.102000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_0.777667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_1.388667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_1.957333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_1.986000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_10.580667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_2.130667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_2.165333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_2.274667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_3.395333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_4.411667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_4.449333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_4.686000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_5.076333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_5.924333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_6.513000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_6.719000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_7.013000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_7.663333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_8.569333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_8.886667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_9.221333.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_9.577667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_9.614667.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_20.mov_9.846000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_0.085410.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_0.942508.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_1.464974.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_1.904699.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_10.141715.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_10.187089.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_10.192093.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_10.373922.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_10.418295.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_2.010794.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_2.486218.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_2.809507.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_2.905259.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_3.457084.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_25.mp4_8.031833.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_27.mov_0.434000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_27.mov_4.984400.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video_29.mp4_7.948000.png
# Converted: ..\Datasets_AfterPreprocessing\UD Ureter-Uterine Artery-Nerve Dataset\train\Masks\artery\video
            if match:
                # Extract video number, main timestamp, and fractional timestamp
                video_number = match.group(1)
                main_timestamp = match.group(2)
                fractional_timestamp = match.group(3)

                # Construct the new name as "##_#_######.png"
                new_name = f"{video_number}_{main_timestamp}_{fractional_timestamp}.png"
                old_path = os.path.join(root, file_name)
                new_path = os.path.join(root, new_name)

                # Rename the file
                os.rename(old_path, new_path)
                print(f'Renamed: "{old_path}" to "{new_path}"')

# Iterate over each split and sub-folder to process the renaming
for split in mask_splits:
    for sub_folder in sub_folders:
        images_dir = os.path.join(after_base_dir, split, sub_folder)
        if os.path.exists(images_dir):
            rename_files_detailed_pattern(images_dir)
        else:
            print(f"Folder not found: {images_dir}")

print("Renaming completed with detailed pattern.")
# Out:
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.024000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_024000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.320667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_320667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.466000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_466000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.483667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_483667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.508000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_508000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.697333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_697333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.740333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_740333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.848667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_848667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_0.877667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_0_877667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_1.020333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_1_020333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_1.198333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_1_198333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_1.300000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_1_300000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_1.535000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_1_535000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_1.759333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_1_759333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_1.788667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_1_788667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.017000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_017000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.127667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_127667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.177000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_177000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.220333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_220333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.310667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_310667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.374333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_374333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.407000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_407000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_1.mov_10.418667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\1_10_418667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_0.998333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_0_998333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_1.430667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_1_430667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_10.500333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_10_500333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_2.027667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_2_027667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_2.804667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_2_804667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_3.051333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_3_051333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_3.108667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_3_108667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_3.728333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_3_728333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_4.081000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_4_081000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_4.088333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_4_088333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_4.288000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_4_288000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_4.713000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_4_713000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_4.746333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_4_746333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_4.886667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_4_886667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_5.412667.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_5_412667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_5.813000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_5_813000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_6.210000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_6_210000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_6.253333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_6_253333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_6.493333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_6_493333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_7.331333.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_7_331333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_7.343000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_7_343000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_12.mov_7.496000.png" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\12_7_496000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_1.035667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_1_035667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_1.041000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_1_041000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_1.355333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_1_355333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_1.513667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_1_513667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_1.682000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_1_682000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_1.825667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_1_825667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_1.992000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_1_992000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_10.130000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_10_130000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_10.212333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_10_212333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_10.217000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_10_217000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_10.234667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_10_234667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_10.295667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_10_295667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_10.355667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_10_355667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_2.952667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_2_952667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_2.972000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_2_972000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_3.380667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_3_380667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_4.067333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_4_067333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_4.183000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_4_183000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_4.499333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_4_499333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_4.677000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_4_677000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_4.749000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_4_749000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_5.178333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_5_178333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_5.220000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_5_220000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_7.528667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_7_528667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_7.560000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_7_560000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_7.925333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_7_925333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.042667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_042667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.081333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_081333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.159667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_159667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.450667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_450667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.476000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_476000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.537667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_537667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.695667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_695667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_8.779333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_8_779333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_9.667333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_9_667333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_9.747667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_9_747667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_9.768667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_9_768667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_14.mov_9.961667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\14_9_961667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_0.130000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_0_130000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_0.827667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_0_827667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_1.299667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_1_299667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_1.417000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_1_417000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_2.145667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_2_145667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_2.444000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_2_444000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_2.658000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_2_658000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_2.740333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_2_740333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_2.775667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_2_775667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_2.785333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_2_785333.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_2.811000.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_2_811000.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_3.676667.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15_3_676667.png"
# Renamed: "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\video_15.mov_3.717333.jpg" to "..\Datasets\UD Ureter-Uterine Artery-Nerve Dataset\train\Frames\15