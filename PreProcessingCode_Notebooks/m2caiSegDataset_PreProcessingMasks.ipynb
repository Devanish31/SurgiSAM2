# %% [markdown]
# ## m2caiSeg Dataset Preprocessing

# %% [markdown]
# #### (For relative paths) This notebook is located in a folder, which is in the same folder as the original dataset being preprocessed
#
# Download dataset from -- "https://www.kaggle.com/datasets/salmanmaq/m2caiseg"

# %% [markdown]
# ## All unique colors in each of the ground truth masks

# %%
import os
import cv2
import shutil
import random
import numpy as np
from PIL import Image
from collections import defaultdict

# Define relative paths to the base folder
base_before_folder = os.path.join("..", "Datasets_BeforePreprocessing", "m2caiSeg")
base_after_folder = os.path.join("..", "Datasets_AfterPreprocessing", "m2caiSeg")

# Define paths for the groundtruth folders in each dataset split
groundtruth_folders = {
    "trainval": os.path.join(base_before_folder, "trainval", "groundtruth"),
    "train": os.path.join(base_before_folder, "train", "groundtruth"),
    "test": os.path.join(base_before_folder, "test", "groundtruth")
}

# Function to get unique colors in an image
def get_unique_colors(image_path):
    image = Image.open(image_path).convert('RGB')  # Open the image and ensure it's in RGB mode
    unique_colors = image.getcolors(maxcolors=1000000)  # Set a high limit to get all unique colors
    return [color[1] for color in unique_colors]  # Extract only the color values

# Iterate over each groundtruth folder and each image within
for dataset_split, folder_path in groundtruth_folders.items():
    print(f"Processing {dataset_split} groundtruth images...")
    for filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, filename)
        if os.path.isfile(image_path):
            unique_colors = get_unique_colors(image_path)
            print(f"Unique colors in '{dataset_split}/{filename}': {unique_colors}")
# Out:
# Processing trainval groundtruth images...
# Unique colors in 'trainval/00_gt.png': [(85, 170, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/015975_gt.png': [(85, 170, 255), (85, 255, 170), (0, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/030750_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/03425_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/04175_gt.png': [(170, 170, 255), (85, 170, 255), (85, 85, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/05150_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (255, 0, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (0, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (0, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (0, 0, 0)]
# Unique colors in 'trainval/06625_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/0_gt.png': [(255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (170, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/10075_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/10275_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/1125_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (85, 85, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/11400_gt.png': [(85, 170, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/1225_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/12550_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/13025_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/13700_gt.png': [(85, 170, 255), (0, 85, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (170, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (170, 0, 85), (170, 255, 0), (85, 255, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/14000_gt.png': [(85, 170, 255), (0, 85, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/14500_gt.png': [(85, 170, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/1475_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/14825_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/15250_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/15975_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/16475_gt.png': [(85, 170, 255), (0, 85, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/1700_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (255, 0, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (255, 0, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (170, 85, 0), (0, 85, 0), (255, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/17700_gt.png': [(85, 170, 255), (170, 255, 170), (85, 255, 170), (170, 170, 170), (85, 170, 170), (170, 85, 170), (170, 255, 85), (85, 255, 85), (170, 170, 85), (85, 170, 85), (170, 85, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/18925_gt.png': [(85, 170, 255), (0, 170, 255), (85, 85, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 0, 255), (170, 255, 170), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (85, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/1950_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (255, 0, 170), (170, 0, 170), (85, 0, 170), (0, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (85, 0, 85), (0, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/20400_gt.png': [(170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/20650_gt.png': [(170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/20900_gt.png': [(170, 170, 255), (85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/21150_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/21400_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (85, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/21625_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/21875_gt.png': [(170, 170, 255), (85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (255, 0, 85), (170, 0, 85), (85, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/2200_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/22125_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/22375_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/225_gt.png': [(85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (0, 0, 170), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/22625_gt.png': [(85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/2275_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (0, 0, 170), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/22875_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/23100_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/23350_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/23600_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/23850_gt.png': [(85, 170, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 85, 170), (170, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/2450_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/25025_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25050_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/25075_gt.png': [(85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25100_gt.png': [(85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/25125_gt.png': [(85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/25150_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25175_gt.png': [(85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25200_gt.png': [(85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25225_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25250_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (0, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25275_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25300_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25325_gt.png': [(85, 170, 255), (0, 85, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25350_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25375_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25400_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25425_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/25450_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25475_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25500_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25525_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25550_gt.png': [(85, 170, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25575_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25600_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25625_gt.png': [(85, 170, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25650_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25675_gt.png': [(85, 170, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25700_gt.png': [(170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25725_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25775_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25800_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25825_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25850_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25875_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25900_gt.png': [(85, 170, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25925_gt.png': [(85, 170, 255), (0, 85, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/25950_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/25975_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/26000_gt.png': [(85, 170, 255), (85, 255, 170), (0, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26025_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/26050_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (170, 85, 85), (85, 85, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/26075_gt.png': [(85, 170, 255), (85, 255, 170), (0, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26100_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26125_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26150_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26175_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26200_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26225_gt.png': [(85, 170, 255), (0, 85, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26250_gt.png': [(85, 170, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26275_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26300_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26325_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26350_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26375_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 0, 0)]
# Unique colors in 'trainval/26400_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26425_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26450_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26475_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (0, 0, 0)]
# Unique colors in 'trainval/26500_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26525_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26550_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26575_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26600_gt.png': [(85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26625_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26650_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26675_gt.png': [(85, 170, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'trainval/26700_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'trainval/26725_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (0, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# ...
# Unique colors in 'test/22125_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/225_gt.png': [(85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (0, 0, 170), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/22625_gt.png': [(85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/2275_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (0, 0, 170), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/22875_gt.png': [(85, 170, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (170, 85, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/23100_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (255, 0, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'test/23350_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (85, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/23600_gt.png': [(85, 170, 255), (85, 85, 255), (0, 85, 255), (170, 0, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (0, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/2450_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/30000_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/30250_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/30750_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/31225_gt.png': [(85, 170, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/31475_gt.png': [(85, 170, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/3175_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/32950_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 170, 85), (0, 170, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/33450_gt.png': [(85, 170, 255), (0, 170, 255), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 170, 85), (0, 170, 85), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/33925_gt.png': [(85, 170, 255), (85, 170, 170), (0, 170, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (0, 0, 170), (85, 170, 85), (0, 170, 85), (85, 85, 85), (0, 85, 85), (85, 0, 85), (85, 170, 0), (0, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/34175_gt.png': [(85, 170, 255), (85, 85, 255), (85, 0, 255), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (85, 170, 85), (0, 170, 85), (85, 85, 85), (0, 85, 85), (85, 0, 85), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/3425_gt.png': [(85, 170, 255), (0, 85, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/34675_gt.png': [(85, 170, 255), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (85, 0, 85), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/3675_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/3925_gt.png': [(85, 170, 255), (0, 170, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (0, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/4175_gt.png': [(170, 170, 255), (85, 170, 255), (170, 85, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/44275_gt.png': [(0, 85, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (170, 255, 0), (85, 255, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/44750_gt.png': [(85, 170, 255), (85, 85, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (85, 170, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (0, 85, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/45250_gt.png': [(85, 170, 255), (85, 85, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (85, 85, 170), (85, 0, 170), (85, 255, 85), (85, 170, 85), (85, 85, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/4550_gt.png': [(85, 170, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (0, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/46000_gt.png': [(255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (170, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (170, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/46475_gt.png': [(85, 255, 0), (85, 170, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/4650_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/46975_gt.png': [(255, 0, 255), (170, 0, 255), (170, 0, 170), (85, 0, 170), (170, 0, 85), (85, 0, 85), (0, 0, 0)]
# Unique colors in 'test/47950_gt.png': [(170, 170, 85), (170, 85, 85), (170, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (255, 85, 0), (170, 85, 0), (255, 0, 0), (170, 0, 0), (0, 0, 0)]
# Unique colors in 'test/48450_gt.png': [(85, 255, 170), (0, 255, 170), (85, 170, 170), (0, 170, 170), (85, 255, 85), (85, 170, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/48700_gt.png': [(85, 170, 255), (85, 85, 255), (85, 0, 255), (85, 255, 170), (0, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (0, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (170, 85, 85), (85, 85, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/49200_gt.png': [(170, 0, 85), (0, 0, 0)]
# Unique colors in 'test/5150_gt.png': [(85, 170, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/5650_gt.png': [(85, 170, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (85, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (85, 85, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]
# Unique colors in 'test/5700_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/6150_gt.png': [(85, 170, 255), (0, 85, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/6375_gt.png': [(85, 170, 255), (255, 0, 255), (170, 0, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (170, 85, 170), (0, 85, 170), (255, 0, 170), (170, 0, 170), (85, 0, 170), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (170, 85, 85), (0, 85, 85), (170, 0, 85), (85, 0, 85), (170, 255, 0), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/6850_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (0, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/725_gt.png': [(85, 170, 255), (85, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/7375_gt.png': [(85, 170, 255), (0, 85, 255), (85, 0, 255), (170, 255, 170), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (170, 255, 85), (85, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (0, 85, 85), (85, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/7850_gt.png': [(85, 170, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (85, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/7975_gt.png': [(85, 170, 255), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (0, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 0, 0)]
# Unique colors in 'test/8100_gt.png': [(85, 170, 255), (85, 0, 255), (170, 255, 170), (85, 255, 170), (170, 170, 170), (85, 170, 170), (0, 170, 170), (85, 85, 170), (0, 85, 170), (85, 0, 170), (85, 255, 85), (0, 255, 85), (170, 170, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (0, 85, 85), (85, 0, 85), (255, 255, 0), (170, 255, 0), (85, 255, 0), (255, 170, 0), (170, 170, 0), (85, 170, 0), (0, 170, 0), (255, 85, 0), (170, 85, 0), (85, 85, 0), (0, 85, 0), (255, 0, 0), (170, 0, 0), (85, 0, 0), (0, 0, 0)]
# Unique colors in 'test/975_gt.png': [(85, 170, 255), (85, 255, 170), (0, 255, 170), (85, 170, 170), (0, 170, 170), (0, 85, 170), (85, 255, 85), (85, 170, 85), (0, 170, 85), (85, 85, 85), (85, 255, 0), (85, 170, 0), (0, 170, 0), (85, 85, 0), (0, 85, 0), (0, 0, 0)]

# %% [markdown]
# ## Number of unique colors in each of the masks

# %%
# Function to get the count of unique colors in an image
def count_unique_colors(image_path):
    image = Image.open(image_path).convert('RGB')  # Open the image and ensure it's in RGB mode
    unique_colors = image.getcolors(maxcolors=1000000)  # Set a high limit to get all unique colors
    return len(unique_colors) if unique_colors else 0  # Return the count of unique colors

# Iterate over each groundtruth folder and each image within to count unique colors
for dataset_split, folder_path in groundtruth_folders.items():
    print(f"Processing {dataset_split} groundtruth images...")
    for filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, filename)
        if os.path.isfile(image_path):
            unique_color_count = count_unique_colors(image_path)
            print(f"Number of unique colors in '{dataset_split}/{filename}': {unique_color_count}")
# Out:
# Processing trainval groundtruth images...
# Number of unique colors in 'trainval/00_gt.png': 19
# Number of unique colors in 'trainval/015975_gt.png': 16
# Number of unique colors in 'trainval/030750_gt.png': 26
# Number of unique colors in 'trainval/03425_gt.png': 16
# Number of unique colors in 'trainval/04175_gt.png': 28
# Number of unique colors in 'trainval/05150_gt.png': 33
# Number of unique colors in 'trainval/06625_gt.png': 16
# Number of unique colors in 'trainval/0_gt.png': 22
# Number of unique colors in 'trainval/10075_gt.png': 33
# Number of unique colors in 'trainval/10275_gt.png': 17
# Number of unique colors in 'trainval/1125_gt.png': 17
# Number of unique colors in 'trainval/11400_gt.png': 17
# Number of unique colors in 'trainval/1225_gt.png': 16
# Number of unique colors in 'trainval/12550_gt.png': 15
# Number of unique colors in 'trainval/13025_gt.png': 15
# Number of unique colors in 'trainval/13700_gt.png': 27
# Number of unique colors in 'trainval/14000_gt.png': 17
# Number of unique colors in 'trainval/14500_gt.png': 28
# Number of unique colors in 'trainval/1475_gt.png': 28
# Number of unique colors in 'trainval/14825_gt.png': 15
# Number of unique colors in 'trainval/15250_gt.png': 15
# Number of unique colors in 'trainval/15975_gt.png': 16
# Number of unique colors in 'trainval/16475_gt.png': 17
# Number of unique colors in 'trainval/1700_gt.png': 33
# Number of unique colors in 'trainval/17700_gt.png': 25
# Number of unique colors in 'trainval/18925_gt.png': 44
# Number of unique colors in 'trainval/1950_gt.png': 33
# Number of unique colors in 'trainval/20400_gt.png': 33
# Number of unique colors in 'trainval/20650_gt.png': 33
# Number of unique colors in 'trainval/20900_gt.png': 34
# Number of unique colors in 'trainval/21150_gt.png': 36
# Number of unique colors in 'trainval/21400_gt.png': 37
# Number of unique colors in 'trainval/21625_gt.png': 34
# Number of unique colors in 'trainval/21875_gt.png': 37
# Number of unique colors in 'trainval/2200_gt.png': 27
# Number of unique colors in 'trainval/22125_gt.png': 25
# Number of unique colors in 'trainval/22375_gt.png': 24
# Number of unique colors in 'trainval/225_gt.png': 14
# Number of unique colors in 'trainval/22625_gt.png': 19
# Number of unique colors in 'trainval/2275_gt.png': 26
# Number of unique colors in 'trainval/22875_gt.png': 21
# Number of unique colors in 'trainval/23100_gt.png': 39
# Number of unique colors in 'trainval/23350_gt.png': 32
# Number of unique colors in 'trainval/23600_gt.png': 30
# Number of unique colors in 'trainval/23850_gt.png': 24
# Number of unique colors in 'trainval/2450_gt.png': 27
# Number of unique colors in 'trainval/25025_gt.png': 28
# Number of unique colors in 'trainval/25050_gt.png': 27
# Number of unique colors in 'trainval/25075_gt.png': 27
# Number of unique colors in 'trainval/25100_gt.png': 27
# Number of unique colors in 'trainval/25125_gt.png': 30
# Number of unique colors in 'trainval/25150_gt.png': 27
# Number of unique colors in 'trainval/25175_gt.png': 29
# Number of unique colors in 'trainval/25200_gt.png': 27
# Number of unique colors in 'trainval/25225_gt.png': 27
# Number of unique colors in 'trainval/25250_gt.png': 30
# Number of unique colors in 'trainval/25275_gt.png': 25
# Number of unique colors in 'trainval/25300_gt.png': 24
# Number of unique colors in 'trainval/25325_gt.png': 25
# Number of unique colors in 'trainval/25350_gt.png': 26
# Number of unique colors in 'trainval/25375_gt.png': 24
# Number of unique colors in 'trainval/25400_gt.png': 26
# Number of unique colors in 'trainval/25425_gt.png': 27
# Number of unique colors in 'trainval/25450_gt.png': 24
# Number of unique colors in 'trainval/25475_gt.png': 24
# Number of unique colors in 'trainval/25500_gt.png': 24
# Number of unique colors in 'trainval/25525_gt.png': 25
# Number of unique colors in 'trainval/25550_gt.png': 29
# Number of unique colors in 'trainval/25575_gt.png': 25
# Number of unique colors in 'trainval/25600_gt.png': 26
# Number of unique colors in 'trainval/25625_gt.png': 27
# Number of unique colors in 'trainval/25650_gt.png': 26
# Number of unique colors in 'trainval/25675_gt.png': 27
# Number of unique colors in 'trainval/25700_gt.png': 27
# Number of unique colors in 'trainval/25725_gt.png': 26
# Number of unique colors in 'trainval/25775_gt.png': 26
# Number of unique colors in 'trainval/25800_gt.png': 23
# Number of unique colors in 'trainval/25825_gt.png': 23
# Number of unique colors in 'trainval/25850_gt.png': 20
# Number of unique colors in 'trainval/25875_gt.png': 25
# Number of unique colors in 'trainval/25900_gt.png': 27
# Number of unique colors in 'trainval/25925_gt.png': 25
# Number of unique colors in 'trainval/25950_gt.png': 21
# Number of unique colors in 'trainval/25975_gt.png': 24
# Number of unique colors in 'trainval/26000_gt.png': 15
# Number of unique colors in 'trainval/26025_gt.png': 24
# Number of unique colors in 'trainval/26050_gt.png': 23
# Number of unique colors in 'trainval/26075_gt.png': 16
# Number of unique colors in 'trainval/26100_gt.png': 25
# Number of unique colors in 'trainval/26125_gt.png': 26
# Number of unique colors in 'trainval/26150_gt.png': 29
# Number of unique colors in 'trainval/26175_gt.png': 29
# Number of unique colors in 'trainval/26200_gt.png': 23
# Number of unique colors in 'trainval/26225_gt.png': 30
# Number of unique colors in 'trainval/26250_gt.png': 27
# Number of unique colors in 'trainval/26275_gt.png': 29
# Number of unique colors in 'trainval/26300_gt.png': 29
# Number of unique colors in 'trainval/26325_gt.png': 27
# Number of unique colors in 'trainval/26350_gt.png': 29
# Number of unique colors in 'trainval/26375_gt.png': 28
# Number of unique colors in 'trainval/26400_gt.png': 27
# Number of unique colors in 'trainval/26425_gt.png': 27
# Number of unique colors in 'trainval/26450_gt.png': 27
# Number of unique colors in 'trainval/26475_gt.png': 27
# Number of unique colors in 'trainval/26500_gt.png': 26
# Number of unique colors in 'trainval/26525_gt.png': 30
# Number of unique colors in 'trainval/26550_gt.png': 30
# Number of unique colors in 'trainval/26575_gt.png': 31
# Number of unique colors in 'trainval/26600_gt.png': 31
# Number of unique colors in 'trainval/26625_gt.png': 32
# Number of unique colors in 'trainval/26650_gt.png': 30
# Number of unique colors in 'trainval/26675_gt.png': 29
# Number of unique colors in 'trainval/26700_gt.png': 31
# Number of unique colors in 'trainval/26725_gt.png': 33
# Number of unique colors in 'trainval/26750_gt.png': 27
# Number of unique colors in 'trainval/26775_gt.png': 32
# Number of unique colors in 'trainval/26800_gt.png': 28
# Number of unique colors in 'trainval/26825_gt.png': 29
# Number of unique colors in 'trainval/26925_gt.png': 28
# Number of unique colors in 'trainval/26950_gt.png': 29
# Number of unique colors in 'trainval/26975_gt.png': 31
# Number of unique colors in 'trainval/27000_gt.png': 29
# Number of unique colors in 'trainval/2700_gt.png': 28
# Number of unique colors in 'trainval/27025_gt.png': 30
# Number of unique colors in 'trainval/27050_gt.png': 29
# Number of unique colors in 'trainval/27075_gt.png': 28
# Number of unique colors in 'trainval/27100_gt.png': 30
# Number of unique colors in 'trainval/27125_gt.png': 31
# Number of unique colors in 'trainval/27150_gt.png': 29
# Number of unique colors in 'trainval/27175_gt.png': 30
# Number of unique colors in 'trainval/27200_gt.png': 28
# Number of unique colors in 'trainval/27225_gt.png': 31
# Number of unique colors in 'trainval/27250_gt.png': 30
# Number of unique colors in 'trainval/27275_gt.png': 29
# Number of unique colors in 'trainval/27300_gt.png': 30
# Number of unique colors in 'trainval/27325_gt.png': 31
# Number of unique colors in 'trainval/27575_gt.png': 29
# Number of unique colors in 'trainval/27600_gt.png': 27
# Number of unique colors in 'trainval/27625_gt.png': 28
# Number of unique colors in 'trainval/27650_gt.png': 27
# Number of unique colors in 'trainval/27675_gt.png': 26
# Number of unique colors in 'trainval/27700_gt.png': 28
# Number of unique colors in 'trainval/28000_gt.png': 28
# Number of unique colors in 'trainval/28025_gt.png': 28
# Number of unique colors in 'trainval/28050_gt.png': 30
# Number of unique colors in 'trainval/28075_gt.png': 28
# Number of unique colors in 'trainval/28100_gt.png': 31
# Number of unique colors in 'trainval/28125_gt.png': 29
# Number of unique colors in 'trainval/28150_gt.png': 29
# Number of unique colors in 'trainval/28175_gt.png': 28
# Number of unique colors in 'trainval/28200_gt.png': 31
# Number of unique colors in 'trainval/2950_gt.png': 25
# Number of unique colors in 'trainval/30000_gt.png': 11
# Number of unique colors in 'trainval/30250_gt.png': 11
# Number of unique colors in 'trainval/30500_gt.png': 13
# Number of unique colors in 'trainval/30600_gt.png': 26
# Number of unique colors in 'trainval/30625_gt.png': 29
# Number of unique colors in 'trainval/30650_gt.png': 25
# Number of unique colors in 'trainval/30675_gt.png': 25
# Number of unique colors in 'trainval/30700_gt.png': 25
# Number of unique colors in 'trainval/30725_gt.png': 15
# Number of unique colors in 'trainval/30750_gt.png': 13
# Number of unique colors in 'trainval/30775_gt.png': 26
# Number of unique colors in 'trainval/30800_gt.png': 16
# Number of unique colors in 'trainval/30825_gt.png': 14
# Number of unique colors in 'trainval/30850_gt.png': 15
# Number of unique colors in 'trainval/30875_gt.png': 23
# Number of unique colors in 'trainval/30900_gt.png': 23
# Number of unique colors in 'trainval/30975_gt.png': 13
# Number of unique colors in 'trainval/31225_gt.png': 13
# Number of unique colors in 'trainval/31475_gt.png': 16
# Number of unique colors in 'trainval/31725_gt.png': 14
# Number of unique colors in 'trainval/3175_gt.png': 25
# Number of unique colors in 'trainval/31975_gt.png': 15
# Number of unique colors in 'trainval/32225_gt.png': 15
# Number of unique colors in 'trainval/32450_gt.png': 15
# Number of unique colors in 'trainval/32700_gt.png': 17
# Number of unique colors in 'trainval/32950_gt.png': 13
# Number of unique colors in 'trainval/33200_gt.png': 14
# Number of unique colors in 'trainval/33450_gt.png': 11
# Number of unique colors in 'trainval/33700_gt.png': 11
# Number of unique colors in 'trainval/33925_gt.png': 17
# Number of unique colors in 'trainval/34175_gt.png': 20
# Number of unique colors in 'trainval/3425_gt.png': 17
# Number of unique colors in 'trainval/34425_gt.png': 17
# Number of unique colors in 'trainval/34675_gt.png': 16
# Number of unique colors in 'trainval/3675_gt.png': 16
# Number of unique colors in 'trainval/3925_gt.png': 24
# Number of unique colors in 'trainval/4050_gt.png': 27
# Number of unique colors in 'trainval/4075_gt.png': 27
# Number of unique colors in 'trainval/4100_gt.png': 30
# Number of unique colors in 'trainval/4125_gt.png': 28
# Number of unique colors in 'trainval/4150_gt.png': 28
# Number of unique colors in 'trainval/4175_gt.png': 30
# Number of unique colors in 'trainval/44025_gt.png': 15
# Number of unique colors in 'trainval/4425_gt.png': 31
# Number of unique colors in 'trainval/44275_gt.png': 26
# Number of unique colors in 'trainval/44525_gt.png': 27
# Number of unique colors in 'trainval/44750_gt.png': 22
# Number of unique colors in 'trainval/45000_gt.png': 23
# Number of unique colors in 'trainval/45250_gt.png': 18
# Number of unique colors in 'trainval/45500_gt.png': 22
# Number of unique colors in 'trainval/4550_gt.png': 29
# Number of unique colors in 'trainval/45750_gt.png': 14
# Number of unique colors in 'trainval/46000_gt.png': 19
# Number of unique colors in 'trainval/46225_gt.png': 18
# Number of unique colors in 'trainval/46475_gt.png': 4
# Number of unique colors in 'trainval/4650_gt.png': 27
# Number of unique colors in 'trainval/46725_gt.png': 5
# Number of unique colors in 'trainval/46975_gt.png': 7
# Number of unique colors in 'trainval/47225_gt.png': 13
# Number of unique colors in 'trainval/47475_gt.png': 9
# Number of unique colors in 'trainval/475_gt.png': 30
# Number of unique colors in 'trainval/47700_gt.png': 9
# Number of unique colors in 'trainval/47950_gt.png': 14
# Number of unique colors in 'trainval/48200_gt.png': 24
# Number of unique colors in 'trainval/48450_gt.png': 10
# Number of unique colors in 'trainval/48700_gt.png': 24
# Number of unique colors in 'trainval/48950_gt.png': 12
# Number of unique colors in 'trainval/4900_gt.png': 27
# Number of unique colors in 'trainval/49200_gt.png': 2
# Number of unique colors in 'trainval/4950_gt.png': 35
# Number of unique colors in 'trainval/4975_gt.png': 30
# Number of unique colors in 'trainval/5000_gt.png': 31
# Number of unique colors in 'trainval/5025_gt.png': 31
# Number of unique colors in 'trainval/5050_gt.png': 34
# Number of unique colors in 'trainval/5075_gt.png': 32
# Number of unique colors in 'trainval/5100_gt.png': 32
# Number of unique colors in 'trainval/5125_gt.png': 31
# Number of unique colors in 'trainval/5150_gt.png': 28
# Number of unique colors in 'trainval/5175_gt.png': 33
# Number of unique colors in 'trainval/53100_gt.png': 17
# Number of unique colors in 'trainval/53125_gt.png': 12
# Number of unique colors in 'trainval/53150_gt.png': 13
# Number of unique colors in 'trainval/53175_gt.png': 13
# Number of unique colors in 'trainval/53200_gt.png': 15
# Number of unique colors in 'trainval/53225_gt.png': 12
# Number of unique colors in 'trainval/53275_gt.png': 15
# Number of unique colors in 'trainval/53300_gt.png': 15
# Number of unique colors in 'trainval/53325_gt.png': 15
# Number of unique colors in 'trainval/53875_gt.png': 29
# Number of unique colors in 'trainval/53900_gt.png': 29
# Number of unique colors in 'trainval/53925_gt.png': 30
# Number of unique colors in 'trainval/53950_gt.png': 32
# Number of unique colors in 'trainval/53975_gt.png': 32
# Number of unique colors in 'trainval/54000_gt.png': 33
# Number of unique colors in 'trainval/5400_gt.png': 26
# Number of unique colors in 'trainval/54025_gt.png': 32
# Number of unique colors in 'trainval/54050_gt.png': 34
# Number of unique colors in 'trainval/54075_gt.png': 33
# Number of unique colors in 'trainval/54100_gt.png': 34
# Number of unique colors in 'trainval/54125_gt.png': 33
# Number of unique colors in 'trainval/54150_gt.png': 33
# Number of unique colors in 'trainval/54175_gt.png': 31
# Number of unique colors in 'trainval/54225_gt.png': 35
# Number of unique colors in 'trainval/54250_gt.png': 32
# Number of unique colors in 'trainval/54275_gt.png': 34
# Number of unique colors in 'trainval/54300_gt.png': 33
# Number of unique colors in 'trainval/54325_gt.png': 34
# Number of unique colors in 'trainval/54350_gt.png': 35
# Number of unique colors in 'trainval/54375_gt.png': 36
# Number of unique colors in 'trainval/54400_gt.png': 35
# Number of unique colors in 'trainval/55000_gt.png': 27
# Number of unique colors in 'trainval/55025_gt.png': 29
# Number of unique colors in 'trainval/55050_gt.png': 29
# Number of unique colors in 'trainval/55075_gt.png': 28
# Number of unique colors in 'trainval/55100_gt.png': 28
# Number of unique colors in 'trainval/55125_gt.png': 27
# Number of unique colors in 'trainval/55150_gt.png': 31
# Number of unique colors in 'trainval/55175_gt.png': 29
# Number of unique colors in 'trainval/55200_gt.png': 32
# Number of unique colors in 'trainval/55225_gt.png': 28
# Number of unique colors in 'trainval/55250_gt.png': 30
# Number of unique colors in 'trainval/55275_gt.png': 26
# Number of unique colors in 'trainval/55300_gt.png': 26
# Number of unique colors in 'trainval/55875_gt.png': 22
# Number of unique colors in 'trainval/55900_gt.png': 21
# Number of unique colors in 'trainval/55925_gt.png': 22
# Number of unique colors in 'trainval/55950_gt.png': 25
# Number of unique colors in 'trainval/55975_gt.png': 26
# Number of unique colors in 'trainval/56000_gt.png': 26
# Number of unique colors in 'trainval/56025_gt.png': 26
# Number of unique colors in 'trainval/56050_gt.png': 25
# Number of unique colors in 'trainval/56075_gt.png': 25
# Number of unique colors in 'trainval/56100_gt.png': 26
# Number of unique colors in 'trainval/5650_gt.png': 27
# Number of unique colors in 'trainval/5700_gt.png': 27
# Number of unique colors in 'trainval/5900_gt.png': 26
# Number of unique colors in 'trainval/6150_gt.png': 28
# Number of unique colors in 'trainval/6375_gt.png': 27
# Number of unique colors in 'trainval/6550_gt.png': 16
# Number of unique colors in 'trainval/6575_gt.png': 16
# Number of unique colors in 'trainval/6600_gt.png': 16
# Number of unique colors in 'trainval/6625_gt.png': 29
# Number of unique colors in 'trainval/6650_gt.png': 18
# Number of unique colors in 'trainval/6675_gt.png': 16
# Number of unique colors in 'trainval/6850_gt.png': 15
# Number of unique colors in 'trainval/6875_gt.png': 25
# Number of unique colors in 'trainval/7125_gt.png': 31
# Number of unique colors in 'trainval/725_gt.png': 14
# Number of unique colors in 'trainval/7375_gt.png': 33
# Number of unique colors in 'trainval/7625_gt.png': 38
# Number of unique colors in 'trainval/7850_gt.png': 29
# Number of unique colors in 'trainval/7975_gt.png': 15
# Number of unique colors in 'trainval/8100_gt.png': 33
# Number of unique colors in 'trainval/9125_gt.png': 16
# Number of unique colors in 'trainval/975_gt.png': 16
# Processing train groundtruth images...
# Number of unique colors in 'train/015975_gt.png': 16
# Number of unique colors in 'train/03425_gt.png': 16
# Number of unique colors in 'train/06625_gt.png': 16
# Number of unique colors in 'train/0_gt.png': 22
# Number of unique colors in 'train/10275_gt.png': 17
# Number of unique colors in 'train/1125_gt.png': 17
# Number of unique colors in 'train/11400_gt.png': 17
# Number of unique colors in 'train/13025_gt.png': 15
# Number of unique colors in 'train/14825_gt.png': 15
# Number of unique colors in 'train/15975_gt.png': 16
# Number of unique colors in 'train/16475_gt.png': 17
# Number of unique colors in 'train/1700_gt.png': 33
# Number of unique colors in 'train/18925_gt.png': 44
# Number of unique colors in 'train/20650_gt.png': 33
# Number of unique colors in 'train/20900_gt.png': 34
# Number of unique colors in 'train/21625_gt.png': 34
# Number of unique colors in 'train/21875_gt.png': 37
# Number of unique colors in 'train/2200_gt.png': 27
# Number of unique colors in 'train/22375_gt.png': 24
# Number of unique colors in 'train/23850_gt.png': 24
# Number of unique colors in 'train/25025_gt.png': 28
# Number of unique colors in 'train/25050_gt.png': 27
# Number of unique colors in 'train/25075_gt.png': 27
# Number of unique colors in 'train/25100_gt.png': 27
# Number of unique colors in 'train/25125_gt.png': 30
# Number of unique colors in 'train/25150_gt.png': 27
# Number of unique colors in 'train/25175_gt.png': 29
# Number of unique colors in 'train/25200_gt.png': 27
# Number of unique colors in 'train/25225_gt.png': 27
# Number of unique colors in 'train/25250_gt.png': 30
# Number of unique colors in 'train/25275_gt.png': 25
# Number of unique colors in 'train/25300_gt.png': 24
# Number of unique colors in 'train/25325_gt.png': 25
# Number of unique colors in 'train/25350_gt.png': 26
# Number of unique colors in 'train/25375_gt.png': 24
# Number of unique colors in 'train/25400_gt.png': 26
# Number of unique colors in 'train/25425_gt.png': 27
# Number of unique colors in 'train/25450_gt.png': 24
# Number of unique colors in 'train/25475_gt.png': 24
# Number of unique colors in 'train/25500_gt.png': 24
# Number of unique colors in 'train/25525_gt.png': 25
# Number of unique colors in 'train/25550_gt.png': 29
# Number of unique colors in 'train/25575_gt.png': 25
# Number of unique colors in 'train/25600_gt.png': 26
# Number of unique colors in 'train/25625_gt.png': 27
# Number of unique colors in 'train/25650_gt.png': 26
# Number of unique colors in 'train/25675_gt.png': 27
# Number of unique colors in 'train/25700_gt.png': 27
# Number of unique colors in 'train/25725_gt.png': 26
# Number of unique colors in 'train/25775_gt.png': 26
# Number of unique colors in 'train/25800_gt.png': 23
# Number of unique colors in 'train/25825_gt.png': 23
# Number of unique colors in 'train/25850_gt.png': 20
# Number of unique colors in 'train/25875_gt.png': 25
# Number of unique colors in 'train/25900_gt.png': 27
# Number of unique colors in 'train/25925_gt.png': 25
# Number of unique colors in 'train/25950_gt.png': 21
# Number of unique colors in 'train/25975_gt.png': 24
# Number of unique colors in 'train/26000_gt.png': 15
# Number of unique colors in 'train/26025_gt.png': 24
# Number of unique colors in 'train/26050_gt.png': 23
# Number of unique colors in 'train/26075_gt.png': 16
# Number of unique colors in 'train/26100_gt.png': 25
# Number of unique colors in 'train/26125_gt.png': 26
# Number of unique colors in 'train/26150_gt.png': 29
# Number of unique colors in 'train/26175_gt.png': 29
# Number of unique colors in 'train/26200_gt.png': 23
# Number of unique colors in 'train/26225_gt.png': 30
# Number of unique colors in 'train/26250_gt.png': 27
# Number of unique colors in 'train/26275_gt.png': 29
# Number of unique colors in 'train/26300_gt.png': 29
# Number of unique colors in 'train/26325_gt.png': 27
# Number of unique colors in 'train/26350_gt.png': 29
# Number of unique colors in 'train/26375_gt.png': 28
# Number of unique colors in 'train/26400_gt.png': 27
# Number of unique colors in 'train/26425_gt.png': 27
# Number of unique colors in 'train/26450_gt.png': 27
# Number of unique colors in 'train/26475_gt.png': 27
# Number of unique colors in 'train/26500_gt.png': 26
# Number of unique colors in 'train/26525_gt.png': 30
# Number of unique colors in 'train/26550_gt.png': 30
# Number of unique colors in 'train/26575_gt.png': 31
# Number of unique colors in 'train/26600_gt.png': 31
# Number of unique colors in 'train/26625_gt.png': 32
# Number of unique colors in 'train/26650_gt.png': 30
# Number of unique colors in 'train/26675_gt.png': 29
# Number of unique colors in 'train/26700_gt.png': 31
# Number of unique colors in 'train/26725_gt.png': 33
# Number of unique colors in 'train/26750_gt.png': 27
# Number of unique colors in 'train/26775_gt.png': 32
# Number of unique colors in 'train/26800_gt.png': 28
# Number of unique colors in 'train/26825_gt.png': 29
# Number of unique colors in 'train/26925_gt.png': 28
# Number of unique colors in 'train/26950_gt.png': 29
# Number of unique colors in 'train/26975_gt.png': 31
# Number of unique colors in 'train/27000_gt.png': 29
# Number of unique colors in 'train/2700_gt.png': 28
# Number of unique colors in 'train/27025_gt.png': 30
# Number of unique colors in 'train/27050_gt.png': 29
# Number of unique colors in 'train/27075_gt.png': 28
# Number of unique colors in 'train/27100_gt.png': 30
# Number of unique colors in 'train/27125_gt.png': 31
# Number of unique colors in 'train/27150_gt.png': 29
# Number of unique colors in 'train/27175_gt.png': 30
# Number of unique colors in 'train/27200_gt.png': 28
# Number of unique colors in 'train/27225_gt.png': 31
# Number of unique colors in 'train/27250_gt.png': 30
# Number of unique colors in 'train/27275_gt.png': 29
# Number of unique colors in 'train/27300_gt.png': 30
# Number of unique colors in 'train/27325_gt.png': 31
# Number of unique colors in 'train/27575_gt.png': 29
# Number of unique colors in 'train/27600_gt.png': 27
# Number of unique colors in 'train/27625_gt.png': 28
# Number of unique colors in 'train/27650_gt.png': 27
# Number of unique colors in 'train/27675_gt.png': 26
# Number of unique colors in 'train/27700_gt.png': 28
# Number of unique colors in 'train/28000_gt.png': 28
# Number of unique colors in 'train/28025_gt.png': 28
# Number of unique colors in 'train/28050_gt.png': 30
# Number of unique colors in 'train/28075_gt.png': 28
# Number of unique colors in 'train/28100_gt.png': 31
# Number of unique colors in 'train/28125_gt.png': 29
# Number of unique colors in 'train/28150_gt.png': 29
# Number of unique colors in 'train/28175_gt.png': 28
# Number of unique colors in 'train/28200_gt.png': 31
# Number of unique colors in 'train/2950_gt.png': 25
# Number of unique colors in 'train/30500_gt.png': 13
# Number of unique colors in 'train/30600_gt.png': 26
# Number of unique colors in 'train/30625_gt.png': 29
# Number of unique colors in 'train/30650_gt.png': 25
# Number of unique colors in 'train/30675_gt.png': 25
# Number of unique colors in 'train/30700_gt.png': 25
# Number of unique colors in 'train/30725_gt.png': 15
# Number of unique colors in 'train/30750_gt.png': 26
# Number of unique colors in 'train/30775_gt.png': 26
# Number of unique colors in 'train/30800_gt.png': 16
# Number of unique colors in 'train/30825_gt.png': 14
# Number of unique colors in 'train/30850_gt.png': 15
# Number of unique colors in 'train/30875_gt.png': 23
# Number of unique colors in 'train/30900_gt.png': 23
# Number of unique colors in 'train/30975_gt.png': 13
# Number of unique colors in 'train/31725_gt.png': 14
# Number of unique colors in 'train/31975_gt.png': 15
# Number of unique colors in 'train/32225_gt.png': 15
# Number of unique colors in 'train/32450_gt.png': 15
# Number of unique colors in 'train/32700_gt.png': 17
# Number of unique colors in 'train/33200_gt.png': 14
# Number of unique colors in 'train/33700_gt.png': 11
# Number of unique colors in 'train/34425_gt.png': 17
# Number of unique colors in 'train/4050_gt.png': 27
# Number of unique colors in 'train/4075_gt.png': 27
# Number of unique colors in 'train/4100_gt.png': 30
# Number of unique colors in 'train/4125_gt.png': 28
# Number of unique colors in 'train/4150_gt.png': 28
# Number of unique colors in 'train/4175_gt.png': 28
# Number of unique colors in 'train/44025_gt.png': 15
# Number of unique colors in 'train/4425_gt.png': 31
# Number of unique colors in 'train/44525_gt.png': 27
# Number of unique colors in 'train/45000_gt.png': 23
# Number of unique colors in 'train/45500_gt.png': 22
# Number of unique colors in 'train/45750_gt.png': 14
# Number of unique colors in 'train/46225_gt.png': 18
# Number of unique colors in 'train/46725_gt.png': 5
# Number of unique colors in 'train/47225_gt.png': 13
# Number of unique colors in 'train/47475_gt.png': 9
# Number of unique colors in 'train/475_gt.png': 30
# Number of unique colors in 'train/47700_gt.png': 9
# Number of unique colors in 'train/48200_gt.png': 24
# Number of unique colors in 'train/48950_gt.png': 12
# Number of unique colors in 'train/4900_gt.png': 27
# Number of unique colors in 'train/4950_gt.png': 35
# Number of unique colors in 'train/4975_gt.png': 30
# Number of unique colors in 'train/5000_gt.png': 31
# Number of unique colors in 'train/5025_gt.png': 31
# Number of unique colors in 'train/5050_gt.png': 34
# Number of unique colors in 'train/5075_gt.png': 32
# Number of unique colors in 'train/5100_gt.png': 32
# Number of unique colors in 'train/5125_gt.png': 31
# Number of unique colors in 'train/5150_gt.png': 33
# Number of unique colors in 'train/5175_gt.png': 33
# Number of unique colors in 'train/53100_gt.png': 17
# Number of unique colors in 'train/53125_gt.png': 12
# Number of unique colors in 'train/53150_gt.png': 13
# Number of unique colors in 'train/53175_gt.png': 13
# Number of unique colors in 'train/53200_gt.png': 15
# Number of unique colors in 'train/53225_gt.png': 12
# Number of unique colors in 'train/53275_gt.png': 15
# Number of unique colors in 'train/53300_gt.png': 15
# Number of unique colors in 'train/53325_gt.png': 15
# Number of unique colors in 'train/53875_gt.png': 29
# Number of unique colors in 'train/53900_gt.png': 29
# Number of unique colors in 'train/53925_gt.png': 30
# Number of unique colors in 'train/53950_gt.png': 32
# Number of unique colors in 'train/53975_gt.png': 32
# Number of unique colors in 'train/54000_gt.png': 33
# Number of unique colors in 'train/5400_gt.png': 26
# Number of unique colors in 'train/54025_gt.png': 32
# Number of unique colors in 'train/54050_gt.png': 34
# Number of unique colors in 'train/54075_gt.png': 33
# Number of unique colors in 'train/54100_gt.png': 34
# Number of unique colors in 'train/54125_gt.png': 33
# Number of unique colors in 'train/54150_gt.png': 33
# Number of unique colors in 'train/54175_gt.png': 31
# Number of unique colors in 'train/54225_gt.png': 35
# Number of unique colors in 'train/54250_gt.png': 32
# Number of unique colors in 'train/54275_gt.png': 34
# Number of unique colors in 'train/54300_gt.png': 33
# Number of unique colors in 'train/54325_gt.png': 34
# Number of unique colors in 'train/54350_gt.png': 35
# Number of unique colors in 'train/54375_gt.png': 36
# Number of unique colors in 'train/54400_gt.png': 35
# Number of unique colors in 'train/55000_gt.png': 27
# Number of unique colors in 'train/55025_gt.png': 29
# Number of unique colors in 'train/55050_gt.png': 29
# Number of unique colors in 'train/55075_gt.png': 28
# Number of unique colors in 'train/55100_gt.png': 28
# Number of unique colors in 'train/55125_gt.png': 27
# Number of unique colors in 'train/55150_gt.png': 31
# Number of unique colors in 'train/55175_gt.png': 29
# Number of unique colors in 'train/55200_gt.png': 32
# Number of unique colors in 'train/55225_gt.png': 28
# Number of unique colors in 'train/55250_gt.png': 30
# Number of unique colors in 'train/55275_gt.png': 26
# Number of unique colors in 'train/55300_gt.png': 26
# Number of unique colors in 'train/55875_gt.png': 22
# Number of unique colors in 'train/55900_gt.png': 21
# Number of unique colors in 'train/55925_gt.png': 22
# Number of unique colors in 'train/55950_gt.png': 25
# Number of unique colors in 'train/55975_gt.png': 26
# Number of unique colors in 'train/56000_gt.png': 26
# Number of unique colors in 'train/56025_gt.png': 26
# Number of unique colors in 'train/56050_gt.png': 25
# Number of unique colors in 'train/56075_gt.png': 25
# Number of unique colors in 'train/56100_gt.png': 26
# Number of unique colors in 'train/5900_gt.png': 26
# Number of unique colors in 'train/6550_gt.png': 16
# Number of unique colors in 'train/6575_gt.png': 16
# Number of unique colors in 'train/6600_gt.png': 16
# Number of unique colors in 'train/6625_gt.png': 29
# Number of unique colors in 'train/6650_gt.png': 18
# Number of unique colors in 'train/6675_gt.png': 16
# Number of unique colors in 'train/6875_gt.png': 25
# Number of unique colors in 'train/7125_gt.png': 31
# Number of unique colors in 'train/7625_gt.png': 38
# Number of unique colors in 'train/9125_gt.png': 16
# Processing test groundtruth images...
# Number of unique colors in 'test/00_gt.png': 19
# Number of unique colors in 'test/10075_gt.png': 33
# Number of unique colors in 'test/1225_gt.png': 16
# Number of unique colors in 'test/12550_gt.png': 15
# Number of unique colors in 'test/13700_gt.png': 27
# Number of unique colors in 'test/14000_gt.png': 17
# Number of unique colors in 'test/14500_gt.png': 28
# Number of unique colors in 'test/1475_gt.png': 28
# Number of unique colors in 'test/15250_gt.png': 15
# Number of unique colors in 'test/17700_gt.png': 25
# Number of unique colors in 'test/1950_gt.png': 33
# Number of unique colors in 'test/20400_gt.png': 33
# Number of unique colors in 'test/21150_gt.png': 36
# Number of unique colors in 'test/21400_gt.png': 37
# Number of unique colors in 'test/22125_gt.png': 25
# Number of unique colors in 'test/225_gt.png': 14
# Number of unique colors in 'test/22625_gt.png': 19
# Number of unique colors in 'test/2275_gt.png': 26
# Number of unique colors in 'test/22875_gt.png': 21
# Number of unique colors in 'test/23100_gt.png': 39
# Number of unique colors in 'test/23350_gt.png': 32
# Number of unique colors in 'test/23600_gt.png': 30
# Number of unique colors in 'test/2450_gt.png': 27
# Number of unique colors in 'test/30000_gt.png': 11
# Number of unique colors in 'test/30250_gt.png': 11
# Number of unique colors in 'test/30750_gt.png': 13
# Number of unique colors in 'test/31225_gt.png': 13
# Number of unique colors in 'test/31475_gt.png': 16
# Number of unique colors in 'test/3175_gt.png': 25
# Number of unique colors in 'test/32950_gt.png': 13
# Number of unique colors in 'test/33450_gt.png': 11
# Number of unique colors in 'test/33925_gt.png': 17
# Number of unique colors in 'test/34175_gt.png': 20
# Number of unique colors in 'test/3425_gt.png': 17
# Number of unique colors in 'test/34675_gt.png': 16
# Number of unique colors in 'test/3675_gt.png': 16
# Number of unique colors in 'test/3925_gt.png': 24
# Number of unique colors in 'test/4175_gt.png': 30
# Number of unique colors in 'test/44275_gt.png': 26
# Number of unique colors in 'test/44750_gt.png': 22
# Number of unique colors in 'test/45250_gt.png': 18
# Number of unique colors in 'test/4550_gt.png': 29
# Number of unique colors in 'test/46000_gt.png': 19
# Number of unique colors in 'test/46475_gt.png': 4
# Number of unique colors in 'test/4650_gt.png': 27
# Number of unique colors in 'test/46975_gt.png': 7
# Number of unique colors in 'test/47950_gt.png': 14
# Number of unique colors in 'test/48450_gt.png': 10
# Number of unique colors in 'test/48700_gt.png': 24
# Number of unique colors in 'test/49200_gt.png': 2
# Number of unique colors in 'test/5150_gt.png': 28
# Number of unique colors in 'test/5650_gt.png': 27
# Number of unique colors in 'test/5700_gt.png': 27
# Number of unique colors in 'test/6150_gt.png': 28
# Number of unique colors in 'test/6375_gt.png': 27
# Number of unique colors in 'test/6850_gt.png': 15
# Number of unique colors in 'test/725_gt.png': 14
# Number of unique colors in 'test/7375_gt.png': 33
# Number of unique colors in 'test/7850_gt.png': 29
# Number of unique colors in 'test/7975_gt.png': 15
# Number of unique colors in 'test/8100_gt.png': 33
# Number of unique colors in 'test/975_gt.png': 16

# %% [markdown]
# ## Editing masks to remove the unique mask colors less than a certain pixel areaa and also moving the "images" into "Frames" folders

# %%
# Define input and output directories for each dataset split
dataset_folders = {
    "trainval": {
        "input_images": os.path.join(base_before_folder, "trainval", "images"),
        "input_masks": os.path.join(base_before_folder, "trainval", "groundtruth"),
        "output_frames": os.path.join(base_after_folder, "trainval", "Frames"),
        "output_masks": os.path.join(base_after_folder, "trainval", "Masks")
    },
    "train": {
        "input_images": os.path.join(base_before_folder, "train", "images"),
        "input_masks": os.path.join(base_before_folder, "train", "groundtruth"),
        "output_frames": os.path.join(base_after_folder, "train", "Frames"),
        "output_masks": os.path.join(base_after_folder, "train", "Masks")
    },
    "test": {
        "input_images": os.path.join(base_before_folder, "test", "images"),
        "input_masks": os.path.join(base_before_folder, "test", "groundtruth"),
        "output_frames": os.path.join(base_after_folder, "test", "Frames"),
        "output_masks": os.path.join(base_after_folder, "test", "Masks")
    }
}

# Function to remove colors with pixel area < min_pixel_area and save the edited image
def remove_small_area_colors(image_path, output_path, min_pixel_area=75):
    image = Image.open(image_path).convert('RGB')  # Ensure the image is in RGB mode
    width, height = image.size
    pixels = image.load()

    # Calculate the area of each color
    color_count = image.getcolors(maxcolors=width * height)
    colors_to_remove = {color[1] for color in color_count if color[0] < min_pixel_area}

    # Create a new image with colors that meet the minimum pixel area requirement
    edited_image = Image.new('RGB', (width, height), (255, 255, 255))  # Start with a white canvas
    edited_pixels = edited_image.load()

    # Copy only pixels with sufficient area to the new image
    for y in range(height):
        for x in range(width):
            if pixels[x, y] not in colors_to_remove:
                edited_pixels[x, y] = pixels[x, y]

    # Save the edited image
    edited_image.save(output_path)

# Process each dataset folder
for split, paths in dataset_folders.items():
    input_images_dir = paths["input_images"]
    input_masks_dir = paths["input_masks"]
    output_frames_dir = paths["output_frames"]
    output_masks_dir = paths["output_masks"]

    # Ensure the output directories exist
    os.makedirs(output_frames_dir, exist_ok=True)
    os.makedirs(output_masks_dir, exist_ok=True)

    # Copy images to the Frames folder
    for filename in os.listdir(input_images_dir):
        source_path = os.path.join(input_images_dir, filename)
        destination_path = os.path.join(output_frames_dir, filename)
        if os.path.isfile(source_path):
            shutil.copy2(source_path, destination_path)
            print(f"Copied '{filename}' to '{output_frames_dir}' as part of '{split}'.")

    # Process and save the edited masks to the Masks folder
    for filename in os.listdir(input_masks_dir):
        mask_path = os.path.join(input_masks_dir, filename)
        if os.path.isfile(mask_path):
            output_path = os.path.join(output_masks_dir, filename)
            remove_small_area_colors(mask_path, output_path)
            print(f"Processed '{filename}' in '{split}' and saved to '{output_masks_dir}' folder.")
# Out:
# Copied '0.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '00.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '015975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '030750.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '03425.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '04175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '05150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '06625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '10075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '10275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '1125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '11400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '1225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '12550.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '13025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '13700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '14000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '14500.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '1475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '14825.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '15250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '15975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '16475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '1700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '17700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '18925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '1950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '20400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '20650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '20900.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '21150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '21400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '21625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '21875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '2200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '22125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '22375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '22625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '2275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '22875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '23100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '23350.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '23600.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '23850.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '2450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25300.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25325.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25350.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25425.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25500.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25525.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25550.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25575.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25600.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25725.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25775.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25800.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25825.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25850.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25900.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '25975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26300.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26325.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26350.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26425.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26500.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26525.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26550.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26575.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26600.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26725.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26750.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26775.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26800.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26825.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '26975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '2700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27300.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27325.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27575.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27600.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '27700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '28200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '2950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30500.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30600.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30725.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30750.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30775.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30800.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30825.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30850.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30900.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '30975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '31225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '31475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '31725.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '3175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '31975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '32225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '32450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '32700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '32950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '33200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '33450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '33700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '33925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '34175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '3425.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '34425.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '34675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '3675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '3925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '44025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4425.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '44275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '44525.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '44750.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '45000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '45250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4550.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '45500.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '45750.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '46000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '46225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '46475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '46725.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '46975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '47225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '47475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '47700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '47950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '48200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '48450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '48700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '48950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4900.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '49200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '4975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53300.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53325.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53900.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '53975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54300.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54325.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54350.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '54400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55300.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55900.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '55975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '56000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '56025.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '56050.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '56075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '56100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '5900.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6550.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6575.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6600.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6850.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '6875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '7125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '725.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '7375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '7625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '7850.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '7975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '8100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '9125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Copied '975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Frames' as part of 'trainval'.
# Processed '00_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '015975_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '030750_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '03425_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '04175_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '05150_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '06625_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '0_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '10075_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '10275_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '1125_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '11400_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '1225_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '12550_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '13025_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '13700_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '14000_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '14500_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '1475_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '14825_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '15250_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '15975_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '16475_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '1700_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '17700_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '18925_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '1950_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '20400_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '20650_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '20900_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '21150_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '21400_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '21625_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '21875_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '2200_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '22125_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '22375_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '225_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '22625_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '2275_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '22875_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '23100_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '23350_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '23600_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '23850_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '2450_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25025_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25050_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25075_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25100_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25125_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25150_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25175_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25200_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25225_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25250_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25275_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25300_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25325_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25350_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25375_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25400_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25425_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25450_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25475_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25500_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25525_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25550_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25575_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25600_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25625_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25650_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25675_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25700_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25725_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25775_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25800_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25825_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25850_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25875_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25900_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25925_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25950_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '25975_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26000_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26025_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26050_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26075_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26100_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26125_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26150_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26175_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26200_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26225_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26250_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26275_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26300_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26325_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26350_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26375_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26400_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26425_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26450_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26475_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26500_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26525_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26550_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26575_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26600_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26625_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26650_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26675_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26700_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26725_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26750_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26775_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26800_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26825_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26925_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26950_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '26975_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27000_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '2700_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27025_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27050_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27075_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27100_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27125_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27150_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27175_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27200_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27225_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27250_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27275_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27300_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27325_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27575_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27600_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27625_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# Processed '27650_gt.png' in 'trainval' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks' folder.
# ...
# Processed '55100_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55125_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55150_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55175_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55200_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55225_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55250_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55275_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55300_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55875_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55900_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55925_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55950_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '55975_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '56000_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '56025_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '56050_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '56075_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '56100_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '5900_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '6550_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '6575_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '6600_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '6625_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '6650_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '6675_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '6875_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '7125_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '7625_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Processed '9125_gt.png' in 'train' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks' folder.
# Copied '00.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '10075.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '1225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '12550.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '13700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '14000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '14500.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '1475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '15250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '17700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '1950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '20400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '21150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '21400.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '22125.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '22625.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '2275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '22875.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '23100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '23350.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '23600.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '2450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '30000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '30250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '30750.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '31225.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '31475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '3175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '32950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '33450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '33925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '34175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '3425.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '34675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '3675.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '3925.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '4175.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '44275.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '44750.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '45250.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '4550.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '46000.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '46475.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '4650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '46975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '47950.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '48450.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '48700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '49200.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '5150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '5650.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '5700.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '6150.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '6375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '6850.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '725.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '7375.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '7850.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '7975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '8100.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Copied '975.jpg' to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Frames' as part of 'test'.
# Processed '00_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '10075_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '1225_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '12550_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '13700_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '14000_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '14500_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '1475_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '15250_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '17700_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '1950_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '20400_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '21150_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '21400_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '22125_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '225_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '22625_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '2275_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '22875_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '23100_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '23350_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '23600_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '2450_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '30000_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '30250_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '30750_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '31225_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '31475_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '3175_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '32950_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '33450_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '33925_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '34175_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '3425_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '34675_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '3675_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '3925_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '4175_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '44275_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '44750_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '45250_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '4550_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '46000_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '46475_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '4650_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '46975_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '47950_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '48450_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '48700_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '49200_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '5150_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '5650_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '5700_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '6150_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '6375_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '6850_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '725_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '7375_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '7850_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '7975_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '8100_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.
# Processed '975_gt.png' in 'test' and saved to '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks' folder.

# %% [markdown]
# ## Recalculating the number of unique mask colors in each of the masks after above preprocessing

# %%
# Define paths for each dataset split's Masks folder
dataset_folders = {
    "trainval": os.path.join(base_after_folder, "trainval", "Masks"),
    "train": os.path.join(base_after_folder, "train", "Masks"),
    "test": os.path.join(base_after_folder, "test", "Masks")
}

# Function to get the count of unique colors in an image
def count_unique_colors(image_path):
    image = Image.open(image_path).convert('RGB')  # Open the image and ensure it's in RGB mode
    unique_colors = image.getcolors(maxcolors=1000000)  # Set a high limit to get all unique colors
    return len(unique_colors) if unique_colors else 0  # Return the count of unique colors

# Process each dataset split and count unique colors in each mask
for split, masks_dir in dataset_folders.items():
    print(f"Processing unique colors in '{split}' Masks folder...")
    for filename in os.listdir(masks_dir):
        mask_path = os.path.join(masks_dir, filename)
        if os.path.isfile(mask_path):
            unique_color_count = count_unique_colors(mask_path)
            print(f"Number of unique colors in '{split}/{filename}': {unique_color_count}")
# Out:
# Processing unique colors in 'trainval' Masks folder...
# Number of unique colors in 'trainval/00_gt.png': 10
# Number of unique colors in 'trainval/015975_gt.png': 9
# Number of unique colors in 'trainval/030750_gt.png': 13
# Number of unique colors in 'trainval/03425_gt.png': 10
# Number of unique colors in 'trainval/04175_gt.png': 12
# Number of unique colors in 'trainval/05150_gt.png': 15
# Number of unique colors in 'trainval/06625_gt.png': 12
# Number of unique colors in 'trainval/0_gt.png': 6
# Number of unique colors in 'trainval/10075_gt.png': 14
# Number of unique colors in 'trainval/10275_gt.png': 10
# Number of unique colors in 'trainval/1125_gt.png': 10
# Number of unique colors in 'trainval/11400_gt.png': 10
# Number of unique colors in 'trainval/1225_gt.png': 10
# Number of unique colors in 'trainval/12550_gt.png': 12
# Number of unique colors in 'trainval/13025_gt.png': 10
# Number of unique colors in 'trainval/13700_gt.png': 12
# Number of unique colors in 'trainval/14000_gt.png': 10
# Number of unique colors in 'trainval/14500_gt.png': 16
# Number of unique colors in 'trainval/1475_gt.png': 11
# Number of unique colors in 'trainval/14825_gt.png': 10
# Number of unique colors in 'trainval/15250_gt.png': 9
# Number of unique colors in 'trainval/15975_gt.png': 9
# Number of unique colors in 'trainval/16475_gt.png': 10
# Number of unique colors in 'trainval/1700_gt.png': 13
# Number of unique colors in 'trainval/17700_gt.png': 13
# Number of unique colors in 'trainval/18925_gt.png': 22
# Number of unique colors in 'trainval/1950_gt.png': 12
# Number of unique colors in 'trainval/20400_gt.png': 13
# Number of unique colors in 'trainval/20650_gt.png': 14
# Number of unique colors in 'trainval/20900_gt.png': 16
# Number of unique colors in 'trainval/21150_gt.png': 14
# Number of unique colors in 'trainval/21400_gt.png': 15
# Number of unique colors in 'trainval/21625_gt.png': 12
# Number of unique colors in 'trainval/21875_gt.png': 16
# Number of unique colors in 'trainval/2200_gt.png': 11
# Number of unique colors in 'trainval/22125_gt.png': 12
# Number of unique colors in 'trainval/22375_gt.png': 11
# Number of unique colors in 'trainval/225_gt.png': 8
# Number of unique colors in 'trainval/22625_gt.png': 10
# Number of unique colors in 'trainval/2275_gt.png': 15
# Number of unique colors in 'trainval/22875_gt.png': 13
# Number of unique colors in 'trainval/23100_gt.png': 17
# Number of unique colors in 'trainval/23350_gt.png': 15
# Number of unique colors in 'trainval/23600_gt.png': 18
# Number of unique colors in 'trainval/23850_gt.png': 13
# Number of unique colors in 'trainval/2450_gt.png': 11
# Number of unique colors in 'trainval/25025_gt.png': 14
# Number of unique colors in 'trainval/25050_gt.png': 15
# Number of unique colors in 'trainval/25075_gt.png': 14
# Number of unique colors in 'trainval/25100_gt.png': 14
# Number of unique colors in 'trainval/25125_gt.png': 17
# Number of unique colors in 'trainval/25150_gt.png': 15
# Number of unique colors in 'trainval/25175_gt.png': 14
# Number of unique colors in 'trainval/25200_gt.png': 15
# Number of unique colors in 'trainval/25225_gt.png': 14
# Number of unique colors in 'trainval/25250_gt.png': 13
# Number of unique colors in 'trainval/25275_gt.png': 12
# Number of unique colors in 'trainval/25300_gt.png': 12
# Number of unique colors in 'trainval/25325_gt.png': 13
# Number of unique colors in 'trainval/25350_gt.png': 14
# Number of unique colors in 'trainval/25375_gt.png': 12
# Number of unique colors in 'trainval/25400_gt.png': 12
# Number of unique colors in 'trainval/25425_gt.png': 14
# Number of unique colors in 'trainval/25450_gt.png': 13
# Number of unique colors in 'trainval/25475_gt.png': 14
# Number of unique colors in 'trainval/25500_gt.png': 14
# Number of unique colors in 'trainval/25525_gt.png': 13
# Number of unique colors in 'trainval/25550_gt.png': 16
# Number of unique colors in 'trainval/25575_gt.png': 16
# Number of unique colors in 'trainval/25600_gt.png': 15
# Number of unique colors in 'trainval/25625_gt.png': 12
# Number of unique colors in 'trainval/25650_gt.png': 12
# Number of unique colors in 'trainval/25675_gt.png': 14
# Number of unique colors in 'trainval/25700_gt.png': 13
# Number of unique colors in 'trainval/25725_gt.png': 15
# Number of unique colors in 'trainval/25775_gt.png': 15
# Number of unique colors in 'trainval/25800_gt.png': 13
# Number of unique colors in 'trainval/25825_gt.png': 13
# Number of unique colors in 'trainval/25850_gt.png': 13
# Number of unique colors in 'trainval/25875_gt.png': 15
# Number of unique colors in 'trainval/25900_gt.png': 14
# Number of unique colors in 'trainval/25925_gt.png': 13
# Number of unique colors in 'trainval/25950_gt.png': 11
# Number of unique colors in 'trainval/25975_gt.png': 11
# Number of unique colors in 'trainval/26000_gt.png': 10
# Number of unique colors in 'trainval/26025_gt.png': 13
# Number of unique colors in 'trainval/26050_gt.png': 12
# Number of unique colors in 'trainval/26075_gt.png': 9
# Number of unique colors in 'trainval/26100_gt.png': 20
# Number of unique colors in 'trainval/26125_gt.png': 17
# Number of unique colors in 'trainval/26150_gt.png': 18
# Number of unique colors in 'trainval/26175_gt.png': 15
# Number of unique colors in 'trainval/26200_gt.png': 16
# Number of unique colors in 'trainval/26225_gt.png': 19
# Number of unique colors in 'trainval/26250_gt.png': 18
# Number of unique colors in 'trainval/26275_gt.png': 16
# Number of unique colors in 'trainval/26300_gt.png': 18
# Number of unique colors in 'trainval/26325_gt.png': 18
# Number of unique colors in 'trainval/26350_gt.png': 16
# Number of unique colors in 'trainval/26375_gt.png': 21
# Number of unique colors in 'trainval/26400_gt.png': 18
# Number of unique colors in 'trainval/26425_gt.png': 18
# Number of unique colors in 'trainval/26450_gt.png': 18
# Number of unique colors in 'trainval/26475_gt.png': 18
# Number of unique colors in 'trainval/26500_gt.png': 17
# Number of unique colors in 'trainval/26525_gt.png': 19
# Number of unique colors in 'trainval/26550_gt.png': 17
# Number of unique colors in 'trainval/26575_gt.png': 17
# Number of unique colors in 'trainval/26600_gt.png': 18
# Number of unique colors in 'trainval/26625_gt.png': 16
# Number of unique colors in 'trainval/26650_gt.png': 20
# Number of unique colors in 'trainval/26675_gt.png': 18
# Number of unique colors in 'trainval/26700_gt.png': 19
# Number of unique colors in 'trainval/26725_gt.png': 17
# Number of unique colors in 'trainval/26750_gt.png': 17
# Number of unique colors in 'trainval/26775_gt.png': 17
# Number of unique colors in 'trainval/26800_gt.png': 20
# Number of unique colors in 'trainval/26825_gt.png': 20
# Number of unique colors in 'trainval/26925_gt.png': 15
# Number of unique colors in 'trainval/26950_gt.png': 19
# Number of unique colors in 'trainval/26975_gt.png': 18
# Number of unique colors in 'trainval/27000_gt.png': 17
# Number of unique colors in 'trainval/2700_gt.png': 12
# Number of unique colors in 'trainval/27025_gt.png': 16
# Number of unique colors in 'trainval/27050_gt.png': 16
# Number of unique colors in 'trainval/27075_gt.png': 16
# Number of unique colors in 'trainval/27100_gt.png': 18
# Number of unique colors in 'trainval/27125_gt.png': 16
# Number of unique colors in 'trainval/27150_gt.png': 16
# Number of unique colors in 'trainval/27175_gt.png': 15
# Number of unique colors in 'trainval/27200_gt.png': 17
# Number of unique colors in 'trainval/27225_gt.png': 17
# Number of unique colors in 'trainval/27250_gt.png': 17
# Number of unique colors in 'trainval/27275_gt.png': 16
# Number of unique colors in 'trainval/27300_gt.png': 17
# Number of unique colors in 'trainval/27325_gt.png': 16
# Number of unique colors in 'trainval/27575_gt.png': 16
# Number of unique colors in 'trainval/27600_gt.png': 16
# Number of unique colors in 'trainval/27625_gt.png': 17
# Number of unique colors in 'trainval/27650_gt.png': 16
# Number of unique colors in 'trainval/27675_gt.png': 16
# Number of unique colors in 'trainval/27700_gt.png': 16
# Number of unique colors in 'trainval/28000_gt.png': 18
# Number of unique colors in 'trainval/28025_gt.png': 18
# Number of unique colors in 'trainval/28050_gt.png': 16
# Number of unique colors in 'trainval/28075_gt.png': 18
# Number of unique colors in 'trainval/28100_gt.png': 18
# Number of unique colors in 'trainval/28125_gt.png': 18
# Number of unique colors in 'trainval/28150_gt.png': 16
# Number of unique colors in 'trainval/28175_gt.png': 17
# Number of unique colors in 'trainval/28200_gt.png': 17
# Number of unique colors in 'trainval/2950_gt.png': 12
# Number of unique colors in 'trainval/30000_gt.png': 9
# Number of unique colors in 'trainval/30250_gt.png': 9
# Number of unique colors in 'trainval/30500_gt.png': 9
# Number of unique colors in 'trainval/30600_gt.png': 15
# Number of unique colors in 'trainval/30625_gt.png': 15
# Number of unique colors in 'trainval/30650_gt.png': 14
# Number of unique colors in 'trainval/30675_gt.png': 16
# Number of unique colors in 'trainval/30700_gt.png': 13
# Number of unique colors in 'trainval/30725_gt.png': 10
# Number of unique colors in 'trainval/30750_gt.png': 9
# Number of unique colors in 'trainval/30775_gt.png': 14
# Number of unique colors in 'trainval/30800_gt.png': 10
# Number of unique colors in 'trainval/30825_gt.png': 10
# Number of unique colors in 'trainval/30850_gt.png': 10
# Number of unique colors in 'trainval/30875_gt.png': 11
# Number of unique colors in 'trainval/30900_gt.png': 12
# Number of unique colors in 'trainval/30975_gt.png': 9
# Number of unique colors in 'trainval/31225_gt.png': 10
# Number of unique colors in 'trainval/31475_gt.png': 10
# Number of unique colors in 'trainval/31725_gt.png': 10
# Number of unique colors in 'trainval/3175_gt.png': 11
# Number of unique colors in 'trainval/31975_gt.png': 9
# Number of unique colors in 'trainval/32225_gt.png': 9
# Number of unique colors in 'trainval/32450_gt.png': 9
# Number of unique colors in 'trainval/32700_gt.png': 8
# Number of unique colors in 'trainval/32950_gt.png': 9
# Number of unique colors in 'trainval/33200_gt.png': 10
# Number of unique colors in 'trainval/33450_gt.png': 7
# Number of unique colors in 'trainval/33700_gt.png': 7
# Number of unique colors in 'trainval/33925_gt.png': 9
# Number of unique colors in 'trainval/34175_gt.png': 11
# Number of unique colors in 'trainval/3425_gt.png': 10
# Number of unique colors in 'trainval/34425_gt.png': 9
# Number of unique colors in 'trainval/34675_gt.png': 8
# Number of unique colors in 'trainval/3675_gt.png': 10
# Number of unique colors in 'trainval/3925_gt.png': 14
# Number of unique colors in 'trainval/4050_gt.png': 13
# Number of unique colors in 'trainval/4075_gt.png': 12
# Number of unique colors in 'trainval/4100_gt.png': 13
# Number of unique colors in 'trainval/4125_gt.png': 11
# Number of unique colors in 'trainval/4150_gt.png': 12
# Number of unique colors in 'trainval/4175_gt.png': 17
# Number of unique colors in 'trainval/44025_gt.png': 8
# Number of unique colors in 'trainval/4425_gt.png': 15
# Number of unique colors in 'trainval/44275_gt.png': 9
# Number of unique colors in 'trainval/44525_gt.png': 13
# Number of unique colors in 'trainval/44750_gt.png': 12
# Number of unique colors in 'trainval/45000_gt.png': 13
# Number of unique colors in 'trainval/45250_gt.png': 13
# Number of unique colors in 'trainval/45500_gt.png': 11
# Number of unique colors in 'trainval/4550_gt.png': 15
# Number of unique colors in 'trainval/45750_gt.png': 8
# Number of unique colors in 'trainval/46000_gt.png': 11
# Number of unique colors in 'trainval/46225_gt.png': 8
# Number of unique colors in 'trainval/46475_gt.png': 4
# Number of unique colors in 'trainval/4650_gt.png': 15
# Number of unique colors in 'trainval/46725_gt.png': 4
# Number of unique colors in 'trainval/46975_gt.png': 6
# Number of unique colors in 'trainval/47225_gt.png': 9
# Number of unique colors in 'trainval/47475_gt.png': 6
# Number of unique colors in 'trainval/475_gt.png': 13
# Number of unique colors in 'trainval/47700_gt.png': 7
# Number of unique colors in 'trainval/47950_gt.png': 8
# Number of unique colors in 'trainval/48200_gt.png': 13
# Number of unique colors in 'trainval/48450_gt.png': 6
# Number of unique colors in 'trainval/48700_gt.png': 14
# Number of unique colors in 'trainval/48950_gt.png': 6
# Number of unique colors in 'trainval/4900_gt.png': 15
# Number of unique colors in 'trainval/49200_gt.png': 2
# Number of unique colors in 'trainval/4950_gt.png': 15
# Number of unique colors in 'trainval/4975_gt.png': 16
# Number of unique colors in 'trainval/5000_gt.png': 17
# Number of unique colors in 'trainval/5025_gt.png': 15
# Number of unique colors in 'trainval/5050_gt.png': 13
# Number of unique colors in 'trainval/5075_gt.png': 14
# Number of unique colors in 'trainval/5100_gt.png': 14
# Number of unique colors in 'trainval/5125_gt.png': 12
# Number of unique colors in 'trainval/5150_gt.png': 15
# Number of unique colors in 'trainval/5175_gt.png': 15
# Number of unique colors in 'trainval/53100_gt.png': 9
# Number of unique colors in 'trainval/53125_gt.png': 8
# Number of unique colors in 'trainval/53150_gt.png': 8
# Number of unique colors in 'trainval/53175_gt.png': 7
# Number of unique colors in 'trainval/53200_gt.png': 9
# Number of unique colors in 'trainval/53225_gt.png': 10
# Number of unique colors in 'trainval/53275_gt.png': 10
# Number of unique colors in 'trainval/53300_gt.png': 11
# Number of unique colors in 'trainval/53325_gt.png': 11
# Number of unique colors in 'trainval/53875_gt.png': 17
# Number of unique colors in 'trainval/53900_gt.png': 18
# Number of unique colors in 'trainval/53925_gt.png': 16
# Number of unique colors in 'trainval/53950_gt.png': 19
# Number of unique colors in 'trainval/53975_gt.png': 19
# Number of unique colors in 'trainval/54000_gt.png': 16
# Number of unique colors in 'trainval/5400_gt.png': 16
# Number of unique colors in 'trainval/54025_gt.png': 19
# Number of unique colors in 'trainval/54050_gt.png': 18
# Number of unique colors in 'trainval/54075_gt.png': 21
# Number of unique colors in 'trainval/54100_gt.png': 20
# Number of unique colors in 'trainval/54125_gt.png': 21
# Number of unique colors in 'trainval/54150_gt.png': 19
# Number of unique colors in 'trainval/54175_gt.png': 19
# Number of unique colors in 'trainval/54225_gt.png': 21
# Number of unique colors in 'trainval/54250_gt.png': 19
# Number of unique colors in 'trainval/54275_gt.png': 21
# Number of unique colors in 'trainval/54300_gt.png': 19
# Number of unique colors in 'trainval/54325_gt.png': 19
# Number of unique colors in 'trainval/54350_gt.png': 20
# Number of unique colors in 'trainval/54375_gt.png': 19
# Number of unique colors in 'trainval/54400_gt.png': 18
# Number of unique colors in 'trainval/55000_gt.png': 14
# Number of unique colors in 'trainval/55025_gt.png': 15
# Number of unique colors in 'trainval/55050_gt.png': 15
# Number of unique colors in 'trainval/55075_gt.png': 16
# Number of unique colors in 'trainval/55100_gt.png': 15
# Number of unique colors in 'trainval/55125_gt.png': 16
# Number of unique colors in 'trainval/55150_gt.png': 16
# Number of unique colors in 'trainval/55175_gt.png': 15
# Number of unique colors in 'trainval/55200_gt.png': 16
# Number of unique colors in 'trainval/55225_gt.png': 13
# Number of unique colors in 'trainval/55250_gt.png': 14
# Number of unique colors in 'trainval/55275_gt.png': 16
# Number of unique colors in 'trainval/55300_gt.png': 16
# Number of unique colors in 'trainval/55875_gt.png': 10
# Number of unique colors in 'trainval/55900_gt.png': 10
# Number of unique colors in 'trainval/55925_gt.png': 10
# Number of unique colors in 'trainval/55950_gt.png': 12
# Number of unique colors in 'trainval/55975_gt.png': 12
# Number of unique colors in 'trainval/56000_gt.png': 13
# Number of unique colors in 'trainval/56025_gt.png': 11
# Number of unique colors in 'trainval/56050_gt.png': 11
# Number of unique colors in 'trainval/56075_gt.png': 13
# Number of unique colors in 'trainval/56100_gt.png': 13
# Number of unique colors in 'trainval/5650_gt.png': 11
# Number of unique colors in 'trainval/5700_gt.png': 15
# Number of unique colors in 'trainval/5900_gt.png': 13
# Number of unique colors in 'trainval/6150_gt.png': 16
# Number of unique colors in 'trainval/6375_gt.png': 15
# Number of unique colors in 'trainval/6550_gt.png': 12
# Number of unique colors in 'trainval/6575_gt.png': 12
# Number of unique colors in 'trainval/6600_gt.png': 12
# Number of unique colors in 'trainval/6625_gt.png': 14
# Number of unique colors in 'trainval/6650_gt.png': 12
# Number of unique colors in 'trainval/6675_gt.png': 12
# Number of unique colors in 'trainval/6850_gt.png': 10
# Number of unique colors in 'trainval/6875_gt.png': 14
# Number of unique colors in 'trainval/7125_gt.png': 18
# Number of unique colors in 'trainval/725_gt.png': 9
# Number of unique colors in 'trainval/7375_gt.png': 13
# Number of unique colors in 'trainval/7625_gt.png': 17
# Number of unique colors in 'trainval/7850_gt.png': 17
# Number of unique colors in 'trainval/7975_gt.png': 11
# Number of unique colors in 'trainval/8100_gt.png': 14
# Number of unique colors in 'trainval/9125_gt.png': 10
# Number of unique colors in 'trainval/975_gt.png': 10
# Processing unique colors in 'train' Masks folder...
# Number of unique colors in 'train/015975_gt.png': 9
# Number of unique colors in 'train/03425_gt.png': 10
# Number of unique colors in 'train/06625_gt.png': 12
# Number of unique colors in 'train/0_gt.png': 6
# Number of unique colors in 'train/10275_gt.png': 10
# Number of unique colors in 'train/1125_gt.png': 10
# Number of unique colors in 'train/11400_gt.png': 10
# Number of unique colors in 'train/13025_gt.png': 10
# Number of unique colors in 'train/14825_gt.png': 10
# Number of unique colors in 'train/15975_gt.png': 9
# Number of unique colors in 'train/16475_gt.png': 10
# Number of unique colors in 'train/1700_gt.png': 13
# Number of unique colors in 'train/18925_gt.png': 22
# Number of unique colors in 'train/20650_gt.png': 14
# Number of unique colors in 'train/20900_gt.png': 16
# Number of unique colors in 'train/21625_gt.png': 12
# Number of unique colors in 'train/21875_gt.png': 16
# Number of unique colors in 'train/2200_gt.png': 11
# Number of unique colors in 'train/22375_gt.png': 11
# Number of unique colors in 'train/23850_gt.png': 13
# Number of unique colors in 'train/25025_gt.png': 14
# Number of unique colors in 'train/25050_gt.png': 15
# Number of unique colors in 'train/25075_gt.png': 14
# Number of unique colors in 'train/25100_gt.png': 14
# Number of unique colors in 'train/25125_gt.png': 17
# Number of unique colors in 'train/25150_gt.png': 15
# Number of unique colors in 'train/25175_gt.png': 14
# Number of unique colors in 'train/25200_gt.png': 15
# Number of unique colors in 'train/25225_gt.png': 14
# Number of unique colors in 'train/25250_gt.png': 13
# Number of unique colors in 'train/25275_gt.png': 12
# Number of unique colors in 'train/25300_gt.png': 12
# Number of unique colors in 'train/25325_gt.png': 13
# Number of unique colors in 'train/25350_gt.png': 14
# Number of unique colors in 'train/25375_gt.png': 12
# Number of unique colors in 'train/25400_gt.png': 12
# Number of unique colors in 'train/25425_gt.png': 14
# Number of unique colors in 'train/25450_gt.png': 13
# Number of unique colors in 'train/25475_gt.png': 14
# Number of unique colors in 'train/25500_gt.png': 14
# Number of unique colors in 'train/25525_gt.png': 13
# Number of unique colors in 'train/25550_gt.png': 16
# Number of unique colors in 'train/25575_gt.png': 16
# Number of unique colors in 'train/25600_gt.png': 15
# Number of unique colors in 'train/25625_gt.png': 12
# Number of unique colors in 'train/25650_gt.png': 12
# Number of unique colors in 'train/25675_gt.png': 14
# Number of unique colors in 'train/25700_gt.png': 13
# Number of unique colors in 'train/25725_gt.png': 15
# Number of unique colors in 'train/25775_gt.png': 15
# Number of unique colors in 'train/25800_gt.png': 13
# Number of unique colors in 'train/25825_gt.png': 13
# Number of unique colors in 'train/25850_gt.png': 13
# Number of unique colors in 'train/25875_gt.png': 15
# Number of unique colors in 'train/25900_gt.png': 14
# Number of unique colors in 'train/25925_gt.png': 13
# Number of unique colors in 'train/25950_gt.png': 11
# Number of unique colors in 'train/25975_gt.png': 11
# Number of unique colors in 'train/26000_gt.png': 10
# Number of unique colors in 'train/26025_gt.png': 13
# Number of unique colors in 'train/26050_gt.png': 12
# Number of unique colors in 'train/26075_gt.png': 9
# Number of unique colors in 'train/26100_gt.png': 20
# Number of unique colors in 'train/26125_gt.png': 17
# Number of unique colors in 'train/26150_gt.png': 18
# Number of unique colors in 'train/26175_gt.png': 15
# Number of unique colors in 'train/26200_gt.png': 16
# Number of unique colors in 'train/26225_gt.png': 19
# Number of unique colors in 'train/26250_gt.png': 18
# Number of unique colors in 'train/26275_gt.png': 16
# Number of unique colors in 'train/26300_gt.png': 18
# Number of unique colors in 'train/26325_gt.png': 18
# Number of unique colors in 'train/26350_gt.png': 16
# Number of unique colors in 'train/26375_gt.png': 21
# Number of unique colors in 'train/26400_gt.png': 18
# Number of unique colors in 'train/26425_gt.png': 18
# Number of unique colors in 'train/26450_gt.png': 18
# Number of unique colors in 'train/26475_gt.png': 18
# Number of unique colors in 'train/26500_gt.png': 17
# Number of unique colors in 'train/26525_gt.png': 19
# Number of unique colors in 'train/26550_gt.png': 17
# Number of unique colors in 'train/26575_gt.png': 17
# Number of unique colors in 'train/26600_gt.png': 18
# Number of unique colors in 'train/26625_gt.png': 16
# Number of unique colors in 'train/26650_gt.png': 20
# Number of unique colors in 'train/26675_gt.png': 18
# Number of unique colors in 'train/26700_gt.png': 19
# Number of unique colors in 'train/26725_gt.png': 17
# Number of unique colors in 'train/26750_gt.png': 17
# Number of unique colors in 'train/26775_gt.png': 17
# Number of unique colors in 'train/26800_gt.png': 20
# Number of unique colors in 'train/26825_gt.png': 20
# Number of unique colors in 'train/26925_gt.png': 15
# Number of unique colors in 'train/26950_gt.png': 19
# Number of unique colors in 'train/26975_gt.png': 18
# Number of unique colors in 'train/27000_gt.png': 17
# Number of unique colors in 'train/2700_gt.png': 12
# Number of unique colors in 'train/27025_gt.png': 16
# Number of unique colors in 'train/27050_gt.png': 16
# Number of unique colors in 'train/27075_gt.png': 16
# Number of unique colors in 'train/27100_gt.png': 18
# Number of unique colors in 'train/27125_gt.png': 16
# Number of unique colors in 'train/27150_gt.png': 16
# Number of unique colors in 'train/27175_gt.png': 15
# Number of unique colors in 'train/27200_gt.png': 17
# Number of unique colors in 'train/27225_gt.png': 17
# Number of unique colors in 'train/27250_gt.png': 17
# Number of unique colors in 'train/27275_gt.png': 16
# Number of unique colors in 'train/27300_gt.png': 17
# Number of unique colors in 'train/27325_gt.png': 16
# Number of unique colors in 'train/27575_gt.png': 16
# Number of unique colors in 'train/27600_gt.png': 16
# Number of unique colors in 'train/27625_gt.png': 17
# Number of unique colors in 'train/27650_gt.png': 16
# Number of unique colors in 'train/27675_gt.png': 16
# Number of unique colors in 'train/27700_gt.png': 16
# Number of unique colors in 'train/28000_gt.png': 18
# Number of unique colors in 'train/28025_gt.png': 18
# Number of unique colors in 'train/28050_gt.png': 16
# Number of unique colors in 'train/28075_gt.png': 18
# Number of unique colors in 'train/28100_gt.png': 18
# Number of unique colors in 'train/28125_gt.png': 18
# Number of unique colors in 'train/28150_gt.png': 16
# Number of unique colors in 'train/28175_gt.png': 17
# Number of unique colors in 'train/28200_gt.png': 17
# Number of unique colors in 'train/2950_gt.png': 12
# Number of unique colors in 'train/30500_gt.png': 9
# Number of unique colors in 'train/30600_gt.png': 15
# Number of unique colors in 'train/30625_gt.png': 15
# Number of unique colors in 'train/30650_gt.png': 14
# Number of unique colors in 'train/30675_gt.png': 16
# Number of unique colors in 'train/30700_gt.png': 13
# Number of unique colors in 'train/30725_gt.png': 10
# Number of unique colors in 'train/30750_gt.png': 13
# Number of unique colors in 'train/30775_gt.png': 14
# Number of unique colors in 'train/30800_gt.png': 10
# Number of unique colors in 'train/30825_gt.png': 10
# Number of unique colors in 'train/30850_gt.png': 10
# Number of unique colors in 'train/30875_gt.png': 11
# Number of unique colors in 'train/30900_gt.png': 12
# Number of unique colors in 'train/30975_gt.png': 9
# Number of unique colors in 'train/31725_gt.png': 10
# Number of unique colors in 'train/31975_gt.png': 9
# Number of unique colors in 'train/32225_gt.png': 9
# Number of unique colors in 'train/32450_gt.png': 9
# Number of unique colors in 'train/32700_gt.png': 8
# Number of unique colors in 'train/33200_gt.png': 10
# Number of unique colors in 'train/33700_gt.png': 7
# Number of unique colors in 'train/34425_gt.png': 9
# Number of unique colors in 'train/4050_gt.png': 13
# Number of unique colors in 'train/4075_gt.png': 12
# Number of unique colors in 'train/4100_gt.png': 13
# Number of unique colors in 'train/4125_gt.png': 11
# Number of unique colors in 'train/4150_gt.png': 12
# Number of unique colors in 'train/4175_gt.png': 12
# Number of unique colors in 'train/44025_gt.png': 8
# Number of unique colors in 'train/4425_gt.png': 15
# Number of unique colors in 'train/44525_gt.png': 13
# Number of unique colors in 'train/45000_gt.png': 13
# Number of unique colors in 'train/45500_gt.png': 11
# Number of unique colors in 'train/45750_gt.png': 8
# Number of unique colors in 'train/46225_gt.png': 8
# Number of unique colors in 'train/46725_gt.png': 4
# Number of unique colors in 'train/47225_gt.png': 9
# Number of unique colors in 'train/47475_gt.png': 6
# Number of unique colors in 'train/475_gt.png': 13
# Number of unique colors in 'train/47700_gt.png': 7
# Number of unique colors in 'train/48200_gt.png': 13
# Number of unique colors in 'train/48950_gt.png': 6
# Number of unique colors in 'train/4900_gt.png': 15
# Number of unique colors in 'train/4950_gt.png': 15
# Number of unique colors in 'train/4975_gt.png': 16
# Number of unique colors in 'train/5000_gt.png': 17
# Number of unique colors in 'train/5025_gt.png': 15
# Number of unique colors in 'train/5050_gt.png': 13
# Number of unique colors in 'train/5075_gt.png': 14
# Number of unique colors in 'train/5100_gt.png': 14
# Number of unique colors in 'train/5125_gt.png': 12
# Number of unique colors in 'train/5150_gt.png': 15
# Number of unique colors in 'train/5175_gt.png': 15
# Number of unique colors in 'train/53100_gt.png': 9
# Number of unique colors in 'train/53125_gt.png': 8
# Number of unique colors in 'train/53150_gt.png': 8
# Number of unique colors in 'train/53175_gt.png': 7
# Number of unique colors in 'train/53200_gt.png': 9
# Number of unique colors in 'train/53225_gt.png': 10
# Number of unique colors in 'train/53275_gt.png': 10
# Number of unique colors in 'train/53300_gt.png': 11
# Number of unique colors in 'train/53325_gt.png': 11
# Number of unique colors in 'train/53875_gt.png': 17
# Number of unique colors in 'train/53900_gt.png': 18
# Number of unique colors in 'train/53925_gt.png': 16
# Number of unique colors in 'train/53950_gt.png': 19
# Number of unique colors in 'train/53975_gt.png': 19
# Number of unique colors in 'train/54000_gt.png': 16
# Number of unique colors in 'train/5400_gt.png': 16
# Number of unique colors in 'train/54025_gt.png': 19
# Number of unique colors in 'train/54050_gt.png': 18
# Number of unique colors in 'train/54075_gt.png': 21
# Number of unique colors in 'train/54100_gt.png': 20
# Number of unique colors in 'train/54125_gt.png': 21
# Number of unique colors in 'train/54150_gt.png': 19
# Number of unique colors in 'train/54175_gt.png': 19
# Number of unique colors in 'train/54225_gt.png': 21
# Number of unique colors in 'train/54250_gt.png': 19
# Number of unique colors in 'train/54275_gt.png': 21
# Number of unique colors in 'train/54300_gt.png': 19
# Number of unique colors in 'train/54325_gt.png': 19
# Number of unique colors in 'train/54350_gt.png': 20
# Number of unique colors in 'train/54375_gt.png': 19
# Number of unique colors in 'train/54400_gt.png': 18
# Number of unique colors in 'train/55000_gt.png': 14
# Number of unique colors in 'train/55025_gt.png': 15
# Number of unique colors in 'train/55050_gt.png': 15
# Number of unique colors in 'train/55075_gt.png': 16
# Number of unique colors in 'train/55100_gt.png': 15
# Number of unique colors in 'train/55125_gt.png': 16
# Number of unique colors in 'train/55150_gt.png': 16
# Number of unique colors in 'train/55175_gt.png': 15
# Number of unique colors in 'train/55200_gt.png': 16
# Number of unique colors in 'train/55225_gt.png': 13
# Number of unique colors in 'train/55250_gt.png': 14
# Number of unique colors in 'train/55275_gt.png': 16
# Number of unique colors in 'train/55300_gt.png': 16
# Number of unique colors in 'train/55875_gt.png': 10
# Number of unique colors in 'train/55900_gt.png': 10
# Number of unique colors in 'train/55925_gt.png': 10
# Number of unique colors in 'train/55950_gt.png': 12
# Number of unique colors in 'train/55975_gt.png': 12
# Number of unique colors in 'train/56000_gt.png': 13
# Number of unique colors in 'train/56025_gt.png': 11
# Number of unique colors in 'train/56050_gt.png': 11
# Number of unique colors in 'train/56075_gt.png': 13
# Number of unique colors in 'train/56100_gt.png': 13
# Number of unique colors in 'train/5900_gt.png': 13
# Number of unique colors in 'train/6550_gt.png': 12
# Number of unique colors in 'train/6575_gt.png': 12
# Number of unique colors in 'train/6600_gt.png': 12
# Number of unique colors in 'train/6625_gt.png': 14
# Number of unique colors in 'train/6650_gt.png': 12
# Number of unique colors in 'train/6675_gt.png': 12
# Number of unique colors in 'train/6875_gt.png': 14
# Number of unique colors in 'train/7125_gt.png': 18
# Number of unique colors in 'train/7625_gt.png': 17
# Number of unique colors in 'train/9125_gt.png': 10
# Processing unique colors in 'test' Masks folder...
# Number of unique colors in 'test/00_gt.png': 10
# Number of unique colors in 'test/10075_gt.png': 14
# Number of unique colors in 'test/1225_gt.png': 10
# Number of unique colors in 'test/12550_gt.png': 12
# Number of unique colors in 'test/13700_gt.png': 12
# Number of unique colors in 'test/14000_gt.png': 10
# Number of unique colors in 'test/14500_gt.png': 16
# Number of unique colors in 'test/1475_gt.png': 11
# Number of unique colors in 'test/15250_gt.png': 9
# Number of unique colors in 'test/17700_gt.png': 13
# Number of unique colors in 'test/1950_gt.png': 12
# Number of unique colors in 'test/20400_gt.png': 13
# Number of unique colors in 'test/21150_gt.png': 14
# Number of unique colors in 'test/21400_gt.png': 15
# Number of unique colors in 'test/22125_gt.png': 12
# Number of unique colors in 'test/225_gt.png': 8
# Number of unique colors in 'test/22625_gt.png': 10
# Number of unique colors in 'test/2275_gt.png': 15
# Number of unique colors in 'test/22875_gt.png': 13
# Number of unique colors in 'test/23100_gt.png': 17
# Number of unique colors in 'test/23350_gt.png': 15
# Number of unique colors in 'test/23600_gt.png': 18
# Number of unique colors in 'test/2450_gt.png': 11
# Number of unique colors in 'test/30000_gt.png': 9
# Number of unique colors in 'test/30250_gt.png': 9
# Number of unique colors in 'test/30750_gt.png': 9
# Number of unique colors in 'test/31225_gt.png': 10
# Number of unique colors in 'test/31475_gt.png': 10
# Number of unique colors in 'test/3175_gt.png': 11
# Number of unique colors in 'test/32950_gt.png': 9
# Number of unique colors in 'test/33450_gt.png': 7
# Number of unique colors in 'test/33925_gt.png': 9
# Number of unique colors in 'test/34175_gt.png': 11
# Number of unique colors in 'test/3425_gt.png': 10
# Number of unique colors in 'test/34675_gt.png': 8
# Number of unique colors in 'test/3675_gt.png': 10
# Number of unique colors in 'test/3925_gt.png': 14
# Number of unique colors in 'test/4175_gt.png': 17
# Number of unique colors in 'test/44275_gt.png': 9
# Number of unique colors in 'test/44750_gt.png': 12
# Number of unique colors in 'test/45250_gt.png': 13
# Number of unique colors in 'test/4550_gt.png': 15
# Number of unique colors in 'test/46000_gt.png': 11
# Number of unique colors in 'test/46475_gt.png': 4
# Number of unique colors in 'test/4650_gt.png': 15
# Number of unique colors in 'test/46975_gt.png': 6
# Number of unique colors in 'test/47950_gt.png': 8
# Number of unique colors in 'test/48450_gt.png': 6
# Number of unique colors in 'test/48700_gt.png': 14
# Number of unique colors in 'test/49200_gt.png': 2
# Number of unique colors in 'test/5150_gt.png': 15
# Number of unique colors in 'test/5650_gt.png': 11
# Number of unique colors in 'test/5700_gt.png': 15
# Number of unique colors in 'test/6150_gt.png': 16
# Number of unique colors in 'test/6375_gt.png': 15
# Number of unique colors in 'test/6850_gt.png': 10
# Number of unique colors in 'test/725_gt.png': 9
# Number of unique colors in 'test/7375_gt.png': 13
# Number of unique colors in 'test/7850_gt.png': 17
# Number of unique colors in 'test/7975_gt.png': 11
# Number of unique colors in 'test/8100_gt.png': 14
# Number of unique colors in 'test/975_gt.png': 10

# %%
# Function to get unique colors in an image
def get_unique_colors(image_path):
    image = Image.open(image_path).convert('RGB')  # Open the image and ensure it's in RGB mode
    unique_colors = image.getcolors(maxcolors=1000000)  # Set a high limit to get all unique colors
    return {color[1] for color in unique_colors} if unique_colors else set()  # Extract only color values as a set

# Store overall unique colors for each dataset split
overall_unique_colors = {
    "trainval": set(),
    "train": set(),
    "test": set()
}

# Process each dataset split and collect unique colors across all masks
for split, masks_dir in dataset_folders.items():
    print(f"Collecting unique colors in '{split}' Masks folder...")
    for filename in os.listdir(masks_dir):
        mask_path = os.path.join(masks_dir, filename)
        if os.path.isfile(mask_path):
            unique_colors = get_unique_colors(mask_path)
            overall_unique_colors[split].update(unique_colors)

# Print overall unique colors found in each dataset split
for split, colors in overall_unique_colors.items():
    print(f"\nOverall unique colors in '{split}' Masks folder: {sorted(colors)}")
# Out:
# Collecting unique colors in 'trainval' Masks folder...
# Collecting unique colors in 'train' Masks folder...
# Collecting unique colors in 'test' Masks folder...
#
# Overall unique colors in 'trainval' Masks folder: [(0, 0, 0), (0, 85, 170), (0, 85, 255), (0, 170, 0), (0, 170, 85), (0, 170, 170), (0, 255, 85), (0, 255, 170), (85, 0, 170), (85, 0, 255), (85, 85, 0), (85, 85, 85), (85, 85, 170), (85, 85, 255), (85, 170, 0), (85, 170, 85), (85, 170, 170), (85, 170, 255), (85, 255, 0), (85, 255, 85), (85, 255, 170), (170, 0, 0), (170, 0, 85), (170, 0, 170), (170, 0, 255), (170, 85, 0), (170, 85, 85), (170, 85, 170), (170, 170, 0), (170, 170, 85), (170, 170, 170), (255, 0, 0), (255, 0, 255), (255, 85, 0), (255, 255, 0), (255, 255, 255)]
#
# Overall unique colors in 'train' Masks folder: [(0, 0, 0), (0, 85, 170), (0, 85, 255), (0, 170, 0), (0, 170, 85), (0, 170, 170), (0, 255, 85), (0, 255, 170), (85, 0, 170), (85, 0, 255), (85, 85, 0), (85, 85, 85), (85, 85, 170), (85, 85, 255), (85, 170, 0), (85, 170, 85), (85, 170, 170), (85, 170, 255), (85, 255, 0), (85, 255, 85), (85, 255, 170), (170, 0, 85), (170, 0, 170), (170, 0, 255), (170, 85, 0), (170, 85, 85), (170, 85, 170), (170, 170, 0), (170, 170, 85), (170, 170, 170), (255, 0, 0), (255, 0, 255), (255, 85, 0), (255, 255, 0), (255, 255, 255)]
#
# Overall unique colors in 'test' Masks folder: [(0, 0, 0), (0, 85, 170), (0, 85, 255), (0, 170, 85), (0, 170, 170), (0, 255, 85), (0, 255, 170), (85, 0, 170), (85, 0, 255), (85, 85, 0), (85, 85, 85), (85, 85, 170), (85, 85, 255), (85, 170, 0), (85, 170, 85), (85, 170, 170), (85, 170, 255), (85, 255, 0), (85, 255, 85), (85, 255, 170), (170, 0, 0), (170, 0, 85), (170, 0, 170), (170, 0, 255), (170, 85, 0), (170, 85, 85), (170, 85, 170), (170, 170, 0), (170, 170, 85), (170, 170, 170), (255, 0, 0), (255, 0, 255), (255, 85, 0), (255, 255, 0), (255, 255, 255)]

# %% [markdown]
# ## Grey-scaling each of the masks into each of its unique colors

# %%
# Function to create a grayscale mask for each unique color in a mask image
def create_grayscale_masks(image_path, output_base_dir):
    # Open the image
    image = Image.open(image_path).convert('RGB')
    width, height = image.size

    # Get unique colors in the image
    unique_colors = image.getcolors(maxcolors=width * height)
    if unique_colors is None:
        print(f"Too many unique colors in '{image_path}' to process.")
        return

    # Create a grayscale mask for each unique color
    for color_count, color in unique_colors:
        # Define directory for this unique color
        color_dir = os.path.join(output_base_dir, f"{color}")
        os.makedirs(color_dir, exist_ok=True)

        # Create a new grayscale image for the color mask
        grayscale_image = Image.new('L', (width, height), 0)  # 'L' mode for grayscale
        original_pixels = image.load()
        grayscale_pixels = grayscale_image.load()

        # Set pixels matching the unique color to 255, others to 0
        for y in range(height):
            for x in range(width):
                if original_pixels[x, y] == color:
                    grayscale_pixels[x, y] = 255

        # Save the grayscale mask image in the unique color's folder
        base_filename = os.path.basename(image_path)
        grayscale_image.save(os.path.join(color_dir, base_filename))

# Process each dataset split and generate grayscale masks for each unique color
for split, masks_dir in dataset_folders.items():
    print(f"Processing grayscale masks for '{split}' Masks folder...")
    for filename in os.listdir(masks_dir):
        mask_path = os.path.join(masks_dir, filename)
        if os.path.isfile(mask_path):
            create_grayscale_masks(mask_path, masks_dir)
            print(f"Generated grayscale masks for unique colors in '{split}/{filename}'")
# Out:
# Processing grayscale masks for 'trainval' Masks folder...
# Generated grayscale masks for unique colors in 'trainval/00_gt.png'
# Generated grayscale masks for unique colors in 'trainval/015975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/030750_gt.png'
# Generated grayscale masks for unique colors in 'trainval/03425_gt.png'
# Generated grayscale masks for unique colors in 'trainval/04175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/05150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/06625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/0_gt.png'
# Generated grayscale masks for unique colors in 'trainval/10075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/10275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/1125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/11400_gt.png'
# Generated grayscale masks for unique colors in 'trainval/1225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/12550_gt.png'
# Generated grayscale masks for unique colors in 'trainval/13025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/13700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/14000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/14500_gt.png'
# Generated grayscale masks for unique colors in 'trainval/1475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/14825_gt.png'
# Generated grayscale masks for unique colors in 'trainval/15250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/15975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/16475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/1700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/17700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/18925_gt.png'
# Generated grayscale masks for unique colors in 'trainval/1950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/20400_gt.png'
# Generated grayscale masks for unique colors in 'trainval/20650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/20900_gt.png'
# Generated grayscale masks for unique colors in 'trainval/21150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/21400_gt.png'
# Generated grayscale masks for unique colors in 'trainval/21625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/21875_gt.png'
# Generated grayscale masks for unique colors in 'trainval/2200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/22125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/22375_gt.png'
# Generated grayscale masks for unique colors in 'trainval/225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/22625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/2275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/22875_gt.png'
# Generated grayscale masks for unique colors in 'trainval/23100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/23350_gt.png'
# Generated grayscale masks for unique colors in 'trainval/23600_gt.png'
# Generated grayscale masks for unique colors in 'trainval/23850_gt.png'
# Generated grayscale masks for unique colors in 'trainval/2450_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25300_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25325_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25350_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25375_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25400_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25425_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25450_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25500_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25525_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25550_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25575_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25600_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25675_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25725_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25775_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25800_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25825_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25850_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25875_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25900_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25925_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/25975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26300_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26325_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26350_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26375_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26400_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26425_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26450_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26500_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26525_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26550_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26575_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26600_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26675_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26725_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26750_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26775_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26800_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26825_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26925_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/26975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/2700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27300_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27325_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27575_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27600_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27675_gt.png'
# Generated grayscale masks for unique colors in 'trainval/27700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/28200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/2950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30500_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30600_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30675_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30725_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30750_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30775_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30800_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30825_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30850_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30875_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30900_gt.png'
# Generated grayscale masks for unique colors in 'trainval/30975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/31225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/31475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/31725_gt.png'
# Generated grayscale masks for unique colors in 'trainval/3175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/31975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/32225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/32450_gt.png'
# Generated grayscale masks for unique colors in 'trainval/32700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/32950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/33200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/33450_gt.png'
# Generated grayscale masks for unique colors in 'trainval/33700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/33925_gt.png'
# Generated grayscale masks for unique colors in 'trainval/34175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/3425_gt.png'
# Generated grayscale masks for unique colors in 'trainval/34425_gt.png'
# Generated grayscale masks for unique colors in 'trainval/34675_gt.png'
# Generated grayscale masks for unique colors in 'trainval/3675_gt.png'
# Generated grayscale masks for unique colors in 'trainval/3925_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/44025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4425_gt.png'
# Generated grayscale masks for unique colors in 'trainval/44275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/44525_gt.png'
# Generated grayscale masks for unique colors in 'trainval/44750_gt.png'
# Generated grayscale masks for unique colors in 'trainval/45000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/45250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/45500_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4550_gt.png'
# Generated grayscale masks for unique colors in 'trainval/45750_gt.png'
# Generated grayscale masks for unique colors in 'trainval/46000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/46225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/46475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/46725_gt.png'
# Generated grayscale masks for unique colors in 'trainval/46975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/47225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/47475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/475_gt.png'
# Generated grayscale masks for unique colors in 'trainval/47700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/47950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/48200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/48450_gt.png'
# Generated grayscale masks for unique colors in 'trainval/48700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/48950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4900_gt.png'
# Generated grayscale masks for unique colors in 'trainval/49200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/4975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53300_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53325_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53875_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53900_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53925_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/53975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5400_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54300_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54325_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54350_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54375_gt.png'
# Generated grayscale masks for unique colors in 'trainval/54400_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55175_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55200_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55225_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55250_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55275_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55300_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55875_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55900_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55925_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55950_gt.png'
# Generated grayscale masks for unique colors in 'trainval/55975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/56000_gt.png'
# Generated grayscale masks for unique colors in 'trainval/56025_gt.png'
# Generated grayscale masks for unique colors in 'trainval/56050_gt.png'
# Generated grayscale masks for unique colors in 'trainval/56075_gt.png'
# Generated grayscale masks for unique colors in 'trainval/56100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5700_gt.png'
# Generated grayscale masks for unique colors in 'trainval/5900_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6150_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6375_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6550_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6575_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6600_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6650_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6675_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6850_gt.png'
# Generated grayscale masks for unique colors in 'trainval/6875_gt.png'
# Generated grayscale masks for unique colors in 'trainval/7125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/725_gt.png'
# Generated grayscale masks for unique colors in 'trainval/7375_gt.png'
# Generated grayscale masks for unique colors in 'trainval/7625_gt.png'
# Generated grayscale masks for unique colors in 'trainval/7850_gt.png'
# Generated grayscale masks for unique colors in 'trainval/7975_gt.png'
# Generated grayscale masks for unique colors in 'trainval/8100_gt.png'
# Generated grayscale masks for unique colors in 'trainval/9125_gt.png'
# Generated grayscale masks for unique colors in 'trainval/975_gt.png'
# Processing grayscale masks for 'train' Masks folder...
# Generated grayscale masks for unique colors in 'train/015975_gt.png'
# Generated grayscale masks for unique colors in 'train/03425_gt.png'
# Generated grayscale masks for unique colors in 'train/06625_gt.png'
# Generated grayscale masks for unique colors in 'train/0_gt.png'
# Generated grayscale masks for unique colors in 'train/10275_gt.png'
# Generated grayscale masks for unique colors in 'train/1125_gt.png'
# Generated grayscale masks for unique colors in 'train/11400_gt.png'
# Generated grayscale masks for unique colors in 'train/13025_gt.png'
# Generated grayscale masks for unique colors in 'train/14825_gt.png'
# Generated grayscale masks for unique colors in 'train/15975_gt.png'
# Generated grayscale masks for unique colors in 'train/16475_gt.png'
# Generated grayscale masks for unique colors in 'train/1700_gt.png'
# Generated grayscale masks for unique colors in 'train/18925_gt.png'
# Generated grayscale masks for unique colors in 'train/20650_gt.png'
# Generated grayscale masks for unique colors in 'train/20900_gt.png'
# Generated grayscale masks for unique colors in 'train/21625_gt.png'
# Generated grayscale masks for unique colors in 'train/21875_gt.png'
# Generated grayscale masks for unique colors in 'train/2200_gt.png'
# Generated grayscale masks for unique colors in 'train/22375_gt.png'
# Generated grayscale masks for unique colors in 'train/23850_gt.png'
# Generated grayscale masks for unique colors in 'train/25025_gt.png'
# Generated grayscale masks for unique colors in 'train/25050_gt.png'
# Generated grayscale masks for unique colors in 'train/25075_gt.png'
# Generated grayscale masks for unique colors in 'train/25100_gt.png'
# Generated grayscale masks for unique colors in 'train/25125_gt.png'
# Generated grayscale masks for unique colors in 'train/25150_gt.png'
# Generated grayscale masks for unique colors in 'train/25175_gt.png'
# Generated grayscale masks for unique colors in 'train/25200_gt.png'
# Generated grayscale masks for unique colors in 'train/25225_gt.png'
# Generated grayscale masks for unique colors in 'train/25250_gt.png'
# Generated grayscale masks for unique colors in 'train/25275_gt.png'
# Generated grayscale masks for unique colors in 'train/25300_gt.png'
# Generated grayscale masks for unique colors in 'train/25325_gt.png'
# Generated grayscale masks for unique colors in 'train/25350_gt.png'
# Generated grayscale masks for unique colors in 'train/25375_gt.png'
# Generated grayscale masks for unique colors in 'train/25400_gt.png'
# Generated grayscale masks for unique colors in 'train/25425_gt.png'
# Generated grayscale masks for unique colors in 'train/25450_gt.png'
# Generated grayscale masks for unique colors in 'train/25475_gt.png'
# Generated grayscale masks for unique colors in 'train/25500_gt.png'
# Generated grayscale masks for unique colors in 'train/25525_gt.png'
# Generated grayscale masks for unique colors in 'train/25550_gt.png'
# Generated grayscale masks for unique colors in 'train/25575_gt.png'
# Generated grayscale masks for unique colors in 'train/25600_gt.png'
# Generated grayscale masks for unique colors in 'train/25625_gt.png'
# Generated grayscale masks for unique colors in 'train/25650_gt.png'
# Generated grayscale masks for unique colors in 'train/25675_gt.png'
# Generated grayscale masks for unique colors in 'train/25700_gt.png'
# Generated grayscale masks for unique colors in 'train/25725_gt.png'
# Generated grayscale masks for unique colors in 'train/25775_gt.png'
# Generated grayscale masks for unique colors in 'train/25800_gt.png'
# Generated grayscale masks for unique colors in 'train/25825_gt.png'
# Generated grayscale masks for unique colors in 'train/25850_gt.png'
# Generated grayscale masks for unique colors in 'train/25875_gt.png'
# Generated grayscale masks for unique colors in 'train/25900_gt.png'
# Generated grayscale masks for unique colors in 'train/25925_gt.png'
# Generated grayscale masks for unique colors in 'train/25950_gt.png'
# Generated grayscale masks for unique colors in 'train/25975_gt.png'
# Generated grayscale masks for unique colors in 'train/26000_gt.png'
# Generated grayscale masks for unique colors in 'train/26025_gt.png'
# Generated grayscale masks for unique colors in 'train/26050_gt.png'
# Generated grayscale masks for unique colors in 'train/26075_gt.png'
# Generated grayscale masks for unique colors in 'train/26100_gt.png'
# Generated grayscale masks for unique colors in 'train/26125_gt.png'
# Generated grayscale masks for unique colors in 'train/26150_gt.png'
# Generated grayscale masks for unique colors in 'train/26175_gt.png'
# Generated grayscale masks for unique colors in 'train/26200_gt.png'
# Generated grayscale masks for unique colors in 'train/26225_gt.png'
# Generated grayscale masks for unique colors in 'train/26250_gt.png'
# Generated grayscale masks for unique colors in 'train/26275_gt.png'
# Generated grayscale masks for unique colors in 'train/26300_gt.png'
# Generated grayscale masks for unique colors in 'train/26325_gt.png'
# Generated grayscale masks for unique colors in 'train/26350_gt.png'
# Generated grayscale masks for unique colors in 'train/26375_gt.png'
# Generated grayscale masks for unique colors in 'train/26400_gt.png'
# Generated grayscale masks for unique colors in 'train/26425_gt.png'
# Generated grayscale masks for unique colors in 'train/26450_gt.png'
# Generated grayscale masks for unique colors in 'train/26475_gt.png'
# Generated grayscale masks for unique colors in 'train/26500_gt.png'
# Generated grayscale masks for unique colors in 'train/26525_gt.png'
# Generated grayscale masks for unique colors in 'train/26550_gt.png'
# Generated grayscale masks for unique colors in 'train/26575_gt.png'
# Generated grayscale masks for unique colors in 'train/26600_gt.png'
# Generated grayscale masks for unique colors in 'train/26625_gt.png'
# Generated grayscale masks for unique colors in 'train/26650_gt.png'
# Generated grayscale masks for unique colors in 'train/26675_gt.png'
# Generated grayscale masks for unique colors in 'train/26700_gt.png'
# Generated grayscale masks for unique colors in 'train/26725_gt.png'
# Generated grayscale masks for unique colors in 'train/26750_gt.png'
# Generated grayscale masks for unique colors in 'train/26775_gt.png'
# Generated grayscale masks for unique colors in 'train/26800_gt.png'
# Generated grayscale masks for unique colors in 'train/26825_gt.png'
# Generated grayscale masks for unique colors in 'train/26925_gt.png'
# Generated grayscale masks for unique colors in 'train/26950_gt.png'
# Generated grayscale masks for unique colors in 'train/26975_gt.png'
# Generated grayscale masks for unique colors in 'train/27000_gt.png'
# Generated grayscale masks for unique colors in 'train/2700_gt.png'
# Generated grayscale masks for unique colors in 'train/27025_gt.png'
# Generated grayscale masks for unique colors in 'train/27050_gt.png'
# Generated grayscale masks for unique colors in 'train/27075_gt.png'
# Generated grayscale masks for unique colors in 'train/27100_gt.png'
# Generated grayscale masks for unique colors in 'train/27125_gt.png'
# Generated grayscale masks for unique colors in 'train/27150_gt.png'
# Generated grayscale masks for unique colors in 'train/27175_gt.png'
# Generated grayscale masks for unique colors in 'train/27200_gt.png'
# Generated grayscale masks for unique colors in 'train/27225_gt.png'
# Generated grayscale masks for unique colors in 'train/27250_gt.png'
# Generated grayscale masks for unique colors in 'train/27275_gt.png'
# Generated grayscale masks for unique colors in 'train/27300_gt.png'
# Generated grayscale masks for unique colors in 'train/27325_gt.png'
# Generated grayscale masks for unique colors in 'train/27575_gt.png'
# Generated grayscale masks for unique colors in 'train/27600_gt.png'
# Generated grayscale masks for unique colors in 'train/27625_gt.png'
# Generated grayscale masks for unique colors in 'train/27650_gt.png'
# Generated grayscale masks for unique colors in 'train/27675_gt.png'
# Generated grayscale masks for unique colors in 'train/27700_gt.png'
# Generated grayscale masks for unique colors in 'train/28000_gt.png'
# Generated grayscale masks for unique colors in 'train/28025_gt.png'
# Generated grayscale masks for unique colors in 'train/28050_gt.png'
# Generated grayscale masks for unique colors in 'train/28075_gt.png'
# Generated grayscale masks for unique colors in 'train/28100_gt.png'
# Generated grayscale masks for unique colors in 'train/28125_gt.png'
# Generated grayscale masks for unique colors in 'train/28150_gt.png'
# Generated grayscale masks for unique colors in 'train/28175_gt.png'
# Generated grayscale masks for unique colors in 'train/28200_gt.png'
# Generated grayscale masks for unique colors in 'train/2950_gt.png'
# Generated grayscale masks for unique colors in 'train/30500_gt.png'
# Generated grayscale masks for unique colors in 'train/30600_gt.png'
# Generated grayscale masks for unique colors in 'train/30625_gt.png'
# Generated grayscale masks for unique colors in 'train/30650_gt.png'
# Generated grayscale masks for unique colors in 'train/30675_gt.png'
# Generated grayscale masks for unique colors in 'train/30700_gt.png'
# Generated grayscale masks for unique colors in 'train/30725_gt.png'
# Generated grayscale masks for unique colors in 'train/30750_gt.png'
# Generated grayscale masks for unique colors in 'train/30775_gt.png'
# Generated grayscale masks for unique colors in 'train/30800_gt.png'
# Generated grayscale masks for unique colors in 'train/30825_gt.png'
# Generated grayscale masks for unique colors in 'train/30850_gt.png'
# Generated grayscale masks for unique colors in 'train/30875_gt.png'
# Generated grayscale masks for unique colors in 'train/30900_gt.png'
# Generated grayscale masks for unique colors in 'train/30975_gt.png'
# Generated grayscale masks for unique colors in 'train/31725_gt.png'
# Generated grayscale masks for unique colors in 'train/31975_gt.png'
# Generated grayscale masks for unique colors in 'train/32225_gt.png'
# Generated grayscale masks for unique colors in 'train/32450_gt.png'
# Generated grayscale masks for unique colors in 'train/32700_gt.png'
# Generated grayscale masks for unique colors in 'train/33200_gt.png'
# Generated grayscale masks for unique colors in 'train/33700_gt.png'
# Generated grayscale masks for unique colors in 'train/34425_gt.png'
# Generated grayscale masks for unique colors in 'train/4050_gt.png'
# Generated grayscale masks for unique colors in 'train/4075_gt.png'
# Generated grayscale masks for unique colors in 'train/4100_gt.png'
# Generated grayscale masks for unique colors in 'train/4125_gt.png'
# Generated grayscale masks for unique colors in 'train/4150_gt.png'
# Generated grayscale masks for unique colors in 'train/4175_gt.png'
# Generated grayscale masks for unique colors in 'train/44025_gt.png'
# Generated grayscale masks for unique colors in 'train/4425_gt.png'
# Generated grayscale masks for unique colors in 'train/44525_gt.png'
# Generated grayscale masks for unique colors in 'train/45000_gt.png'
# Generated grayscale masks for unique colors in 'train/45500_gt.png'
# Generated grayscale masks for unique colors in 'train/45750_gt.png'
# Generated grayscale masks for unique colors in 'train/46225_gt.png'
# Generated grayscale masks for unique colors in 'train/46725_gt.png'
# Generated grayscale masks for unique colors in 'train/47225_gt.png'
# Generated grayscale masks for unique colors in 'train/47475_gt.png'
# Generated grayscale masks for unique colors in 'train/475_gt.png'
# Generated grayscale masks for unique colors in 'train/47700_gt.png'
# Generated grayscale masks for unique colors in 'train/48200_gt.png'
# Generated grayscale masks for unique colors in 'train/48950_gt.png'
# Generated grayscale masks for unique colors in 'train/4900_gt.png'
# Generated grayscale masks for unique colors in 'train/4950_gt.png'
# Generated grayscale masks for unique colors in 'train/4975_gt.png'
# Generated grayscale masks for unique colors in 'train/5000_gt.png'
# Generated grayscale masks for unique colors in 'train/5025_gt.png'
# Generated grayscale masks for unique colors in 'train/5050_gt.png'
# Generated grayscale masks for unique colors in 'train/5075_gt.png'
# Generated grayscale masks for unique colors in 'train/5100_gt.png'
# Generated grayscale masks for unique colors in 'train/5125_gt.png'
# Generated grayscale masks for unique colors in 'train/5150_gt.png'
# Generated grayscale masks for unique colors in 'train/5175_gt.png'
# Generated grayscale masks for unique colors in 'train/53100_gt.png'
# Generated grayscale masks for unique colors in 'train/53125_gt.png'
# Generated grayscale masks for unique colors in 'train/53150_gt.png'
# Generated grayscale masks for unique colors in 'train/53175_gt.png'
# Generated grayscale masks for unique colors in 'train/53200_gt.png'
# Generated grayscale masks for unique colors in 'train/53225_gt.png'
# Generated grayscale masks for unique colors in 'train/53275_gt.png'
# Generated grayscale masks for unique colors in 'train/53300_gt.png'
# Generated grayscale masks for unique colors in 'train/53325_gt.png'
# Generated grayscale masks for unique colors in 'train/53875_gt.png'
# Generated grayscale masks for unique colors in 'train/53900_gt.png'
# Generated grayscale masks for unique colors in 'train/53925_gt.png'
# Generated grayscale masks for unique colors in 'train/53950_gt.png'
# Generated grayscale masks for unique colors in 'train/53975_gt.png'
# Generated grayscale masks for unique colors in 'train/54000_gt.png'
# Generated grayscale masks for unique colors in 'train/5400_gt.png'
# Generated grayscale masks for unique colors in 'train/54025_gt.png'
# Generated grayscale masks for unique colors in 'train/54050_gt.png'
# Generated grayscale masks for unique colors in 'train/54075_gt.png'
# Generated grayscale masks for unique colors in 'train/54100_gt.png'
# Generated grayscale masks for unique colors in 'train/54125_gt.png'
# Generated grayscale masks for unique colors in 'train/54150_gt.png'
# Generated grayscale masks for unique colors in 'train/54175_gt.png'
# Generated grayscale masks for unique colors in 'train/54225_gt.png'
# Generated grayscale masks for unique colors in 'train/54250_gt.png'
# Generated grayscale masks for unique colors in 'train/54275_gt.png'
# Generated grayscale masks for unique colors in 'train/54300_gt.png'
# Generated grayscale masks for unique colors in 'train/54325_gt.png'
# Generated grayscale masks for unique colors in 'train/54350_gt.png'
# Generated grayscale masks for unique colors in 'train/54375_gt.png'
# Generated grayscale masks for unique colors in 'train/54400_gt.png'
# Generated grayscale masks for unique colors in 'train/55000_gt.png'
# Generated grayscale masks for unique colors in 'train/55025_gt.png'
# Generated grayscale masks for unique colors in 'train/55050_gt.png'
# Generated grayscale masks for unique colors in 'train/55075_gt.png'
# Generated grayscale masks for unique colors in 'train/55100_gt.png'
# Generated grayscale masks for unique colors in 'train/55125_gt.png'
# Generated grayscale masks for unique colors in 'train/55150_gt.png'
# Generated grayscale masks for unique colors in 'train/55175_gt.png'
# Generated grayscale masks for unique colors in 'train/55200_gt.png'
# Generated grayscale masks for unique colors in 'train/55225_gt.png'
# Generated grayscale masks for unique colors in 'train/55250_gt.png'
# Generated grayscale masks for unique colors in 'train/55275_gt.png'
# Generated grayscale masks for unique colors in 'train/55300_gt.png'
# Generated grayscale masks for unique colors in 'train/55875_gt.png'
# Generated grayscale masks for unique colors in 'train/55900_gt.png'
# Generated grayscale masks for unique colors in 'train/55925_gt.png'
# Generated grayscale masks for unique colors in 'train/55950_gt.png'
# Generated grayscale masks for unique colors in 'train/55975_gt.png'
# Generated grayscale masks for unique colors in 'train/56000_gt.png'
# Generated grayscale masks for unique colors in 'train/56025_gt.png'
# Generated grayscale masks for unique colors in 'train/56050_gt.png'
# Generated grayscale masks for unique colors in 'train/56075_gt.png'
# Generated grayscale masks for unique colors in 'train/56100_gt.png'
# Generated grayscale masks for unique colors in 'train/5900_gt.png'
# Generated grayscale masks for unique colors in 'train/6550_gt.png'
# Generated grayscale masks for unique colors in 'train/6575_gt.png'
# Generated grayscale masks for unique colors in 'train/6600_gt.png'
# Generated grayscale masks for unique colors in 'train/6625_gt.png'
# Generated grayscale masks for unique colors in 'train/6650_gt.png'
# Generated grayscale masks for unique colors in 'train/6675_gt.png'
# Generated grayscale masks for unique colors in 'train/6875_gt.png'
# Generated grayscale masks for unique colors in 'train/7125_gt.png'
# Generated grayscale masks for unique colors in 'train/7625_gt.png'
# Generated grayscale masks for unique colors in 'train/9125_gt.png'
# Processing grayscale masks for 'test' Masks folder...
# Generated grayscale masks for unique colors in 'test/00_gt.png'
# Generated grayscale masks for unique colors in 'test/10075_gt.png'
# Generated grayscale masks for unique colors in 'test/1225_gt.png'
# Generated grayscale masks for unique colors in 'test/12550_gt.png'
# Generated grayscale masks for unique colors in 'test/13700_gt.png'
# Generated grayscale masks for unique colors in 'test/14000_gt.png'
# Generated grayscale masks for unique colors in 'test/14500_gt.png'
# Generated grayscale masks for unique colors in 'test/1475_gt.png'
# Generated grayscale masks for unique colors in 'test/15250_gt.png'
# Generated grayscale masks for unique colors in 'test/17700_gt.png'
# Generated grayscale masks for unique colors in 'test/1950_gt.png'
# Generated grayscale masks for unique colors in 'test/20400_gt.png'
# Generated grayscale masks for unique colors in 'test/21150_gt.png'
# Generated grayscale masks for unique colors in 'test/21400_gt.png'
# Generated grayscale masks for unique colors in 'test/22125_gt.png'
# Generated grayscale masks for unique colors in 'test/225_gt.png'
# Generated grayscale masks for unique colors in 'test/22625_gt.png'
# Generated grayscale masks for unique colors in 'test/2275_gt.png'
# Generated grayscale masks for unique colors in 'test/22875_gt.png'
# Generated grayscale masks for unique colors in 'test/23100_gt.png'
# Generated grayscale masks for unique colors in 'test/23350_gt.png'
# Generated grayscale masks for unique colors in 'test/23600_gt.png'
# Generated grayscale masks for unique colors in 'test/2450_gt.png'
# Generated grayscale masks for unique colors in 'test/30000_gt.png'
# Generated grayscale masks for unique colors in 'test/30250_gt.png'
# Generated grayscale masks for unique colors in 'test/30750_gt.png'
# Generated grayscale masks for unique colors in 'test/31225_gt.png'
# Generated grayscale masks for unique colors in 'test/31475_gt.png'
# Generated grayscale masks for unique colors in 'test/3175_gt.png'
# Generated grayscale masks for unique colors in 'test/32950_gt.png'
# Generated grayscale masks for unique colors in 'test/33450_gt.png'
# Generated grayscale masks for unique colors in 'test/33925_gt.png'
# Generated grayscale masks for unique colors in 'test/34175_gt.png'
# Generated grayscale masks for unique colors in 'test/3425_gt.png'
# Generated grayscale masks for unique colors in 'test/34675_gt.png'
# Generated grayscale masks for unique colors in 'test/3675_gt.png'
# Generated grayscale masks for unique colors in 'test/3925_gt.png'
# Generated grayscale masks for unique colors in 'test/4175_gt.png'
# Generated grayscale masks for unique colors in 'test/44275_gt.png'
# Generated grayscale masks for unique colors in 'test/44750_gt.png'
# Generated grayscale masks for unique colors in 'test/45250_gt.png'
# Generated grayscale masks for unique colors in 'test/4550_gt.png'
# Generated grayscale masks for unique colors in 'test/46000_gt.png'
# Generated grayscale masks for unique colors in 'test/46475_gt.png'
# Generated grayscale masks for unique colors in 'test/4650_gt.png'
# Generated grayscale masks for unique colors in 'test/46975_gt.png'
# Generated grayscale masks for unique colors in 'test/47950_gt.png'
# Generated grayscale masks for unique colors in 'test/48450_gt.png'
# Generated grayscale masks for unique colors in 'test/48700_gt.png'
# Generated grayscale masks for unique colors in 'test/49200_gt.png'
# Generated grayscale masks for unique colors in 'test/5150_gt.png'
# Generated grayscale masks for unique colors in 'test/5650_gt.png'
# Generated grayscale masks for unique colors in 'test/5700_gt.png'
# Generated grayscale masks for unique colors in 'test/6150_gt.png'
# Generated grayscale masks for unique colors in 'test/6375_gt.png'
# Generated grayscale masks for unique colors in 'test/6850_gt.png'
# Generated grayscale masks for unique colors in 'test/725_gt.png'
# Generated grayscale masks for unique colors in 'test/7375_gt.png'
# Generated grayscale masks for unique colors in 'test/7850_gt.png'
# Generated grayscale masks for unique colors in 'test/7975_gt.png'
# Generated grayscale masks for unique colors in 'test/8100_gt.png'
# Generated grayscale masks for unique colors in 'test/975_gt.png'

# %% [markdown]
# ## Based on the classses in (https://github.com/salmanmaq/segmentationNetworks/blob/master/datasets/miccaiSegClasses.json), we only kept those colored mask classes/folders

# %%
# List of allowed colors from the class list (in RGB format)
allowed_colors = [
    (170, 0, 85), (0, 85, 170), (0, 85, 255), (0, 170, 85), (0, 255, 85),
    (0, 255, 170), (85, 0, 170), (85, 0, 255), (170, 85, 85), (170, 170, 170),
    (85, 170, 0), (85, 170, 255), (85, 255, 0), (85, 255, 170), (170, 0, 255),
    (255, 0, 255), (255, 255, 0), (255, 0, 0), (0, 0, 0)
]

# Function to delete folders not in allowed colors
def remove_unwanted_color_folders(masks_dir):
    # Iterate over each folder in the Masks directory
    for folder_name in os.listdir(masks_dir):
        # Convert folder name to tuple for color comparison
        try:
            folder_color = tuple(map(int, folder_name.strip("()").split(",")))
        except ValueError:
            continue  # Skip if folder name is not in RGB format

        # Check if color is not in allowed colors
        if folder_color not in allowed_colors:
            folder_path = os.path.join(masks_dir, folder_name)
            shutil.rmtree(folder_path)
            print(f"Removed folder with unlisted color: {folder_path}")

# Process each dataset split's Masks folder
for split, masks_dir in dataset_folders.items():
    print(f"Cleaning up unwanted color folders in '{split}' Masks folder...")
    remove_unwanted_color_folders(masks_dir)

print("Unwanted color folders removed successfully.")
# Out:
# Cleaning up unwanted color folders in 'trainval' Masks folder...
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(0, 170, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(0, 170, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(170, 0, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(170, 0, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(170, 170, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(170, 170, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(170, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(170, 85, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(255, 255, 255)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(255, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(85, 170, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(85, 170, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(85, 255, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(85, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(85, 85, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(85, 85, 255)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\(85, 85, 85)
# Cleaning up unwanted color folders in 'train' Masks folder...
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(0, 170, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(0, 170, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(170, 0, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(170, 170, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(170, 170, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(170, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(170, 85, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(255, 255, 255)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(255, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(85, 170, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(85, 170, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(85, 255, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(85, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(85, 85, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(85, 85, 255)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\(85, 85, 85)
# Cleaning up unwanted color folders in 'test' Masks folder...
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(0, 170, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(170, 0, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(170, 0, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(170, 170, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(170, 170, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(170, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(170, 85, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(255, 255, 255)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(255, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(85, 170, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(85, 170, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(85, 255, 85)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(85, 85, 0)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(85, 85, 170)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(85, 85, 255)
# Removed folder with unlisted color: ..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\(85, 85, 85)
# Unwanted color folders removed successfully.

# %% [markdown]
# ## Rename the classes to their class names from their color RGB values

# %%
# Define the color-to-class name mapping
color_to_class_name = {
    "(170, 0, 85)": "unknown",
    "(0, 85, 170)": "grasper",
    "(0, 85, 255)": "bipolar",
    "(0, 170, 85)": "hook",
    "(0, 255, 85)": "scissors",
    "(0, 255, 170)": "clipper",
    "(85, 0, 170)": "irrigator",
    "(85, 0, 255)": "specimen-bag",
    "(170, 85, 85)": "trocars",
    "(170, 170, 170)": "clip",
    "(85, 170, 0)": "liver",
    "(85, 170, 255)": "gall-bladder",
    "(85, 255, 0)": "fat",
    "(85, 255, 170)": "upperwall",
    "(170, 0, 255)": "artery",
    "(255, 0, 255)": "intestine",
    "(255, 255, 0)": "bile",
    "(255, 0, 0)": "blood",
    "(0, 0, 0)": "black"
}

# Folders to process
dataset_folders = ["trainval", "train", "test"]

# Iterate over each dataset folder and rename color folders
for split in dataset_folders:
    masks_dir = os.path.join(base_after_folder, split, "Masks")
    for folder_name in os.listdir(masks_dir):
        if folder_name in color_to_class_name:
            # Get the new name for the folder
            new_folder_name = color_to_class_name[folder_name]
            old_folder_path = os.path.join(masks_dir, folder_name)
            new_folder_path = os.path.join(masks_dir, new_folder_name)
            
            # Rename the folder
            if not os.path.exists(new_folder_path):  # Avoid overwriting
                os.rename(old_folder_path, new_folder_path)
                print(f"Renamed '{folder_name}' to '{new_folder_name}' in '{split}' Masks folder.")
            else:
                print(f"Skipped renaming '{folder_name}' to '{new_folder_name}' as it already exists.")
# Out:
# Renamed '(0, 0, 0)' to 'black' in 'trainval' Masks folder.
# Renamed '(0, 170, 85)' to 'hook' in 'trainval' Masks folder.
# Renamed '(0, 255, 170)' to 'clipper' in 'trainval' Masks folder.
# Renamed '(0, 255, 85)' to 'scissors' in 'trainval' Masks folder.
# Renamed '(0, 85, 170)' to 'grasper' in 'trainval' Masks folder.
# Renamed '(0, 85, 255)' to 'bipolar' in 'trainval' Masks folder.
# Renamed '(170, 0, 255)' to 'artery' in 'trainval' Masks folder.
# Renamed '(170, 0, 85)' to 'unknown' in 'trainval' Masks folder.
# Renamed '(170, 170, 170)' to 'clip' in 'trainval' Masks folder.
# Renamed '(170, 85, 85)' to 'trocars' in 'trainval' Masks folder.
# Renamed '(255, 0, 0)' to 'blood' in 'trainval' Masks folder.
# Renamed '(255, 0, 255)' to 'intestine' in 'trainval' Masks folder.
# Renamed '(255, 255, 0)' to 'bile' in 'trainval' Masks folder.
# Renamed '(85, 0, 170)' to 'irrigator' in 'trainval' Masks folder.
# Renamed '(85, 0, 255)' to 'specimen-bag' in 'trainval' Masks folder.
# Renamed '(85, 170, 0)' to 'liver' in 'trainval' Masks folder.
# Renamed '(85, 170, 255)' to 'gall-bladder' in 'trainval' Masks folder.
# Renamed '(85, 255, 0)' to 'fat' in 'trainval' Masks folder.
# Renamed '(85, 255, 170)' to 'upperwall' in 'trainval' Masks folder.
# Renamed '(0, 0, 0)' to 'black' in 'train' Masks folder.
# Renamed '(0, 170, 85)' to 'hook' in 'train' Masks folder.
# Renamed '(0, 255, 170)' to 'clipper' in 'train' Masks folder.
# Renamed '(0, 255, 85)' to 'scissors' in 'train' Masks folder.
# Renamed '(0, 85, 170)' to 'grasper' in 'train' Masks folder.
# Renamed '(0, 85, 255)' to 'bipolar' in 'train' Masks folder.
# Renamed '(170, 0, 255)' to 'artery' in 'train' Masks folder.
# Renamed '(170, 0, 85)' to 'unknown' in 'train' Masks folder.
# Renamed '(170, 170, 170)' to 'clip' in 'train' Masks folder.
# Renamed '(170, 85, 85)' to 'trocars' in 'train' Masks folder.
# Renamed '(255, 0, 0)' to 'blood' in 'train' Masks folder.
# Renamed '(255, 0, 255)' to 'intestine' in 'train' Masks folder.
# Renamed '(255, 255, 0)' to 'bile' in 'train' Masks folder.
# Renamed '(85, 0, 170)' to 'irrigator' in 'train' Masks folder.
# Renamed '(85, 0, 255)' to 'specimen-bag' in 'train' Masks folder.
# Renamed '(85, 170, 0)' to 'liver' in 'train' Masks folder.
# Renamed '(85, 170, 255)' to 'gall-bladder' in 'train' Masks folder.
# Renamed '(85, 255, 0)' to 'fat' in 'train' Masks folder.
# Renamed '(85, 255, 170)' to 'upperwall' in 'train' Masks folder.
# Renamed '(0, 0, 0)' to 'black' in 'test' Masks folder.
# Renamed '(0, 170, 85)' to 'hook' in 'test' Masks folder.
# Renamed '(0, 255, 170)' to 'clipper' in 'test' Masks folder.
# Renamed '(0, 255, 85)' to 'scissors' in 'test' Masks folder.
# Renamed '(0, 85, 170)' to 'grasper' in 'test' Masks folder.
# Renamed '(0, 85, 255)' to 'bipolar' in 'test' Masks folder.
# Renamed '(170, 0, 255)' to 'artery' in 'test' Masks folder.
# Renamed '(170, 0, 85)' to 'unknown' in 'test' Masks folder.
# Renamed '(170, 170, 170)' to 'clip' in 'test' Masks folder.
# Renamed '(170, 85, 85)' to 'trocars' in 'test' Masks folder.
# Renamed '(255, 0, 0)' to 'blood' in 'test' Masks folder.
# Renamed '(255, 0, 255)' to 'intestine' in 'test' Masks folder.
# Renamed '(255, 255, 0)' to 'bile' in 'test' Masks folder.
# Renamed '(85, 0, 170)' to 'irrigator' in 'test' Masks folder.
# Renamed '(85, 0, 255)' to 'specimen-bag' in 'test' Masks folder.
# Renamed '(85, 170, 0)' to 'liver' in 'test' Masks folder.
# Renamed '(85, 170, 255)' to 'gall-bladder' in 'test' Masks folder.
# Renamed '(85, 255, 0)' to 'fat' in 'test' Masks folder.
# Renamed '(85, 255, 170)' to 'upperwall' in 'test' Masks folder.

# %% [markdown]
# ## Removing the "_gt" from the mask files names for easy handling

# %%
# List of dataset splits
dataset_folders = ["trainval", "train", "test"]

# Loop through each dataset split and traverse all subfolders to remove "_gt" in file names
for split in dataset_folders:
    masks_dir = os.path.join(base_after_folder, split, "Masks")
    
    # Walk through all subdirectories and files in the Masks directory
    for root, _, files in os.walk(masks_dir):
        for file_name in files:
            # Check if "_gt" is in the file name before the extension
            if "_gt" in file_name:
                new_name = file_name.replace("_gt", "")  # Remove "_gt" from the file name
                old_file_path = os.path.join(root, file_name)
                new_file_path = os.path.join(root, new_name)
                
                # Rename the file
                os.rename(old_file_path, new_file_path)
                print(f"Renamed '{file_name}' to '{new_name}' in folder '{root}' for '{split}'")

print("Renaming complete.")
# Out:
# Renamed '04175_gt.png' to '04175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '05150_gt.png' to '05150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '14500_gt.png' to '14500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '1700_gt.png' to '1700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '1950_gt.png' to '1950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '20400_gt.png' to '20400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '20650_gt.png' to '20650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '20900_gt.png' to '20900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '21150_gt.png' to '21150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '21400_gt.png' to '21400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '21625_gt.png' to '21625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '21875_gt.png' to '21875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '2275_gt.png' to '2275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '22875_gt.png' to '22875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '23100_gt.png' to '23100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '23350_gt.png' to '23350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '23600_gt.png' to '23600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25025_gt.png' to '25025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25050_gt.png' to '25050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25075_gt.png' to '25075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25100_gt.png' to '25100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25125_gt.png' to '25125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25150_gt.png' to '25150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25175_gt.png' to '25175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25200_gt.png' to '25200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25225_gt.png' to '25225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25250_gt.png' to '25250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25275_gt.png' to '25275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25300_gt.png' to '25300.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25325_gt.png' to '25325.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25350_gt.png' to '25350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25375_gt.png' to '25375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25400_gt.png' to '25400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25425_gt.png' to '25425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25450_gt.png' to '25450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25475_gt.png' to '25475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25500_gt.png' to '25500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25525_gt.png' to '25525.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25550_gt.png' to '25550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25575_gt.png' to '25575.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25600_gt.png' to '25600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25625_gt.png' to '25625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25650_gt.png' to '25650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25675_gt.png' to '25675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25700_gt.png' to '25700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25725_gt.png' to '25725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25775_gt.png' to '25775.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25800_gt.png' to '25800.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25825_gt.png' to '25825.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25850_gt.png' to '25850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25875_gt.png' to '25875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25900_gt.png' to '25900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25925_gt.png' to '25925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25950_gt.png' to '25950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '25975_gt.png' to '25975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26025_gt.png' to '26025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26050_gt.png' to '26050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26100_gt.png' to '26100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26125_gt.png' to '26125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26150_gt.png' to '26150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26175_gt.png' to '26175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26200_gt.png' to '26200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26225_gt.png' to '26225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26250_gt.png' to '26250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26275_gt.png' to '26275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26300_gt.png' to '26300.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26325_gt.png' to '26325.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26350_gt.png' to '26350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26375_gt.png' to '26375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26400_gt.png' to '26400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26425_gt.png' to '26425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26450_gt.png' to '26450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26475_gt.png' to '26475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26500_gt.png' to '26500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26525_gt.png' to '26525.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26550_gt.png' to '26550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26575_gt.png' to '26575.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26600_gt.png' to '26600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26625_gt.png' to '26625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26650_gt.png' to '26650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26675_gt.png' to '26675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26700_gt.png' to '26700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26725_gt.png' to '26725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26750_gt.png' to '26750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26775_gt.png' to '26775.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26800_gt.png' to '26800.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26825_gt.png' to '26825.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26925_gt.png' to '26925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26950_gt.png' to '26950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '26975_gt.png' to '26975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27000_gt.png' to '27000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '2700_gt.png' to '2700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27025_gt.png' to '27025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27050_gt.png' to '27050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27075_gt.png' to '27075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27100_gt.png' to '27100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27125_gt.png' to '27125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27150_gt.png' to '27150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27175_gt.png' to '27175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27200_gt.png' to '27200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27225_gt.png' to '27225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27250_gt.png' to '27250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27275_gt.png' to '27275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27300_gt.png' to '27300.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27325_gt.png' to '27325.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27575_gt.png' to '27575.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27600_gt.png' to '27600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27625_gt.png' to '27625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27650_gt.png' to '27650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27675_gt.png' to '27675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '27700_gt.png' to '27700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28000_gt.png' to '28000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28025_gt.png' to '28025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28050_gt.png' to '28050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28075_gt.png' to '28075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28100_gt.png' to '28100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28125_gt.png' to '28125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28150_gt.png' to '28150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28175_gt.png' to '28175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '28200_gt.png' to '28200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '2950_gt.png' to '2950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '30600_gt.png' to '30600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '30625_gt.png' to '30625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '30650_gt.png' to '30650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '30675_gt.png' to '30675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '30900_gt.png' to '30900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4050_gt.png' to '4050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4075_gt.png' to '4075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4100_gt.png' to '4100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4125_gt.png' to '4125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4150_gt.png' to '4150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4175_gt.png' to '4175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4425_gt.png' to '4425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '44525_gt.png' to '44525.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4550_gt.png' to '4550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '46000_gt.png' to '46000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '46225_gt.png' to '46225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4650_gt.png' to '4650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '46975_gt.png' to '46975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '475_gt.png' to '475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4900_gt.png' to '4900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4950_gt.png' to '4950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '4975_gt.png' to '4975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5000_gt.png' to '5000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5025_gt.png' to '5025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5050_gt.png' to '5050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5075_gt.png' to '5075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5100_gt.png' to '5100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5125_gt.png' to '5125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5150_gt.png' to '5150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5175_gt.png' to '5175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '53875_gt.png' to '53875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '53900_gt.png' to '53900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '53925_gt.png' to '53925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '53950_gt.png' to '53950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '53975_gt.png' to '53975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54000_gt.png' to '54000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5400_gt.png' to '5400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54025_gt.png' to '54025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54050_gt.png' to '54050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54075_gt.png' to '54075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54100_gt.png' to '54100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54125_gt.png' to '54125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54150_gt.png' to '54150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54175_gt.png' to '54175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54225_gt.png' to '54225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54250_gt.png' to '54250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54275_gt.png' to '54275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54325_gt.png' to '54325.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54350_gt.png' to '54350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54375_gt.png' to '54375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '54400_gt.png' to '54400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5700_gt.png' to '5700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '5900_gt.png' to '5900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '6150_gt.png' to '6150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '6375_gt.png' to '6375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '6875_gt.png' to '6875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '7125_gt.png' to '7125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '7625_gt.png' to '7625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' for 'trainval'
# Renamed '17700_gt.png' to '17700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bile' for 'trainval'
# Renamed '18925_gt.png' to '18925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bile' for 'trainval'
# Renamed '7125_gt.png' to '7125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bile' for 'trainval'
# Renamed '7375_gt.png' to '7375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bile' for 'trainval'
# Renamed '7625_gt.png' to '7625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bile' for 'trainval'
# Renamed '7850_gt.png' to '7850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bile' for 'trainval'
# Renamed '8100_gt.png' to '8100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bile' for 'trainval'
# Renamed '18925_gt.png' to '18925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '44025_gt.png' to '44025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '44275_gt.png' to '44275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '54225_gt.png' to '54225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '55950_gt.png' to '55950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '55975_gt.png' to '55975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '56000_gt.png' to '56000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '56025_gt.png' to '56025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '56050_gt.png' to '56050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '56075_gt.png' to '56075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '56100_gt.png' to '56100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\bipolar' for 'trainval'
# Renamed '00_gt.png' to '00.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '015975_gt.png' to '015975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '030750_gt.png' to '030750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '03425_gt.png' to '03425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '04175_gt.png' to '04175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '05150_gt.png' to '05150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '06625_gt.png' to '06625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '0_gt.png' to '0.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '10075_gt.png' to '10075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '10275_gt.png' to '10275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '1125_gt.png' to '1125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '11400_gt.png' to '11400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '1225_gt.png' to '1225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '12550_gt.png' to '12550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '13025_gt.png' to '13025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '13700_gt.png' to '13700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '14000_gt.png' to '14000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '14500_gt.png' to '14500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '1475_gt.png' to '1475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '14825_gt.png' to '14825.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '15250_gt.png' to '15250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '15975_gt.png' to '15975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '16475_gt.png' to '16475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '1700_gt.png' to '1700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '17700_gt.png' to '17700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '18925_gt.png' to '18925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '1950_gt.png' to '1950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '20400_gt.png' to '20400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '20650_gt.png' to '20650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '20900_gt.png' to '20900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '21150_gt.png' to '21150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '21400_gt.png' to '21400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '21625_gt.png' to '21625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '21875_gt.png' to '21875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '2200_gt.png' to '2200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '22125_gt.png' to '22125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '22375_gt.png' to '22375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '225_gt.png' to '225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '22625_gt.png' to '22625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '2275_gt.png' to '2275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '22875_gt.png' to '22875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '23100_gt.png' to '23100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '23350_gt.png' to '23350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '23600_gt.png' to '23600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '23850_gt.png' to '23850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '2450_gt.png' to '2450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25025_gt.png' to '25025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25050_gt.png' to '25050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25075_gt.png' to '25075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25100_gt.png' to '25100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25125_gt.png' to '25125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25150_gt.png' to '25150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25175_gt.png' to '25175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25200_gt.png' to '25200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25225_gt.png' to '25225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25250_gt.png' to '25250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25275_gt.png' to '25275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25300_gt.png' to '25300.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25325_gt.png' to '25325.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25350_gt.png' to '25350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25375_gt.png' to '25375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25400_gt.png' to '25400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25425_gt.png' to '25425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25450_gt.png' to '25450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25475_gt.png' to '25475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25500_gt.png' to '25500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25525_gt.png' to '25525.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25550_gt.png' to '25550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25575_gt.png' to '25575.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25600_gt.png' to '25600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25625_gt.png' to '25625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25650_gt.png' to '25650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25675_gt.png' to '25675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25700_gt.png' to '25700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25725_gt.png' to '25725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25775_gt.png' to '25775.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25800_gt.png' to '25800.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25825_gt.png' to '25825.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25850_gt.png' to '25850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25875_gt.png' to '25875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25900_gt.png' to '25900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25925_gt.png' to '25925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25950_gt.png' to '25950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '25975_gt.png' to '25975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26000_gt.png' to '26000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26025_gt.png' to '26025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26050_gt.png' to '26050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26075_gt.png' to '26075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26100_gt.png' to '26100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26125_gt.png' to '26125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26150_gt.png' to '26150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26175_gt.png' to '26175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26200_gt.png' to '26200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26225_gt.png' to '26225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26250_gt.png' to '26250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26275_gt.png' to '26275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26300_gt.png' to '26300.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26325_gt.png' to '26325.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26350_gt.png' to '26350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26375_gt.png' to '26375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26400_gt.png' to '26400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26425_gt.png' to '26425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26450_gt.png' to '26450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26475_gt.png' to '26475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26500_gt.png' to '26500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26525_gt.png' to '26525.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26550_gt.png' to '26550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26575_gt.png' to '26575.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26600_gt.png' to '26600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26625_gt.png' to '26625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26650_gt.png' to '26650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26675_gt.png' to '26675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26700_gt.png' to '26700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26725_gt.png' to '26725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26750_gt.png' to '26750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26775_gt.png' to '26775.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26800_gt.png' to '26800.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26825_gt.png' to '26825.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26925_gt.png' to '26925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26950_gt.png' to '26950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '26975_gt.png' to '26975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27000_gt.png' to '27000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '2700_gt.png' to '2700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27025_gt.png' to '27025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27050_gt.png' to '27050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27075_gt.png' to '27075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27100_gt.png' to '27100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27125_gt.png' to '27125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27150_gt.png' to '27150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27175_gt.png' to '27175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27200_gt.png' to '27200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27225_gt.png' to '27225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27250_gt.png' to '27250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27275_gt.png' to '27275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27300_gt.png' to '27300.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27325_gt.png' to '27325.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27575_gt.png' to '27575.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27600_gt.png' to '27600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27625_gt.png' to '27625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27650_gt.png' to '27650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27675_gt.png' to '27675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '27700_gt.png' to '27700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28000_gt.png' to '28000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28025_gt.png' to '28025.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28050_gt.png' to '28050.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28075_gt.png' to '28075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28100_gt.png' to '28100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28125_gt.png' to '28125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28150_gt.png' to '28150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28175_gt.png' to '28175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '28200_gt.png' to '28200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '2950_gt.png' to '2950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30000_gt.png' to '30000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30250_gt.png' to '30250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30500_gt.png' to '30500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30600_gt.png' to '30600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30625_gt.png' to '30625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30650_gt.png' to '30650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30675_gt.png' to '30675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30700_gt.png' to '30700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30725_gt.png' to '30725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30750_gt.png' to '30750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30775_gt.png' to '30775.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30800_gt.png' to '30800.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30825_gt.png' to '30825.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30850_gt.png' to '30850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30875_gt.png' to '30875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30900_gt.png' to '30900.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '30975_gt.png' to '30975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '31225_gt.png' to '31225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '31475_gt.png' to '31475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '31725_gt.png' to '31725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '3175_gt.png' to '3175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '31975_gt.png' to '31975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '32225_gt.png' to '32225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '32450_gt.png' to '32450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '32700_gt.png' to '32700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '32950_gt.png' to '32950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '33200_gt.png' to '33200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '33450_gt.png' to '33450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '33700_gt.png' to '33700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '33925_gt.png' to '33925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# Renamed '34175_gt.png' to '34175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\black' for 'trainval'
# ...
# Renamed '13700_gt.png' to '13700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '14000_gt.png' to '14000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '14500_gt.png' to '14500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '1475_gt.png' to '1475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '15250_gt.png' to '15250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '17700_gt.png' to '17700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '1950_gt.png' to '1950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '20400_gt.png' to '20400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '21150_gt.png' to '21150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '21400_gt.png' to '21400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '22125_gt.png' to '22125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '225_gt.png' to '225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '22625_gt.png' to '22625.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '2275_gt.png' to '2275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '22875_gt.png' to '22875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '23100_gt.png' to '23100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '23350_gt.png' to '23350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '23600_gt.png' to '23600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '2450_gt.png' to '2450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '30000_gt.png' to '30000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '30250_gt.png' to '30250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '30750_gt.png' to '30750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '31225_gt.png' to '31225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '31475_gt.png' to '31475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '3175_gt.png' to '3175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '32950_gt.png' to '32950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '33450_gt.png' to '33450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '33925_gt.png' to '33925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '34175_gt.png' to '34175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '3425_gt.png' to '3425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '34675_gt.png' to '34675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '3675_gt.png' to '3675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '3925_gt.png' to '3925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '4175_gt.png' to '4175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '44275_gt.png' to '44275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '44750_gt.png' to '44750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '45250_gt.png' to '45250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '4550_gt.png' to '4550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '46000_gt.png' to '46000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '46475_gt.png' to '46475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '4650_gt.png' to '4650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '47950_gt.png' to '47950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '48450_gt.png' to '48450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '48700_gt.png' to '48700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '5150_gt.png' to '5150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '5650_gt.png' to '5650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '5700_gt.png' to '5700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '6150_gt.png' to '6150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '6375_gt.png' to '6375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '6850_gt.png' to '6850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '725_gt.png' to '725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '7375_gt.png' to '7375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '7850_gt.png' to '7850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '7975_gt.png' to '7975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '8100_gt.png' to '8100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '975_gt.png' to '975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' for 'test'
# Renamed '20400_gt.png' to '20400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\scissors' for 'test'
# Renamed '23350_gt.png' to '23350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\scissors' for 'test'
# Renamed '23600_gt.png' to '23600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\scissors' for 'test'
# Renamed '21150_gt.png' to '21150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' for 'test'
# Renamed '21400_gt.png' to '21400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' for 'test'
# Renamed '23600_gt.png' to '23600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' for 'test'
# Renamed '44750_gt.png' to '44750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' for 'test'
# Renamed '45250_gt.png' to '45250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' for 'test'
# Renamed '48700_gt.png' to '48700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' for 'test'
# Renamed '00_gt.png' to '00.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '2275_gt.png' to '2275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '3925_gt.png' to '3925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '4175_gt.png' to '4175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '4550_gt.png' to '4550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '46000_gt.png' to '46000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '47950_gt.png' to '47950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '48700_gt.png' to '48700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '5700_gt.png' to '5700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '6150_gt.png' to '6150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '6375_gt.png' to '6375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' for 'test'
# Renamed '20400_gt.png' to '20400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '21400_gt.png' to '21400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '23100_gt.png' to '23100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '3925_gt.png' to '3925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '4175_gt.png' to '4175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '46000_gt.png' to '46000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '46975_gt.png' to '46975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '49200_gt.png' to '49200.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' for 'test'
# Renamed '00_gt.png' to '00.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '10075_gt.png' to '10075.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '1225_gt.png' to '1225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '12550_gt.png' to '12550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '13700_gt.png' to '13700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '14000_gt.png' to '14000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '14500_gt.png' to '14500.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '1475_gt.png' to '1475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '15250_gt.png' to '15250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '17700_gt.png' to '17700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '1950_gt.png' to '1950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '21150_gt.png' to '21150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '21400_gt.png' to '21400.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '22125_gt.png' to '22125.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '225_gt.png' to '225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '2275_gt.png' to '2275.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '22875_gt.png' to '22875.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '23100_gt.png' to '23100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '23350_gt.png' to '23350.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '23600_gt.png' to '23600.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '2450_gt.png' to '2450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '30000_gt.png' to '30000.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '30250_gt.png' to '30250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '30750_gt.png' to '30750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '31225_gt.png' to '31225.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '31475_gt.png' to '31475.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '3175_gt.png' to '3175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '32950_gt.png' to '32950.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '3425_gt.png' to '3425.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '3675_gt.png' to '3675.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '3925_gt.png' to '3925.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '4175_gt.png' to '4175.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '44750_gt.png' to '44750.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '45250_gt.png' to '45250.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '4550_gt.png' to '4550.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '4650_gt.png' to '4650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '48450_gt.png' to '48450.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '48700_gt.png' to '48700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '5150_gt.png' to '5150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '5650_gt.png' to '5650.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '5700_gt.png' to '5700.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '6150_gt.png' to '6150.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '6375_gt.png' to '6375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '6850_gt.png' to '6850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '725_gt.png' to '725.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '7375_gt.png' to '7375.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '7850_gt.png' to '7850.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '7975_gt.png' to '7975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '8100_gt.png' to '8100.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renamed '975_gt.png' to '975.png' in folder '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' for 'test'
# Renaming complete.

# %% [markdown]
# ## Removing masks with largest isolated island area less than 50 pixels (due to errors in mask creation?)

# %%
# Threshold for the largest connected component area
min_area_threshold = 50

# Function to calculate the area of the largest connected component
def largest_connected_component_area(image_path):
    # Open the image and convert to grayscale
    image = Image.open(image_path).convert("L")
    image_np = np.array(image)

    # Binarize the image (assuming non-zero pixels are part of the mask)
    _, binary_image = cv2.threshold(image_np, 1, 255, cv2.THRESH_BINARY)

    # Find connected components
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(binary_image, connectivity=8)

    # If there are no components, return 0
    if num_labels <= 1:
        return 0

    # Exclude the background component and find the largest area
    largest_area = max(stat[cv2.CC_STAT_AREA] for stat in stats[1:])
    return largest_area

# Process each dataset split
for split in dataset_folders:
    masks_dir = os.path.join(base_after_folder, split, "Masks")
    
    # Walk through all subdirectories and mask files
    for root, _, files in os.walk(masks_dir):
        for file_name in files:
            mask_path = os.path.join(root, file_name)
            
            # Check the largest connected component area
            largest_area = largest_connected_component_area(mask_path)
            
            # Delete file if largest connected component area is below the threshold
            if largest_area < min_area_threshold:
                os.remove(mask_path)
                print(f"Removed '{file_name}' in '{root}' as largest component area was {largest_area} pixels.")
                
print("Mask cleanup complete.")
# Out:
# Removed '04175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 49 pixels.
# Removed '05150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 36 pixels.
# Removed '14500.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 7 pixels.
# Removed '1700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 34 pixels.
# Removed '1950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 27 pixels.
# Removed '2275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 16 pixels.
# Removed '2700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 17 pixels.
# Removed '2950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 12 pixels.
# Removed '30600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 5 pixels.
# Removed '30625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 17 pixels.
# Removed '30650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 17 pixels.
# Removed '30675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 33 pixels.
# Removed '30900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 22 pixels.
# Removed '4050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 37 pixels.
# Removed '4075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 43 pixels.
# Removed '4100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 16 pixels.
# Removed '4125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 33 pixels.
# Removed '4150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 35 pixels.
# Removed '4175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 30 pixels.
# Removed '4425.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 30 pixels.
# Removed '44525.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 17 pixels.
# Removed '4550.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 15 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 46 pixels.
# Removed '46225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 31 pixels.
# Removed '4650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 14 pixels.
# Removed '46975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 43 pixels.
# Removed '475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 8 pixels.
# Removed '4900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 13 pixels.
# Removed '4950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 27 pixels.
# Removed '5000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 33 pixels.
# Removed '5025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 36 pixels.
# Removed '5075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 44 pixels.
# Removed '5125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 30 pixels.
# Removed '5150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 9 pixels.
# Removed '5400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 5 pixels.
# Removed '54050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 35 pixels.
# Removed '54075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 36 pixels.
# Removed '54100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 34 pixels.
# Removed '54125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 14 pixels.
# Removed '54150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 15 pixels.
# Removed '54175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 15 pixels.
# Removed '54225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 36 pixels.
# Removed '54250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 18 pixels.
# Removed '54275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 7 pixels.
# Removed '54325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 21 pixels.
# Removed '54350.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 29 pixels.
# Removed '54375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 27 pixels.
# Removed '54400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 22 pixels.
# Removed '5700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 14 pixels.
# Removed '6150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 9 pixels.
# Removed '6375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 17 pixels.
# Removed '6875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 7 pixels.
# Removed '7125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 17 pixels.
# Removed '7625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\artery' as largest component area was 21 pixels.
# Removed '10075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 17 pixels.
# Removed '13700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 15 pixels.
# Removed '20900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 21 pixels.
# Removed '26100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 41 pixels.
# Removed '26150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 9 pixels.
# Removed '26425.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 23 pixels.
# Removed '26475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 19 pixels.
# Removed '26525.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 26 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 27 pixels.
# Removed '4650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 7 pixels.
# Removed '48700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 18 pixels.
# Removed '48950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 31 pixels.
# Removed '53875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 26 pixels.
# Removed '53900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 20 pixels.
# Removed '53925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 20 pixels.
# Removed '53975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 34 pixels.
# Removed '54000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 27 pixels.
# Removed '54025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 31 pixels.
# Removed '54050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 19 pixels.
# Removed '54075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 21 pixels.
# Removed '54100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 19 pixels.
# Removed '54125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 20 pixels.
# Removed '54150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 32 pixels.
# Removed '54175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 35 pixels.
# Removed '54225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 25 pixels.
# Removed '54250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 27 pixels.
# Removed '54275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 28 pixels.
# Removed '54300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 22 pixels.
# Removed '54325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 19 pixels.
# Removed '54350.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 16 pixels.
# Removed '54375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 20 pixels.
# Removed '54400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 43 pixels.
# Removed '55000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 21 pixels.
# Removed '55025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 10 pixels.
# Removed '55050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 13 pixels.
# Removed '55075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 32 pixels.
# Removed '55100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 19 pixels.
# Removed '55125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 21 pixels.
# Removed '55150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 11 pixels.
# Removed '55175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 20 pixels.
# Removed '55200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 15 pixels.
# Removed '55225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 20 pixels.
# Removed '55250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 19 pixels.
# Removed '55275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 10 pixels.
# Removed '55300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 43 pixels.
# Removed '7850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\clip' as largest component area was 44 pixels.
# Removed '45250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\gall-bladder' as largest component area was 40 pixels.
# Removed '1225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 5 pixels.
# Removed '1475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 6 pixels.
# Removed '1700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 14 pixels.
# Removed '18925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 29 pixels.
# Removed '1950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 8 pixels.
# Removed '2200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 5 pixels.
# Removed '225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 10 pixels.
# Removed '23100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 9 pixels.
# Removed '23600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 39 pixels.
# Removed '23850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 15 pixels.
# Removed '2450.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 8 pixels.
# Removed '25125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 8 pixels.
# Removed '25450.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 41 pixels.
# Removed '25525.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 31 pixels.
# Removed '25550.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 49 pixels.
# Removed '25575.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 46 pixels.
# Removed '25625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 29 pixels.
# Removed '25650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 30 pixels.
# Removed '25700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 46 pixels.
# Removed '25725.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 19 pixels.
# Removed '25775.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 16 pixels.
# Removed '26100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 9 pixels.
# Removed '26125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 14 pixels.
# Removed '26150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 15 pixels.
# Removed '26175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 13 pixels.
# Removed '26225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 21 pixels.
# Removed '26300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 33 pixels.
# Removed '26325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 15 pixels.
# Removed '26375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 19 pixels.
# Removed '26475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 10 pixels.
# Removed '26650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 11 pixels.
# Removed '26725.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 21 pixels.
# Removed '26800.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 29 pixels.
# Removed '26825.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 8 pixels.
# Removed '26950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 14 pixels.
# Removed '26975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 9 pixels.
# Removed '2700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 7 pixels.
# Removed '27100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 7 pixels.
# Removed '27225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 10 pixels.
# Removed '27300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 9 pixels.
# Removed '4100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 41 pixels.
# Removed '44525.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 15 pixels.
# Removed '45750.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 11 pixels.
# Removed '53100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 12 pixels.
# Removed '53125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 29 pixels.
# Removed '53150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 11 pixels.
# Removed '53175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 16 pixels.
# Removed '53200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 11 pixels.
# Removed '53225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 10 pixels.
# Removed '53275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 21 pixels.
# Removed '53300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 15 pixels.
# Removed '53325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 22 pixels.
# Removed '53875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 15 pixels.
# Removed '53950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 39 pixels.
# Removed '54000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 42 pixels.
# Removed '54025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 33 pixels.
# Removed '54075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 48 pixels.
# Removed '54100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 21 pixels.
# Removed '54125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 21 pixels.
# Removed '54175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 16 pixels.
# Removed '54225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 16 pixels.
# Removed '54250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 25 pixels.
# Removed '54275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 19 pixels.
# Removed '54300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 22 pixels.
# Removed '54325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 17 pixels.
# Removed '54350.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 23 pixels.
# Removed '54375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 24 pixels.
# Removed '54400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 49 pixels.
# Removed '55175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 21 pixels.
# Removed '55900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 23 pixels.
# Removed '55925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 22 pixels.
# Removed '55975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 37 pixels.
# Removed '56075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 28 pixels.
# Removed '56100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 30 pixels.
# Removed '7375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 43 pixels.
# Removed '7850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\hook' as largest component area was 40 pixels.
# Removed '05150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 29 pixels.
# Removed '18925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 17 pixels.
# Removed '20650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 30 pixels.
# Removed '22875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 25 pixels.
# Removed '23600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 16 pixels.
# Removed '25025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 38 pixels.
# Removed '25050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 20 pixels.
# Removed '25075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 49 pixels.
# Removed '25675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 26 pixels.
# Removed '26200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 26 pixels.
# Removed '26225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 25 pixels.
# Removed '26450.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 14 pixels.
# Removed '26700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 30 pixels.
# Removed '26725.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 23 pixels.
# Removed '26800.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 18 pixels.
# Removed '26950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 29 pixels.
# Removed '26975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 32 pixels.
# Removed '27000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 18 pixels.
# Removed '27075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 9 pixels.
# Removed '27100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 16 pixels.
# Removed '27125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 22 pixels.
# Removed '27200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 22 pixels.
# Removed '27275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 27 pixels.
# Removed '28000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 25 pixels.
# Removed '28025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 38 pixels.
# Removed '28050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 32 pixels.
# Removed '28075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 12 pixels.
# Removed '28100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 18 pixels.
# Removed '28125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 18 pixels.
# Removed '46975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 5 pixels.
# Removed '4950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 27 pixels.
# Removed '5000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 24 pixels.
# Removed '5075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 43 pixels.
# Removed '5175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 27 pixels.
# Removed '53875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 44 pixels.
# Removed '53900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 26 pixels.
# Removed '53925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 23 pixels.
# Removed '53975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 49 pixels.
# Removed '54050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 29 pixels.
# Removed '54150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 40 pixels.
# Removed '54175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 45 pixels.
# Removed '54350.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 30 pixels.
# Removed '55075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 29 pixels.
# Removed '55100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 29 pixels.
# Removed '55150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 26 pixels.
# Removed '55175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 32 pixels.
# Removed '55200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 45 pixels.
# Removed '55225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 48 pixels.
# Removed '56050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 47 pixels.
# Removed '56075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\irrigator' as largest component area was 46 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\liver' as largest component area was 13 pixels.
# Removed '46225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\liver' as largest component area was 6 pixels.
# Removed '46475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\liver' as largest component area was 6 pixels.
# Removed '47225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\liver' as largest component area was 32 pixels.
# Removed '47475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\liver' as largest component area was 27 pixels.
# Removed '23350.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 49 pixels.
# Removed '25125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 30 pixels.
# Removed '25150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 44 pixels.
# Removed '26125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 23 pixels.
# Removed '26175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 30 pixels.
# Removed '26300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 39 pixels.
# Removed '26475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 34 pixels.
# Removed '27000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 30 pixels.
# Removed '27050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 44 pixels.
# Removed '27075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 34 pixels.
# Removed '27150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 42 pixels.
# Removed '27250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 27 pixels.
# Removed '27275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 25 pixels.
# Removed '27300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\scissors' as largest component area was 27 pixels.
# Removed '20900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 15 pixels.
# Removed '21150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 23 pixels.
# Removed '21400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 28 pixels.
# Removed '21625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 18 pixels.
# Removed '21875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 20 pixels.
# Removed '23600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 16 pixels.
# Removed '25050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 17 pixels.
# Removed '25100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 32 pixels.
# Removed '25125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 23 pixels.
# Removed '25150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 32 pixels.
# Removed '25175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 24 pixels.
# Removed '25200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 21 pixels.
# Removed '26375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 22 pixels.
# Removed '26525.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 22 pixels.
# Removed '26550.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 21 pixels.
# Removed '26575.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 22 pixels.
# Removed '26600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 27 pixels.
# Removed '26650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 30 pixels.
# Removed '26675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 28 pixels.
# Removed '26700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 33 pixels.
# Removed '26775.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 38 pixels.
# Removed '26925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 24 pixels.
# Removed '26950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 34 pixels.
# Removed '26975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 31 pixels.
# Removed '27000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 12 pixels.
# Removed '27025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 19 pixels.
# Removed '27050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 19 pixels.
# Removed '27100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 24 pixels.
# Removed '27150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 35 pixels.
# Removed '27200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 26 pixels.
# Removed '27225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 16 pixels.
# Removed '27250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 13 pixels.
# Removed '27300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 27 pixels.
# Removed '27325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 23 pixels.
# Removed '27575.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 25 pixels.
# Removed '27625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 49 pixels.
# Removed '27650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 41 pixels.
# Removed '27675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 33 pixels.
# Removed '28050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 47 pixels.
# Removed '28100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 44 pixels.
# Removed '28150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 26 pixels.
# Removed '28175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 23 pixels.
# Removed '28200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\specimen-bag' as largest component area was 18 pixels.
# Removed '030750.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 28 pixels.
# Removed '05150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 49 pixels.
# Removed '20900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 10 pixels.
# Removed '23850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 9 pixels.
# Removed '25025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 9 pixels.
# Removed '25050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 8 pixels.
# Removed '25075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 6 pixels.
# Removed '25100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 10 pixels.
# Removed '25125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 9 pixels.
# Removed '25175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 14 pixels.
# Removed '25200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 37 pixels.
# Removed '25225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 16 pixels.
# Removed '25250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 13 pixels.
# Removed '25275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 25 pixels.
# Removed '25325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 11 pixels.
# Removed '25350.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 24 pixels.
# Removed '25425.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 20 pixels.
# Removed '25475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 14 pixels.
# Removed '25500.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 11 pixels.
# Removed '25550.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 15 pixels.
# Removed '25575.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 40 pixels.
# Removed '25800.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 11 pixels.
# Removed '25825.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 12 pixels.
# Removed '25850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 13 pixels.
# Removed '25900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 22 pixels.
# Removed '25925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 19 pixels.
# Removed '26100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 15 pixels.
# Removed '26125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 33 pixels.
# Removed '26225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 30 pixels.
# Removed '26250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 11 pixels.
# Removed '26300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 11 pixels.
# Removed '26325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 8 pixels.
# Removed '26375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 8 pixels.
# Removed '26400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 41 pixels.
# Removed '26500.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 21 pixels.
# Removed '26525.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 31 pixels.
# Removed '26550.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 39 pixels.
# Removed '26600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 27 pixels.
# Removed '26650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 25 pixels.
# Removed '26675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 19 pixels.
# Removed '26700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 17 pixels.
# Removed '26750.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 15 pixels.
# Removed '26950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 43 pixels.
# Removed '26975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 13 pixels.
# Removed '27000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 14 pixels.
# Removed '27025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 15 pixels.
# Removed '27050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 21 pixels.
# Removed '27075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 13 pixels.
# Removed '27100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 32 pixels.
# Removed '27125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 20 pixels.
# Removed '27150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 25 pixels.
# Removed '27175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 35 pixels.
# Removed '27200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 27 pixels.
# Removed '27225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 18 pixels.
# Removed '27250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 20 pixels.
# Removed '27275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 29 pixels.
# Removed '27300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 10 pixels.
# Removed '27325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 18 pixels.
# Removed '27575.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 23 pixels.
# Removed '27625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 14 pixels.
# Removed '27675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 26 pixels.
# Removed '27700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 15 pixels.
# Removed '28000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 10 pixels.
# Removed '28025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 17 pixels.
# Removed '28075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 22 pixels.
# Removed '28100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 21 pixels.
# Removed '28125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 13 pixels.
# Removed '28150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 20 pixels.
# Removed '28175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 18 pixels.
# Removed '28200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 21 pixels.
# Removed '30600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 28 pixels.
# Removed '30775.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 40 pixels.
# Removed '3925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 32 pixels.
# Removed '4075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 47 pixels.
# Removed '4100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 29 pixels.
# Removed '4175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 29 pixels.
# Removed '4425.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 9 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 9 pixels.
# Removed '475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 8 pixels.
# Removed '48200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 25 pixels.
# Removed '5100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 35 pixels.
# Removed '53875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 26 pixels.
# Removed '53900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 38 pixels.
# Removed '53925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\trainval\Masks\trocars' as largest component area was 35 pixels.
# ...
# Removed '26500.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 21 pixels.
# Removed '26525.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 31 pixels.
# Removed '26550.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 39 pixels.
# Removed '26600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 27 pixels.
# Removed '26650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 25 pixels.
# Removed '26675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 19 pixels.
# Removed '26700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 17 pixels.
# Removed '26750.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 15 pixels.
# Removed '26950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 43 pixels.
# Removed '26975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 13 pixels.
# Removed '27000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 14 pixels.
# Removed '27025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 15 pixels.
# Removed '27050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 21 pixels.
# Removed '27075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 13 pixels.
# Removed '27100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 32 pixels.
# Removed '27125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 20 pixels.
# Removed '27150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 25 pixels.
# Removed '27175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 35 pixels.
# Removed '27200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 27 pixels.
# Removed '27225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 18 pixels.
# Removed '27250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 20 pixels.
# Removed '27275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 29 pixels.
# Removed '27300.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 10 pixels.
# Removed '27325.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 18 pixels.
# Removed '27575.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 23 pixels.
# Removed '27625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 14 pixels.
# Removed '27675.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 26 pixels.
# Removed '27700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 15 pixels.
# Removed '28000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 10 pixels.
# Removed '28025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 17 pixels.
# Removed '28075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 22 pixels.
# Removed '28100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 21 pixels.
# Removed '28125.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 13 pixels.
# Removed '28150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 20 pixels.
# Removed '28175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 18 pixels.
# Removed '28200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 21 pixels.
# Removed '30600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 28 pixels.
# Removed '30750.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 28 pixels.
# Removed '30775.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 40 pixels.
# Removed '4075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 47 pixels.
# Removed '4100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 29 pixels.
# Removed '4425.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 9 pixels.
# Removed '475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 8 pixels.
# Removed '48200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 25 pixels.
# Removed '5100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 35 pixels.
# Removed '5150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 49 pixels.
# Removed '53875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 26 pixels.
# Removed '53900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 38 pixels.
# Removed '53925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 35 pixels.
# Removed '53950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 49 pixels.
# Removed '53975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 22 pixels.
# Removed '5400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 11 pixels.
# Removed '54000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 41 pixels.
# Removed '54025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 24 pixels.
# Removed '54050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 43 pixels.
# Removed '54225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 38 pixels.
# Removed '54375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 48 pixels.
# Removed '55000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 14 pixels.
# Removed '55025.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 16 pixels.
# Removed '55050.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 9 pixels.
# Removed '55075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 25 pixels.
# Removed '55100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 12 pixels.
# Removed '6625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\trocars' as largest component area was 28 pixels.
# Removed '18925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\unknown' as largest component area was 30 pixels.
# Removed '20900.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\unknown' as largest component area was 16 pixels.
# Removed '21625.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\unknown' as largest component area was 40 pixels.
# Removed '23850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\unknown' as largest component area was 20 pixels.
# Removed '16475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 48 pixels.
# Removed '2950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 31 pixels.
# Removed '31725.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 32 pixels.
# Removed '31975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 49 pixels.
# Removed '32450.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 31 pixels.
# Removed '33200.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 35 pixels.
# Removed '45750.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 42 pixels.
# Removed '47225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\train\Masks\upperwall' as largest component area was 9 pixels.
# Removed '14500.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 7 pixels.
# Removed '1950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 27 pixels.
# Removed '2275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 16 pixels.
# Removed '4175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 30 pixels.
# Removed '4550.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 15 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 46 pixels.
# Removed '4650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 14 pixels.
# Removed '46975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 43 pixels.
# Removed '5150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 9 pixels.
# Removed '5700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 14 pixels.
# Removed '6150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 9 pixels.
# Removed '6375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\artery' as largest component area was 17 pixels.
# Removed '10075.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\clip' as largest component area was 17 pixels.
# Removed '13700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\clip' as largest component area was 15 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\clip' as largest component area was 27 pixels.
# Removed '4650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\clip' as largest component area was 7 pixels.
# Removed '48700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\clip' as largest component area was 18 pixels.
# Removed '7850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\clip' as largest component area was 44 pixels.
# Removed '45250.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\gall-bladder' as largest component area was 40 pixels.
# Removed '1225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 5 pixels.
# Removed '1475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 6 pixels.
# Removed '1950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 8 pixels.
# Removed '225.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 10 pixels.
# Removed '23100.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 9 pixels.
# Removed '23600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 39 pixels.
# Removed '2450.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 8 pixels.
# Removed '7375.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 43 pixels.
# Removed '7850.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 40 pixels.
# Removed '975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\hook' as largest component area was 13 pixels.
# Removed '22875.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\irrigator' as largest component area was 25 pixels.
# Removed '23600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\irrigator' as largest component area was 16 pixels.
# Removed '46975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\irrigator' as largest component area was 5 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' as largest component area was 13 pixels.
# Removed '46475.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\liver' as largest component area was 6 pixels.
# Removed '23350.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\scissors' as largest component area was 49 pixels.
# Removed '21150.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' as largest component area was 23 pixels.
# Removed '21400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' as largest component area was 28 pixels.
# Removed '23600.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\specimen-bag' as largest component area was 16 pixels.
# Removed '3925.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' as largest component area was 32 pixels.
# Removed '4175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' as largest component area was 29 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' as largest component area was 9 pixels.
# Removed '5700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\trocars' as largest component area was 47 pixels.
# Removed '20400.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' as largest component area was 41 pixels.
# Removed '46000.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' as largest component area was 4 pixels.
# Removed '46975.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\unknown' as largest component area was 4 pixels.
# Removed '13700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' as largest component area was 37 pixels.
# Removed '14500.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' as largest component area was 42 pixels.
# Removed '2275.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' as largest component area was 40 pixels.
# Removed '32950.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' as largest component area was 27 pixels.
# Removed '4175.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' as largest component area was 45 pixels.
# Removed '5650.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' as largest component area was 43 pixels.
# Removed '5700.png' in '..\Datasets_AfterPreprocessing\m2caiSeg\test\Masks\upperwall' as largest component area was 25 pixels.
# Mask cleanup complete.

# %% [markdown]
# ## Additional manual removal of masks that did not have any organ masks was also done

# %% [markdown]
# ## Reshuffling the mask split to have better distribution of classes of masks

# %%
# Define the base directory
base_after_dir = os.path.join("..", "Datasets_AfterPreprocessing", "m2caiSeg")
splits = ["train", "val", "test"]

# Define paths for the Masks in each split
mask_split_dirs = {split: os.path.join(base_after_dir, split, "Masks") for split in splits}

# Temporary directory for unique masks
temp_dir = os.path.join(base_after_dir, "TempMasks")
os.makedirs(temp_dir, exist_ok=True)

# List of organ classes
organ_classes = [
    "upperwall", "scissors", "bipolar", "intestine",
    "artery", "bile", "black", "blood", "clip", "clipper", "fat", "grasper",
    "hook", "irrigator", "liver", "specimen-bag", "trocars", "unknown"
]

# Step 1: Collect all unique mask files into the TempMasks folder
unique_mask_files = defaultdict(set)

print("Collecting unique mask files into TempMasks...")
for split in splits:
    for organ in organ_classes:
        organ_path = os.path.join(mask_split_dirs[split], organ)
        if os.path.exists(organ_path):
            for mask_file in os.listdir(organ_path):
                mask_path = os.path.join(organ_path, mask_file)
                if os.path.isfile(mask_path):
                    unique_mask_files[organ].add(mask_file)
                    temp_organ_dir = os.path.join(temp_dir, organ)
                    os.makedirs(temp_organ_dir, exist_ok=True)
                    shutil.copy2(mask_path, temp_organ_dir)

# Step 2: Remove masks from their original locations
print("Removing masks from original locations...")
for split in splits:
    for organ in organ_classes:
        organ_path = os.path.join(mask_split_dirs[split], organ)
        if os.path.exists(organ_path):
            for mask_file in os.listdir(organ_path):
                mask_path = os.path.join(organ_path, mask_file)
                if os.path.isfile(mask_path):
                    os.remove(mask_path)

# Step 3: Distribute masks back to train/val/test in 80/10/10 ratio
print("Distributing masks to train/val/test in 80/10/10 ratio...")
for organ, masks in unique_mask_files.items():
    masks = list(masks)
    random.shuffle(masks)
    total_masks = len(masks)

    # Calculate split indices
    train_idx = int(total_masks * 0.8)
    val_idx = train_idx + int(total_masks * 0.1)

    # Split masks into train, val, and test
    split_masks = {
        "train": masks[:train_idx],
        "val": masks[train_idx:val_idx],
        "test": masks[val_idx:]
    }

    # Copy masks to their respective directories
    for split, mask_list in split_masks.items():
        organ_split_dir = os.path.join(mask_split_dirs[split], organ)
        os.makedirs(organ_split_dir, exist_ok=True)
        for mask_file in mask_list:
            temp_organ_dir = os.path.join(temp_dir, organ)
            temp_mask_path = os.path.join(temp_organ_dir, mask_file)
            if os.path.exists(temp_mask_path):
                shutil.copy2(temp_mask_path, organ_split_dir)

# Step 4: Clean up temporary folder
print("Cleaning up TempMasks folder...")
shutil.rmtree(temp_dir)

# Step 5: Print final summary
print("\nFinal Split Summary:")
for split in splits:
    print(f"\n{split.capitalize()} Split:")
    for organ in organ_classes:
        organ_split_dir = os.path.join(mask_split_dirs[split], organ)
        if os.path.exists(organ_split_dir):
            print(f"  {organ}: {len(os.listdir(organ_split_dir))} masks")
# Out:
# Collecting unique mask files into TempMasks...
# Removing masks from original locations...
# Distributing masks to train/val/test in 80/10/10 ratio...
# Cleaning up TempMasks folder...
#
# Final Split Summary:
#
# Train Split:
#   upperwall: 178 masks
#   scissors: 12 masks
#   bipolar: 8 masks
#   intestine: 64 masks
#   artery: 90 masks
#   bile: 5 masks
#   blood: 17 masks
#   clipper: 41 masks
#   fat: 231 masks
#   grasper: 205 masks
#   hook: 75 masks
#   irrigator: 8 masks
#   liver: 237 masks
#   specimen-bag: 40 masks
#   trocars: 11 masks
#   unknown: 31 masks
#
# Val Split:
#   upperwall: 22 masks
#   scissors: 1 masks
#   bipolar: 1 masks
#   intestine: 8 masks
#   artery: 11 masks
#   bile: 0 masks
#   blood: 2 masks
#   clipper: 5 masks
#   fat: 28 masks
#   grasper: 25 masks
#   hook: 9 masks
#   irrigator: 1 masks
#   liver: 29 masks
#   specimen-bag: 5 masks
#   trocars: 1 masks
#   unknown: 3 masks
#
# Test Split:
#   upperwall: 23 masks
#   scissors: 2 masks
#   bipolar: 2 masks
#   intestine: 9 masks
#   artery: 12 masks
#   bile: 2 masks
#   blood: 3 masks
#   clipper: 6 masks
#   fat: 30 masks
#   grasper: 27 masks
#   hook: 10 masks
#   irrigator: 2 masks
#   liver: 31 masks
#   specimen-bag: 5 masks
#   trocars: 2 masks
#   unknown: 5 masks

# %% [markdown]
# ## Reshuffling Frames according to the mask split

# %%
# Paths for Masks and Frames in each split
mask_split_dirs = {split: os.path.join(base_after_dir, split, "Masks") for split in splits}
frame_split_dirs = {split: os.path.join(base_after_dir, split, "Frames") for split in splits}

# Temporary directory containing all unique frames
temp_frames_dir = os.path.join(base_after_dir, "TempFrames")

# Ensure TempFrames exists
if not os.path.exists(temp_frames_dir):
    print("Error: TempFrames directory does not exist.")
    exit()

# Step 1: Distribute frames to train/val/test based on masks
print("Distributing frames to train/val/test based on masks...")

missing_frames = defaultdict(list)

for split in splits:
    masks_dir = mask_split_dirs[split]
    frames_dir = frame_split_dirs[split]
    os.makedirs(frames_dir, exist_ok=True)

    # Iterate over all organ class subfolders in the Masks directory
    for organ_folder in os.listdir(masks_dir):
        organ_path = os.path.join(masks_dir, organ_folder)
        if os.path.isdir(organ_path):
            for mask_file in os.listdir(organ_path):
                mask_name = os.path.splitext(mask_file)[0]  # Get the base name of the mask file
                temp_frame_path = os.path.join(temp_frames_dir, f"{mask_name}.jpg")  # Match `.jpg` files in TempFrames
                dest_frame_path = os.path.join(frames_dir, f"{mask_name}.jpg")  # Save as `.jpg`

                # Copy the frame back to the respective split if it exists
                if os.path.exists(temp_frame_path):
                    shutil.copy2(temp_frame_path, dest_frame_path)
                else:
                    # Log missing frames
                    missing_frames[split].append(os.path.join(organ_folder, f"{mask_name}.jpg"))

# Step 2: Report missing frames
print("\nMissing Frame Report:")
total_missing = 0
for split, missing in missing_frames.items():
    print(f"\nSplit: {split}")
    print(f"Missing frames for {len(missing)} masks:")
    if missing:
        for frame_file in missing[:10]:  # Show up to 10 missing files per split for brevity
            print(f"  {frame_file}")
    total_missing += len(missing)

# Step 3: Final Split Summary
print("\nFinal Split Summary:")
for split in splits:
    frames_dir = frame_split_dirs[split]
    if os.path.exists(frames_dir):
        frame_count = len(os.listdir(frames_dir))
        print(f"{split.capitalize()} Split: {frame_count} frames")

# Step 4: Cleanup TempFrames if all frames were successfully distributed
if total_missing == 0:
    print("\nAll frames distributed successfully. Cleaning up TempFrames folder...")
    shutil.rmtree(temp_frames_dir)
else:
    print("\nSome frames were not distributed. Retaining TempFrames folder for debugging.")
    print(f"Total missing frames: {total_missing}")
# Out:
# Distributing frames to train/val/test based on masks...
#
# Missing Frame Report:
#
# Final Split Summary:
# Train Split: 306 frames
# Val Split: 277 frames
# Test Split: 177 frames
#
# All frames distributed successfully. Cleaning up TempFrames folder...

# %% [markdown]
# ## Checking if every masks has a corresponsing Frame in its Frame folders

# %%
# Step 1: Collect all unique frame file names
unique_frame_files = set()

print("Collecting all unique frame file names across splits...")
for split in splits:
    frames_dir = frame_split_dirs[split]
    if os.path.exists(frames_dir):
        for frame_file in os.listdir(frames_dir):
            if os.path.isfile(os.path.join(frames_dir, frame_file)):
                # Normalize file names
                unique_frame_files.add(frame_file.strip().lower())

print(f"Total unique frame files collected: {len(unique_frame_files)}")

# Step 2: Collect all mask file names
all_mask_files = set()

print("\nCollecting all mask file names across splits...")
for split in splits:
    masks_dir = mask_split_dirs[split]
    if os.path.exists(masks_dir):
        for organ_folder in os.listdir(masks_dir):
            organ_path = os.path.join(masks_dir, organ_folder)
            if os.path.isdir(organ_path):
                for mask_file in os.listdir(organ_path):
                    # Normalize mask file names and convert to frame file names
                    frame_file_name = os.path.splitext(mask_file.strip().lower())[0] + ".jpg"
                    all_mask_files.add(frame_file_name)

print(f"Total unique mask files collected: {len(all_mask_files)}")

# Step 3: Compare mask file names with frame file names
missing_frames = all_mask_files - unique_frame_files

# Step 4: Report missing frames
print("\nMissing Frames Report:")
print(f"Total missing frames: {len(missing_frames)}")
for missing_frame in sorted(missing_frames):
    print(f"  {missing_frame}")
# Out:
# Collecting all unique frame file names across splits...
# Total unique frame files collected: 307
#
# Collecting all mask file names across splits...
# Total unique mask files collected: 307
#
# Missing Frames Report:
# Total missing frames: 0

# %% [markdown]
# ## Checking shapes of images vs masks

# %%
# Initialize mismatch counts
mismatch_counts = {}
not_equal_records = []

# Iterate through each split and check the shapes for equality
for split in splits:
    frames_path = frame_split_dirs[split]
    masks_path = mask_split_dirs[split]

    if not os.path.exists(frames_path) or not os.path.exists(masks_path):
        print(f"Missing directory for split: {split}")
        continue

    # Get list of all frame images
    frame_files = {os.path.splitext(f)[0]: f for f in os.listdir(frames_path) if f.endswith(('.jpg', '.png'))}

    # Iterate through organ folders in Masks
    for organ in os.listdir(masks_path):
        organ_path = os.path.join(masks_path, organ)
        if organ not in mismatch_counts:
            mismatch_counts[organ] = 0

        # Get list of mask images in this organ folder
        mask_files = [f for f in os.listdir(organ_path) if f.endswith('.png')]

        for mask_file in mask_files:
            mask_name = os.path.splitext(mask_file)[0]
            mask_path = os.path.join(organ_path, mask_file)

            # Check if the corresponding frame exists
            if mask_name in frame_files:
                frame_path = os.path.join(frames_path, frame_files[mask_name])

                try:
                    # Load frame and mask images
                    frame_img = Image.open(frame_path)
                    mask_img = Image.open(mask_path)

                    # Compare dimensions and log results
                    if frame_img.size == mask_img.size:
                        print(f"[{split}] Shape of mask: {mask_img.size} == Shape of frame: {frame_img.size} (Equal)")
                    else:
                        not_equal_records.append(
                            f"[{split}] Shape of mask: {mask_img.size} != Shape of frame: {frame_img.size} (Not Equal) "
                            f"[Organ: {organ}, Mask: {mask_file}, Frame: {frame_files[mask_name]}]"
                        )
                        mismatch_counts[organ] += 1
                except Exception as e:
                    print(f"Error processing {mask_name} in split {split}: {e}")
            else:
                print(f"[{split}] Missing corresponding frame for mask: {mask_file} in organ: {organ}")

# Print all mismatches at the end
print("\nNot Equal Records:")
for record in not_equal_records:
    print(record)

print("\nMismatch counts by organ:")
for organ, count in mismatch_counts.items():
    print(f"{organ}: {count}")
# Out:
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [train] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# ...
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (716, 402) == Shape of frame: (716, 402) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (774, 434) == Shape of frame: (774, 434) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
# [test] Shape of mask: (596, 334) == Shape of frame: (596, 334) (Equal)
#
# Not Equal Records:
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: fat, Mask: 30750.png, Frame: 30750.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: fat, Mask: 4175.png, Frame: 4175.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: fat, Mask: 5150.png, Frame: 5150.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: grasper, Mask: 4175.png, Frame: 4175.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: hook, Mask: 30750.png, Frame: 30750.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: hook, Mask: 4175.png, Frame: 4175.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: hook, Mask: 5150.png, Frame: 5150.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: intestine, Mask: 5150.png, Frame: 5150.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: liver, Mask: 30750.png, Frame: 30750.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: liver, Mask: 4175.png, Frame: 4175.jpg]
# [train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: liver, Mask: 5150.png, Frame: 5150.jpg]
# [val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 30750.png, Frame: 30750.jpg]
# [val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 4175.png, Frame: 4175.jpg]
# [val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 5150.png, Frame: 5150.jpg]
# [val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: grasper, Mask: 5150.png, Frame: 5150.jpg]
# [val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: intestine, Mask: 4175.png, Frame: 4175.jpg]
# [test] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 30750.png, Frame: 30750.jpg]
# [test] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 4175.png, Frame: 4175.jpg]
# [test] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 5150.png, Frame: 5150.jpg]
#
# Mismatch counts by organ:
# artery: 0
# bile: 0
# bipolar: 0
# blood: 0
# clipper: 0
# fat: 3
# gall-bladder: 6
# grasper: 2
# hook: 3
# intestine: 2
# irrigator: 0
# liver: 3
# scissors: 0
# specimen-bag: 0
# trocars: 0
# unknown: 0
# upperwall: 0

# %% [markdown]
# ## Removing these misamtched files

# %%
# Define mismatched records to remove
not_equal_records = [
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: fat, Mask: 30750.png, Frame: 30750.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: fat, Mask: 4175.png, Frame: 4175.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: fat, Mask: 5150.png, Frame: 5150.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: grasper, Mask: 4175.png, Frame: 4175.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: hook, Mask: 30750.png, Frame: 30750.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: hook, Mask: 4175.png, Frame: 4175.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: hook, Mask: 5150.png, Frame: 5150.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: intestine, Mask: 5150.png, Frame: 5150.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: liver, Mask: 30750.png, Frame: 30750.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: liver, Mask: 4175.png, Frame: 4175.jpg]",
    "[train] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: liver, Mask: 5150.png, Frame: 5150.jpg]",
    "[val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 30750.png, Frame: 30750.jpg]",
    "[val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 4175.png, Frame: 4175.jpg]",
    "[val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 5150.png, Frame: 5150.jpg]",
    "[val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: grasper, Mask: 5150.png, Frame: 5150.jpg]",
    "[val] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: intestine, Mask: 4175.png, Frame: 4175.jpg]",
    "[test] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 30750.png, Frame: 30750.jpg]",
    "[test] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 4175.png, Frame: 4175.jpg]",
    "[test] Shape of mask: (774, 434) != Shape of frame: (596, 334) (Not Equal) [Organ: gall-bladder, Mask: 5150.png, Frame: 5150.jpg]"
]

# Parse and remove files
for record in not_equal_records:
    # Extract split, organ, and filenames from the record
    split = record.split("[")[1].split("]")[0]
    organ = record.split("Organ: ")[1].split(",")[0]
    mask_file = record.split("Mask: ")[1].split(",")[0].strip()
    frame_file = record.split("Frame: ")[1].split("]")[0].strip()

    # Construct paths for mask and frame
    mask_path = os.path.join(base_after_dir, split, "Masks", organ, mask_file)
    frame_path = os.path.join(base_after_dir, split, "Frames", frame_file)

    # Remove the mask file if it exists
    if os.path.exists(mask_path):
        os.remove(mask_path)
        print(f"Removed mask file: {mask_path}")
    else:
        print(f"Mask file not found: {mask_path}")

    # Remove the frame file if it exists
    if os.path.exists(frame_path):
        os.remove(frame_path)
        print(f"Removed frame file: {frame_path}")
    else:
        print(f"Frame file not found: {frame_path}")
# Out:
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\fat\30750.png
# Removed frame file: ..\Datasets\m2caiSeg\train\Frames\30750.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\fat\4175.png
# Removed frame file: ..\Datasets\m2caiSeg\train\Frames\4175.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\fat\5150.png
# Removed frame file: ..\Datasets\m2caiSeg\train\Frames\5150.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\grasper\4175.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\4175.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\hook\30750.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\30750.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\hook\4175.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\4175.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\hook\5150.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\5150.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\intestine\5150.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\5150.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\liver\30750.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\30750.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\liver\4175.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\4175.jpg
# Removed mask file: ..\Datasets\m2caiSeg\train\Masks\liver\5150.png
# Frame file not found: ..\Datasets\m2caiSeg\train\Frames\5150.jpg
# Removed mask file: ..\Datasets\m2caiSeg\val\Masks\gall-bladder\30750.png
# Removed frame file: ..\Datasets\m2caiSeg\val\Frames\30750.jpg
# Removed mask file: ..\Datasets\m2caiSeg\val\Masks\gall-bladder\4175.png
# Removed frame file: ..\Datasets\m2caiSeg\val\Frames\4175.jpg
# Removed mask file: ..\Datasets\m2caiSeg\val\Masks\gall-bladder\5150.png
# Removed frame file: ..\Datasets\m2caiSeg\val\Frames\5150.jpg
# Removed mask file: ..\Datasets\m2caiSeg\val\Masks\grasper\5150.png
# Frame file not found: ..\Datasets\m2caiSeg\val\Frames\5150.jpg
# Removed mask file: ..\Datasets\m2caiSeg\val\Masks\intestine\4175.png
# Frame file not found: ..\Datasets\m2caiSeg\val\Frames\4175.jpg
# Removed mask file: ..\Datasets\m2caiSeg\test\Masks\gall-bladder\30750.png
# Removed frame file: ..\Datasets\m2caiSeg\test\Frames\30750.jpg
# Removed mask file: ..\Datasets\m2caiSeg\test\Masks\gall-bladder\4175.png
# Removed frame file: ..\Datasets\m2caiSeg\test\Frames\4175.jpg
# Removed mask file: ..\Datasets\m2caiSeg\test\Masks\gall-bladder\5150.png
# Removed frame file: ..\Datasets\m2caiSeg\test\Frames\5150.jpg
